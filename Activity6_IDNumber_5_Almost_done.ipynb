# %% [markdown]
# Student Name: Sajin Mohamed Pallikkathodi Erathali
#
# Student ID: 23037601

# %% [markdown]
# # Activity 6: Pytorch and CNNs for Fashion-MNIST
#
# In this activity, we are going to explore designing various neural networks for the FashionMNIST classification problem. This is, of course, a 'toy' problem, but the fundamentals of classification of images is here.

# %% [markdown]
# ## Hints, tips, and notes
#
# * Here I'm not going to mandate TensorBoard. In Colab, this is a little bit more involved. Instead, we'll just put the losses and accuracies in a list and print them after training. However, TensorBoard is very useful, particularly for projects, so I suggest playing around with it.
# * Some of these runs will take several minutes to complete. This is the nature of ML. Grab a beer, or a coffee.
#
# As usual, we will give you some code that you use to build the rest of the activity.

# %% [markdown]
# # Common Code

# %% [markdown]
# All the imports

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Normalize, transforms
from torchsummary import summary
import matplotlib.pyplot as plt
from torchvision import models

# %% [markdown]
# ### 1. Select the device to use.
#
# To access the GPU on Google Colab, `Select Runtime` -> `Change Runtime Type` and pick `GPU` from the `Hardware Accelerator` dropdown menu. In the free version, the GPU is modest. If you buy credits, you get access to a much nice A100 GPU. In both cases, you may find contention for the resource is an issue, but less likely to happen if you use credits.

# %%
# Get appropriate device for training
device = ( "cuda"     # CUDA is a programming interface for certain Nvidia GPUs
           if torch.cuda.is_available()
           else "mps"  # Kind of like CUDA for a mac, I guess? I don't use macs
           if torch.backends.mps.is_available()
           else "cpu" )   # If you end up with CPU, go use Google Colab and get a GPU

print(f"{device} device available")
# Out:
# cuda device available

# %% [markdown]
# ### 2. Code for training the models
#
# I'm going to provide this code, rather than you having to struggle creating it. This is a normal training cycle with PyTorch. However, I do want you to explain the PyTorch functions called in the train function. I will marke them with comments.

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()        #<--- what is this function for?
                         # used to place the model in training mode

    for batch, (X, y) in enumerate(dataloader):
        # print(type(X))
        X, y = X.to(device), y.to(device)   #<--- this is a bit funny, explain it
                                            # Moving the input data to the GPU/CPU device we are using for efficient computation
        # Compute prediction error
        pred = model(X)                     #<--- what is this for?
                                            # predicting the results for the input provided
        loss = loss_fn(pred, y)             #<--- what is this for?
                                            # difference between outputs and true labels are calculated as loss. How far off is the predicted result from the expected results

        # This is the backprop set up. Explain what each of the steps do
        loss.backward()                     #<--- what is this for?
                                            # does the backward pass calculate the gradients that will direct the learning. Using the gradients it changes the weightes nad baises to reduce the loss
        optimizer.step()                    #<--- what is this for?
                                            # based on the optimizer(driving the learning) defined, one learning step is performed, here the gradients from the backward call made above are used to move the learning weights to reduce the loss
        optimizer.zero_grad()               #<--- what is this for?
                                            # gradients accumulated over each batch is reset else the gradients would keep accuumulating and provide incorrect values and learning would be incorrect

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    loss, accuracy = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss += loss_fn(pred, y).item()
            accuracy += (pred.argmax(1) == y).type(torch.float).sum().item()
    loss /= num_batches
    accuracy /= size

    return loss, accuracy

def train_loop(train_dataloader, test_dataloader, model, loss_fn, optimizer, epochs):
    train_loss = []
    train_accuracy = []
    test_loss = []
    test_accuracy = []

    # Iterate over each epoch
    for t in range(epochs):
        print(f"Epoch {t+1}:\n")
        train(train_dataloader, model, loss_fn, optimizer)

        # Get the overall loss and accuracy for both train and test datasets
        tr_loss, tr_acc = test(train_dataloader, model, loss_fn)
        ts_loss, ts_acc = test(test_dataloader, model, loss_fn)

        print(f"Train Error: \n Accuracy: {(100*tr_acc):>0.1f}%, Avg loss: {tr_loss:>8f} \n")
        print(f"Test Error: \n Accuracy: {(100*ts_acc):>0.1f}%, Avg loss: {ts_loss:>8f} \n")

        # Store and return the losses and accuracies. We can graph these later
        train_loss = train_loss + [tr_loss]
        train_accuracy = train_accuracy + [tr_acc]
        test_loss = test_loss + [ts_loss]
        test_accuracy = test_accuracy + [ts_acc]

    print("Done training!")
    return train_loss, train_accuracy, test_loss, test_accuracy

# %% [markdown]
# ### <font color='red'>Your input here.</font>
# <font color='red'>Enter you description of the above parts:</font>

# %% [markdown]
# ### 3. Load the data
#
# 1. Load the Fashion-MNIST dataset using `torchvision`'s `datasets` library (e.g., [`datasets.FashionMNIST...`](https://pytorch.org/vision/stable/generated/torchvision.datasets.FashionMNIST.html)...)
# 2. When loading the data, convert it to tensor format ([`transforms.ToTensor`](https://pytorch.org/vision/stable/generated/torchvision.transforms.ToTensor.html)), and apply the standard scaler to the data (using [`transforms.Normalize`](https://pytorch.org/vision/main/generated/torchvision.transforms.Normalize.html)). Use the [`transforms.Resize`](https://pytorch.org/vision/main/generated/torchvision.transforms.Resize.html) transform to turn it into a 28x28 image rather than a 784-vector
#     * Rather than loading the data, and caluclating the mean and std, you can use the values `mean = 0.2859` and `std = 0.3530`. I pre-calculated these for you!
# 3. Create the [`DataLoader`](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)s. Here we're going to use a batch size of 64.
# 4. Display a few examples of the dataset - this is always a good idea to make sure the data has loaded correctly
#
# We haven't really touched on batch size yet, because up to now we have used plain old gradient descent. Later on, we will use the Adam optimiser, because it is quicker and uses less memory. But Adam is a mini-batch optimizer, and you have to pick that mini-batch size. Bit more info on this, if you are interested:
#  * https://sebastianraschka.com/faq/docs/gradient-optimization.html
#  * https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/
#
# We need to set the batch size when we create the dataloaders.

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
##############################
# Your code below

import numpy as np

# defining a transform to normalize and resize the data
transform = transforms.Compose([transforms.Resize((28,28)),
                                transforms.ToTensor(),
                                transforms.Normalize((0.2859,), (0.3530))])

# downloading the data(train and test)
train_dataset = datasets.FashionMNIST('./data', train = True, download = True, transform = transform)
# note the use of train = False to denote the download of test data
test_dataset = datasets.FashionMNIST('./data', train = False, download = True, transform = transform)

# print("train data set is ", train_dataset ,"end")
batch_size = 64
# defining a dataloader for train and test with batch size of 64 as required
train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True, num_workers = 2)
test_loader = DataLoader(test_dataset, batch_size = batch_size, shuffle = False, num_workers = 2)

# forming a map for prining later
class_labels = {0: 'T-shirt/top', 1: 'Trouser', 2: 'Pullover', 3: 'Dress', 4: 'Coat',
                5: 'Sandal', 6: 'Shirt', 7: 'Sneaker', 8: 'Bag', 9: 'Ankle boot'}


# below obtained from the material provided
def imshow(img):
  img = img / 2 + 0.5 # unnormalize
  npimg = img.numpy ()
  plt.imshow (np.transpose(npimg, (1, 2, 0)))

# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.__next__()

import torchvision
# show 4 images with its labels
imshow (torchvision.utils.make_grid(images[:4]))
print(' '. join('%5s' % class_labels[labels[j].item()] for j in range(4)))
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:02<00:00, 13199857.52it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 208427.49it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 3863481.58it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 26172456.96it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# T-shirt/top Ankle boot T-shirt/top Sneaker

# %% [markdown]
# ---
# ## 1. Replicate the Neural Network from the previous tasks for the FashionMNIST dataset
# ---
#
#
# In the previous activity, you designed a fully connected neural network (a multi-layer perceptron) to predict on Fashion-MNIST.
#
# 1. Replicate the best network that you found in that activity, but in PyTorch.
# 1. Use [`summary`](https://pypi.org/project/torch-summary/) to display a summary of your model.
# 1. Use some random inputs to test the model. This will be meaningless, as the model is not trained yet (and the inputs are random). However, it is useful to test that you have defined the model at leats without any coding errors.
#
# Hints and notes:
#  * We need to [`Flatten`](https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html) the incoming data. In the previous step, you loaded the dataset as a 28x28 image (because, later on we will be using CNNs that require image inputs). However, fully connected layers require vector inputs. `nn.Flatten` converts the image input to a vector (i.e., a 28x28 image to a 784 vector).
#  * Use [`.to(device)`](https://pytorch.org/docs/stable/generated/torch.Tensor.to.html) to "send" objects to the GPU (if you have one). E.g., once you define your class for the neural network, you will create an instance of that NN - you need to send this object to the GPU.
#  * Generally, at inference time, we will use a [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.Softmax.html) on the output of the model. Prior to the softmax, the model outputs a score per class. That is, there will be 10 outputs. However, here we will ignore the softmax part.

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
##############################
# Your code below

'''Define model called Neural network that takes in 784 input parameters
   and uses 3 hidden layers of size 100, 100 and 50 and applies ReLU after each
   fully connected layer and produces an output layer of 10'''
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(784, 100) # 100, 100, 50 relu after each linear
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(100, 100)
        self.fc3 = nn.Linear(100, 50)
        self.fc4 = nn.Linear(50, 10)

    def forward(self, x):
        out = self.flatten(x)
        # print(out)
        out = self.fc1(out)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.fc3(out)
        out = self.relu(out)
        out = self.fc4(out)
        return out

# moving it to the device(GPU) selected above
model = NeuralNetwork().to(device)
summary(model, (1,28*28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                  [-1, 100]          78,500
#               ReLU-3                  [-1, 100]               0
#             Linear-4                  [-1, 100]          10,100
#               ReLU-5                  [-1, 100]               0
#             Linear-6                   [-1, 50]           5,050
#               ReLU-7                   [-1, 50]               0
#             Linear-8                   [-1, 10]             510
# ================================================================
# Total params: 94,160
# Trainable params: 94,160
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.36
# Estimated Total Size (MB): 0.37
# ----------------------------------------------------------------

# %% [markdown]
# Now train the model.
#
# We will use [Cross Entropy Loss](https://towardsdatascience.com/cross-entropy-loss-function-f38c4ec8643e), and as discussed, the Adam optimiser (with learning rate = 0.001).
#
# * Call the training loop - I would suggest a max of ~20 epochs
# * Use matplotlib to plot the train and test loss, and the train and test accuracy
# * Describe what you see in the graphs
#
# This training could take a few minutes. But note how you will see a bunch of losses reported in each epoch? These are the mini-batches in Adam that we discussed before. Then there will be an overall Train and Test error reported for the Epoch.

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
def Train_model(train_loader, test_loader, model):
  # Define the loss function and the Adam optimizer with a learning rate of 0.001
  loss_fn = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
  # Note, replace model with the instance name of your model

  ##############################
  # Your code below
  epochs = 20
  train_loss, train_accuracy, test_loss, test_accuracy = train_loop(train_loader, test_loader, model, loss_fn, optimizer, epochs)
  return train_loss, train_accuracy, test_loss, test_accuracy

# %%
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.291001  [   64/60000]
# loss: 0.672089  [ 6464/60000]
# loss: 0.696997  [12864/60000]
# loss: 0.547627  [19264/60000]
# loss: 0.345325  [25664/60000]
# loss: 0.437882  [32064/60000]
# loss: 0.254674  [38464/60000]
# loss: 0.426839  [44864/60000]
# loss: 0.325143  [51264/60000]
# loss: 0.355509  [57664/60000]
# Train Error:
#  Accuracy: 86.2%, Avg loss: 0.369716
#
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.413567
#
# Epoch 2:
#
# loss: 0.336998  [   64/60000]
# loss: 0.357302  [ 6464/60000]
# loss: 0.290936  [12864/60000]
# loss: 0.370725  [19264/60000]
# loss: 0.337626  [25664/60000]
# loss: 0.513316  [32064/60000]
# loss: 0.353653  [38464/60000]
# loss: 0.389037  [44864/60000]
# loss: 0.306141  [51264/60000]
# loss: 0.386659  [57664/60000]
# Train Error:
#  Accuracy: 88.0%, Avg loss: 0.326024
#
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.379493
#
# Epoch 3:
#
# loss: 0.315334  [   64/60000]
# loss: 0.213182  [ 6464/60000]
# loss: 0.276898  [12864/60000]
# loss: 0.342114  [19264/60000]
# loss: 0.417839  [25664/60000]
# loss: 0.373821  [32064/60000]
# loss: 0.305826  [38464/60000]
# loss: 0.348654  [44864/60000]
# loss: 0.411894  [51264/60000]
# loss: 0.447545  [57664/60000]
# Train Error:
#  Accuracy: 88.8%, Avg loss: 0.304898
#
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.377407
#
# Epoch 4:
#
# loss: 0.333070  [   64/60000]
# loss: 0.190730  [ 6464/60000]
# loss: 0.289003  [12864/60000]
# loss: 0.218101  [19264/60000]
# loss: 0.247382  [25664/60000]
# loss: 0.338498  [32064/60000]
# loss: 0.290484  [38464/60000]
# loss: 0.137796  [44864/60000]
# loss: 0.309263  [51264/60000]
# loss: 0.292361  [57664/60000]
# Train Error:
#  Accuracy: 88.3%, Avg loss: 0.322882
#
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.396598
#
# Epoch 5:
#
# loss: 0.371826  [   64/60000]
# loss: 0.320017  [ 6464/60000]
# loss: 0.345648  [12864/60000]
# loss: 0.273908  [19264/60000]
# loss: 0.341917  [25664/60000]
# loss: 0.319509  [32064/60000]
# loss: 0.230171  [38464/60000]
# loss: 0.400957  [44864/60000]
# loss: 0.212396  [51264/60000]
# loss: 0.180230  [57664/60000]
# Train Error:
#  Accuracy: 90.0%, Avg loss: 0.267328
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.351785
#
# Epoch 6:
#
# loss: 0.389964  [   64/60000]
# loss: 0.210822  [ 6464/60000]
# loss: 0.286590  [12864/60000]
# loss: 0.247962  [19264/60000]
# loss: 0.205896  [25664/60000]
# loss: 0.293072  [32064/60000]
# loss: 0.294668  [38464/60000]
# loss: 0.305256  [44864/60000]
# loss: 0.394766  [51264/60000]
# loss: 0.183189  [57664/60000]
# Train Error:
#  Accuracy: 91.0%, Avg loss: 0.243875
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.337122
#
# Epoch 7:
#
# loss: 0.218517  [   64/60000]
# loss: 0.269757  [ 6464/60000]
# loss: 0.241974  [12864/60000]
# loss: 0.163798  [19264/60000]
# loss: 0.315521  [25664/60000]
# loss: 0.406700  [32064/60000]
# loss: 0.201190  [38464/60000]
# loss: 0.178869  [44864/60000]
# loss: 0.312263  [51264/60000]
# loss: 0.231829  [57664/60000]
# Train Error:
#  Accuracy: 91.3%, Avg loss: 0.234849
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.338873
#
# Epoch 8:
#
# loss: 0.297252  [   64/60000]
# loss: 0.183427  [ 6464/60000]
# loss: 0.352891  [12864/60000]
# loss: 0.278470  [19264/60000]
# loss: 0.358035  [25664/60000]
# loss: 0.205867  [32064/60000]
# loss: 0.154600  [38464/60000]
# loss: 0.205082  [44864/60000]
# loss: 0.251461  [51264/60000]
# loss: 0.339619  [57664/60000]
# Train Error:
#  Accuracy: 91.4%, Avg loss: 0.226212
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.343401
#
# Epoch 9:
#
# loss: 0.230070  [   64/60000]
# loss: 0.282551  [ 6464/60000]
# loss: 0.127375  [12864/60000]
# loss: 0.163471  [19264/60000]
# loss: 0.291118  [25664/60000]
# loss: 0.292336  [32064/60000]
# loss: 0.149999  [38464/60000]
# loss: 0.214659  [44864/60000]
# loss: 0.148351  [51264/60000]
# loss: 0.204846  [57664/60000]
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.211169
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.348874
#
# Epoch 10:
#
# loss: 0.228864  [   64/60000]
# loss: 0.089171  [ 6464/60000]
# loss: 0.167483  [12864/60000]
# loss: 0.126750  [19264/60000]
# loss: 0.182251  [25664/60000]
# loss: 0.135633  [32064/60000]
# loss: 0.205996  [38464/60000]
# loss: 0.151272  [44864/60000]
# loss: 0.157136  [51264/60000]
# loss: 0.223569  [57664/60000]
# Train Error:
#  Accuracy: 92.4%, Avg loss: 0.200695
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.337290
#
# Epoch 11:
#
# loss: 0.267275  [   64/60000]
# loss: 0.335256  [ 6464/60000]
# loss: 0.117705  [12864/60000]
# loss: 0.206687  [19264/60000]
# loss: 0.279962  [25664/60000]
# loss: 0.225881  [32064/60000]
# loss: 0.327669  [38464/60000]
# loss: 0.246622  [44864/60000]
# loss: 0.235542  [51264/60000]
# loss: 0.214105  [57664/60000]
# Train Error:
#  Accuracy: 92.4%, Avg loss: 0.199240
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.349225
#
# Epoch 12:
#
# loss: 0.107956  [   64/60000]
# loss: 0.204828  [ 6464/60000]
# loss: 0.280755  [12864/60000]
# loss: 0.157650  [19264/60000]
# loss: 0.278499  [25664/60000]
# loss: 0.151490  [32064/60000]
# loss: 0.213119  [38464/60000]
# loss: 0.281204  [44864/60000]
# loss: 0.206423  [51264/60000]
# loss: 0.168725  [57664/60000]
# Train Error:
#  Accuracy: 92.4%, Avg loss: 0.198922
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.355118
#
# Epoch 13:
#
# loss: 0.180620  [   64/60000]
# loss: 0.154339  [ 6464/60000]
# loss: 0.323636  [12864/60000]
# loss: 0.299662  [19264/60000]
# loss: 0.257890  [25664/60000]
# loss: 0.320725  [32064/60000]
# loss: 0.127413  [38464/60000]
# loss: 0.190804  [44864/60000]
# loss: 0.197554  [51264/60000]
# loss: 0.258581  [57664/60000]
# Train Error:
#  Accuracy: 93.3%, Avg loss: 0.178474
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.354851
#
# Epoch 14:
#
# loss: 0.163465  [   64/60000]
# loss: 0.152851  [ 6464/60000]
# loss: 0.174867  [12864/60000]
# loss: 0.146241  [19264/60000]
# loss: 0.158423  [25664/60000]
# loss: 0.200836  [32064/60000]
# loss: 0.211736  [38464/60000]
# loss: 0.239093  [44864/60000]
# loss: 0.123102  [51264/60000]
# loss: 0.268280  [57664/60000]
# Train Error:
#  Accuracy: 93.3%, Avg loss: 0.179375
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.349784
#
# Epoch 15:
#
# loss: 0.086805  [   64/60000]
# loss: 0.105881  [ 6464/60000]
# loss: 0.139339  [12864/60000]
# loss: 0.088195  [19264/60000]
# loss: 0.329637  [25664/60000]
# loss: 0.124239  [32064/60000]
# loss: 0.104178  [38464/60000]
# loss: 0.253702  [44864/60000]
# loss: 0.097248  [51264/60000]
# loss: 0.276817  [57664/60000]
# Train Error:
#  Accuracy: 93.3%, Avg loss: 0.181922
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.377451
#
# Epoch 16:
#
# loss: 0.133201  [   64/60000]
# loss: 0.324396  [ 6464/60000]
# loss: 0.077694  [12864/60000]
# loss: 0.099366  [19264/60000]
# loss: 0.262472  [25664/60000]
# loss: 0.110737  [32064/60000]
# loss: 0.286241  [38464/60000]
# loss: 0.095618  [44864/60000]
# loss: 0.125541  [51264/60000]
# loss: 0.086410  [57664/60000]
# Train Error:
#  Accuracy: 94.1%, Avg loss: 0.156388
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.359810
#
# Epoch 17:
#
# loss: 0.125039  [   64/60000]
# loss: 0.191819  [ 6464/60000]
# loss: 0.125700  [12864/60000]
# loss: 0.185272  [19264/60000]
# loss: 0.142488  [25664/60000]
# loss: 0.057061  [32064/60000]
# loss: 0.066706  [38464/60000]
# loss: 0.133994  [44864/60000]
# loss: 0.124016  [51264/60000]
# loss: 0.148106  [57664/60000]
# Train Error:
#  Accuracy: 94.5%, Avg loss: 0.146571
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.379440
#
# Epoch 18:
#
# loss: 0.239553  [   64/60000]
# loss: 0.198143  [ 6464/60000]
# loss: 0.184965  [12864/60000]
# loss: 0.147762  [19264/60000]
# loss: 0.102772  [25664/60000]
# loss: 0.193590  [32064/60000]
# loss: 0.203666  [38464/60000]
# loss: 0.116945  [44864/60000]
# loss: 0.157474  [51264/60000]
# loss: 0.198688  [57664/60000]
# Train Error:
#  Accuracy: 94.4%, Avg loss: 0.148266
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.382927
#
# Epoch 19:
#
# loss: 0.196664  [   64/60000]
# loss: 0.118073  [ 6464/60000]
# loss: 0.082513  [12864/60000]
# loss: 0.081958  [19264/60000]
# loss: 0.125998  [25664/60000]
# loss: 0.081684  [32064/60000]
# loss: 0.172027  [38464/60000]
# loss: 0.134886  [44864/60000]
# loss: 0.194925  [51264/60000]
# loss: 0.064313  [57664/60000]
# Train Error:
#  Accuracy: 94.2%, Avg loss: 0.154076
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.387696
#
# Epoch 20:
#
# loss: 0.193239  [   64/60000]
# loss: 0.095498  [ 6464/60000]
# loss: 0.107402  [12864/60000]
# loss: 0.232373  [19264/60000]
# loss: 0.114454  [25664/60000]
# loss: 0.190554  [32064/60000]
# loss: 0.143472  [38464/60000]
# loss: 0.173948  [44864/60000]
# loss: 0.204195  [51264/60000]
# loss: 0.096541  [57664/60000]
# Train Error:
#  Accuracy: 94.8%, Avg loss: 0.138293
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.390897
#
# Done training!

# %%
# defining function for later use
def plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy) :
  train_loss_percent = [loss * 100 for loss in train_loss]
  test_loss_percent = [loss * 100 for loss in test_loss]
  train_accuracy_percent = [acc * 100 for acc in train_accuracy]
  test_accuracy_percent = [acc * 100 for acc in test_accuracy]

  # Plotting the training and testing loss
  plt.figure(figsize=(10,5))
  plt.subplot(1,2,1)
  plt.title("Training and Testing Loss over Epochs")
  plt.plot(train_loss_percent, label="Train")
  plt.plot(test_loss_percent, label="Test")
  plt.xlabel("Epochs")
  plt.ylabel("Loss(%)")
  plt.legend()
  plt.xticks(range(0, len(train_loss), 2))

  # Plotting the training and testing accuracy
  plt.subplot(1,2,2)
  plt.title("Training and Testing Accuracy over Epochs")
  plt.plot(train_accuracy_percent, label="Train")
  plt.plot(test_accuracy_percent, label="Test")
  plt.grid()
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy(%)")
  plt.legend()
  plt.xticks(range(0, len(train_accuracy), 2))
  plt.tight_layout()
  plt.show()

# %%
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# <span style="color:green"> The graphs show training and test loss over the 20 epochs and the accuracy of test and train. Both the training and test loss decrease for initial few epochs, and then we see a divergence in behaviour of the loss between the test and train. While the train loss does decrease with a slope the test loss seems to stay steady and then rise. This implies there is the model is overfitting the data using the train data.
#
# On the right we see the train and test accuracy plotted. The graph shows a steady rise in accuracy for the initial few epochs, then the train accuracy does increase, however, the rise test accuracy declines. The maximum test accuracy I can observe with the model described above is ##$$ and the train accuracy is ##$$. This wide gap in the test and train accuracy shows overfitting.</span>

# %% [markdown]
# ---
#
# # 2. Replicate LeNet-5 for Fashion-MNIST
#
# ---
#
#
# Below is the LeNet architecture (from https://en.wikipedia.org/wiki/LeNet). If you search on the internet, you will find slightly different implementations and descriptions of LeNet-5, but below is what was actually in LeCun's [original paper](https://ieeexplore.ieee.org/document/726791). Of course, LeCun was applying this to the digit recognition problem (MNIST), but we are looking at Fashion-MNIST.
#
#  * Create the model in PyTorch.
#  * Train the model using the same parameters as above, and plot the loss and accuracy.
#  * Discuss and compare (in a markdown cell) with the fully connected model above. Particularly consider - number of parameters, performance, and overfitting?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
##############################
# Your code below

import torch.nn as nn
import torch.nn.functional as F

# PyTorch models inherit from torch.nn.Module
class LeNet5 (nn.Module):
  def __init__(self):
    super(LeNet5, self).__init__()
    # define first convolution with 6 output and 5 * 5 filters(kernels) and padding = 2
    self.conv1 = nn.Conv2d(1, 6, 5, padding=2)
    # define sigmoid function
    self.sigmoid = nn.Sigmoid()
    # define flatten
    self.flatten = nn.Flatten()
    # using average pooling
    self.pool = nn.AvgPool2d(2, 2)
    # define 2nd convolution with 6 inputs(output from the previous layer) and 5 * 5 kernels
    self.conv2 = nn.Conv2d(6, 16, 5)
    # defining fully connected layer 1
    self.fc1 = nn.Linear(5*5*16, 120)
    # defining fully connected layer 2 taking 120 input(output from the previous) and forming 84 outputs
    self.fc2 = nn.Linear(120, 84)
    # defining fully connected layer 2 taking 84 input(output from the previous) and forming 10 outputs
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    # convolve with 5 x 5 kernel and padding 2
    x = self.conv1(x)
    # apply sigmoid activation function as described in the question
    x = self.sigmoid(x)
    # using average pooling as is used in LeNet5
    x = self.pool(x)

    # 2nd convolution with 5 x 5 kernel
    x = self.conv2(x)
    # apply sigmoid activation function as described in the question
    x = self.sigmoid(x)
    # using average pooling as is used in LeNet5
    x = self.pool(x)

    # flatten before moving it to fully connected layers since they expect a 1D input
    x = self.flatten(x)
    x = self.fc1(x)
    # applying sigmoid activation between fully connected layers
    x = self.sigmoid(x)
    x = self.fc2(x)
    x = self.sigmoid(x)
    x = self.fc3(x)
    return x

model = LeNet5().to(device)
summary(model, (1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#            Sigmoid-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#            Sigmoid-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#            Flatten-7                  [-1, 400]               0
#             Linear-8                  [-1, 120]          48,120
#            Sigmoid-9                  [-1, 120]               0
#            Linear-10                   [-1, 84]          10,164
#           Sigmoid-11                   [-1, 84]               0
#            Linear-12                   [-1, 10]             850
# ================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.24
# Estimated Total Size (MB): 0.35
# ----------------------------------------------------------------

# %%
# calling the train loop
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.368441  [   64/60000]
# loss: 2.027517  [ 6464/60000]
# loss: 1.331257  [12864/60000]
# loss: 1.094237  [19264/60000]
# loss: 1.051244  [25664/60000]
# loss: 0.901633  [32064/60000]
# loss: 0.857429  [38464/60000]
# loss: 0.752379  [44864/60000]
# loss: 0.639829  [51264/60000]
# loss: 0.677236  [57664/60000]
# Train Error:
#  Accuracy: 75.3%, Avg loss: 0.651980
#
# Test Error:
#  Accuracy: 74.8%, Avg loss: 0.667368
#
# Epoch 2:
#
# loss: 0.727837  [   64/60000]
# loss: 0.684932  [ 6464/60000]
# loss: 0.420058  [12864/60000]
# loss: 0.772694  [19264/60000]
# loss: 0.755649  [25664/60000]
# loss: 0.610890  [32064/60000]
# loss: 0.586742  [38464/60000]
# loss: 0.628049  [44864/60000]
# loss: 0.626305  [51264/60000]
# loss: 0.506036  [57664/60000]
# Train Error:
#  Accuracy: 78.2%, Avg loss: 0.543713
#
# Test Error:
#  Accuracy: 77.1%, Avg loss: 0.568459
#
# Epoch 3:
#
# loss: 0.521869  [   64/60000]
# loss: 0.635896  [ 6464/60000]
# loss: 0.535949  [12864/60000]
# loss: 0.462380  [19264/60000]
# loss: 0.546686  [25664/60000]
# loss: 0.502058  [32064/60000]
# loss: 0.458224  [38464/60000]
# loss: 0.411849  [44864/60000]
# loss: 0.657749  [51264/60000]
# loss: 0.366194  [57664/60000]
# Train Error:
#  Accuracy: 82.1%, Avg loss: 0.483545
#
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.510423
#
# Epoch 4:
#
# loss: 0.462143  [   64/60000]
# loss: 0.453628  [ 6464/60000]
# loss: 0.363080  [12864/60000]
# loss: 0.371615  [19264/60000]
# loss: 0.334972  [25664/60000]
# loss: 0.552302  [32064/60000]
# loss: 0.309592  [38464/60000]
# loss: 0.361072  [44864/60000]
# loss: 0.423870  [51264/60000]
# loss: 0.513936  [57664/60000]
# Train Error:
#  Accuracy: 83.7%, Avg loss: 0.444150
#
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.474537
#
# Epoch 5:
#
# loss: 0.433590  [   64/60000]
# loss: 0.644208  [ 6464/60000]
# loss: 0.391304  [12864/60000]
# loss: 0.513005  [19264/60000]
# loss: 0.363156  [25664/60000]
# loss: 0.391093  [32064/60000]
# loss: 0.475859  [38464/60000]
# loss: 0.577316  [44864/60000]
# loss: 0.333065  [51264/60000]
# loss: 0.415353  [57664/60000]
# Train Error:
#  Accuracy: 84.7%, Avg loss: 0.412780
#
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.445826
#
# Epoch 6:
#
# loss: 0.375926  [   64/60000]
# loss: 0.480828  [ 6464/60000]
# loss: 0.632314  [12864/60000]
# loss: 0.451627  [19264/60000]
# loss: 0.332537  [25664/60000]
# loss: 0.373617  [32064/60000]
# loss: 0.416399  [38464/60000]
# loss: 0.390667  [44864/60000]
# loss: 0.205535  [51264/60000]
# loss: 0.349832  [57664/60000]
# Train Error:
#  Accuracy: 85.8%, Avg loss: 0.389095
#
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.420923
#
# Epoch 7:
#
# loss: 0.337601  [   64/60000]
# loss: 0.365085  [ 6464/60000]
# loss: 0.386899  [12864/60000]
# loss: 0.369470  [19264/60000]
# loss: 0.260278  [25664/60000]
# loss: 0.444631  [32064/60000]
# loss: 0.451314  [38464/60000]
# loss: 0.526460  [44864/60000]
# loss: 0.284394  [51264/60000]
# loss: 0.384881  [57664/60000]
# Train Error:
#  Accuracy: 86.6%, Avg loss: 0.366815
#
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.398925
#
# Epoch 8:
#
# loss: 0.248370  [   64/60000]
# loss: 0.326854  [ 6464/60000]
# loss: 0.527394  [12864/60000]
# loss: 0.304232  [19264/60000]
# loss: 0.360329  [25664/60000]
# loss: 0.206707  [32064/60000]
# loss: 0.546262  [38464/60000]
# loss: 0.325578  [44864/60000]
# loss: 0.322217  [51264/60000]
# loss: 0.361437  [57664/60000]
# Train Error:
#  Accuracy: 86.0%, Avg loss: 0.375439
#
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.413547
#
# Epoch 9:
#
# loss: 0.274096  [   64/60000]
# loss: 0.476685  [ 6464/60000]
# loss: 0.253267  [12864/60000]
# loss: 0.389010  [19264/60000]
# loss: 0.314483  [25664/60000]
# loss: 0.311238  [32064/60000]
# loss: 0.403967  [38464/60000]
# loss: 0.428048  [44864/60000]
# loss: 0.435840  [51264/60000]
# loss: 0.500050  [57664/60000]
# Train Error:
#  Accuracy: 87.4%, Avg loss: 0.340700
#
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.373454
#
# Epoch 10:
#
# loss: 0.183928  [   64/60000]
# loss: 0.313898  [ 6464/60000]
# loss: 0.186756  [12864/60000]
# loss: 0.473922  [19264/60000]
# loss: 0.301834  [25664/60000]
# loss: 0.231103  [32064/60000]
# loss: 0.194201  [38464/60000]
# loss: 0.361173  [44864/60000]
# loss: 0.334882  [51264/60000]
# loss: 0.345646  [57664/60000]
# Train Error:
#  Accuracy: 87.8%, Avg loss: 0.330021
#
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.365981
#
# Epoch 11:
#
# loss: 0.420711  [   64/60000]
# loss: 0.336360  [ 6464/60000]
# loss: 0.436172  [12864/60000]
# loss: 0.472671  [19264/60000]
# loss: 0.366403  [25664/60000]
# loss: 0.217700  [32064/60000]
# loss: 0.224962  [38464/60000]
# loss: 0.328144  [44864/60000]
# loss: 0.354961  [51264/60000]
# loss: 0.240801  [57664/60000]
# Train Error:
#  Accuracy: 87.9%, Avg loss: 0.327399
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.369093
#
# Epoch 12:
#
# loss: 0.327593  [   64/60000]
# loss: 0.306032  [ 6464/60000]
# loss: 0.215448  [12864/60000]
# loss: 0.472272  [19264/60000]
# loss: 0.315344  [25664/60000]
# loss: 0.317067  [32064/60000]
# loss: 0.416480  [38464/60000]
# loss: 0.388023  [44864/60000]
# loss: 0.286648  [51264/60000]
# loss: 0.300595  [57664/60000]
# Train Error:
#  Accuracy: 88.8%, Avg loss: 0.308252
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.345601
#
# Epoch 13:
#
# loss: 0.302428  [   64/60000]
# loss: 0.352327  [ 6464/60000]
# loss: 0.185077  [12864/60000]
# loss: 0.414673  [19264/60000]
# loss: 0.312746  [25664/60000]
# loss: 0.212101  [32064/60000]
# loss: 0.311048  [38464/60000]
# loss: 0.294958  [44864/60000]
# loss: 0.217210  [51264/60000]
# loss: 0.313724  [57664/60000]
# Train Error:
#  Accuracy: 88.8%, Avg loss: 0.301296
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.340980
#
# Epoch 14:
#
# loss: 0.394280  [   64/60000]
# loss: 0.280673  [ 6464/60000]
# loss: 0.441677  [12864/60000]
# loss: 0.280154  [19264/60000]
# loss: 0.274275  [25664/60000]
# loss: 0.621074  [32064/60000]
# loss: 0.210358  [38464/60000]
# loss: 0.340154  [44864/60000]
# loss: 0.351112  [51264/60000]
# loss: 0.351922  [57664/60000]
# Train Error:
#  Accuracy: 88.9%, Avg loss: 0.298526
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.338804
#
# Epoch 15:
#
# loss: 0.312463  [   64/60000]
# loss: 0.306958  [ 6464/60000]
# loss: 0.433504  [12864/60000]
# loss: 0.374685  [19264/60000]
# loss: 0.427527  [25664/60000]
# loss: 0.314508  [32064/60000]
# loss: 0.134027  [38464/60000]
# loss: 0.277218  [44864/60000]
# loss: 0.273574  [51264/60000]
# loss: 0.357419  [57664/60000]
# Train Error:
#  Accuracy: 88.6%, Avg loss: 0.299984
#
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.344283
#
# Epoch 16:
#
# loss: 0.204588  [   64/60000]
# loss: 0.250871  [ 6464/60000]
# loss: 0.395457  [12864/60000]
# loss: 0.436577  [19264/60000]
# loss: 0.286954  [25664/60000]
# loss: 0.221234  [32064/60000]
# loss: 0.303038  [38464/60000]
# loss: 0.417525  [44864/60000]
# loss: 0.353710  [51264/60000]
# loss: 0.305087  [57664/60000]
# Train Error:
#  Accuracy: 89.7%, Avg loss: 0.279617
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.324657
#
# Epoch 17:
#
# loss: 0.284190  [   64/60000]
# loss: 0.191348  [ 6464/60000]
# loss: 0.309934  [12864/60000]
# loss: 0.262421  [19264/60000]
# loss: 0.416559  [25664/60000]
# loss: 0.353246  [32064/60000]
# loss: 0.233380  [38464/60000]
# loss: 0.237994  [44864/60000]
# loss: 0.443139  [51264/60000]
# loss: 0.247614  [57664/60000]
# Train Error:
#  Accuracy: 88.9%, Avg loss: 0.293875
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.342401
#
# Epoch 18:
#
# loss: 0.150934  [   64/60000]
# loss: 0.227621  [ 6464/60000]
# loss: 0.397563  [12864/60000]
# loss: 0.235382  [19264/60000]
# loss: 0.297613  [25664/60000]
# loss: 0.208574  [32064/60000]
# loss: 0.225821  [38464/60000]
# loss: 0.396440  [44864/60000]
# loss: 0.505151  [51264/60000]
# loss: 0.236641  [57664/60000]
# Train Error:
#  Accuracy: 89.8%, Avg loss: 0.276821
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.325184
#
# Epoch 19:
#
# loss: 0.143639  [   64/60000]
# loss: 0.249932  [ 6464/60000]
# loss: 0.265900  [12864/60000]
# loss: 0.461975  [19264/60000]
# loss: 0.339087  [25664/60000]
# loss: 0.182067  [32064/60000]
# loss: 0.313748  [38464/60000]
# loss: 0.250193  [44864/60000]
# loss: 0.200469  [51264/60000]
# loss: 0.204473  [57664/60000]
# Train Error:
#  Accuracy: 90.2%, Avg loss: 0.264670
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.312553
#
# Epoch 20:
#
# loss: 0.411130  [   64/60000]
# loss: 0.231259  [ 6464/60000]
# loss: 0.142999  [12864/60000]
# loss: 0.268640  [19264/60000]
# loss: 0.347973  [25664/60000]
# loss: 0.260236  [32064/60000]
# loss: 0.147264  [38464/60000]
# loss: 0.217283  [44864/60000]
# loss: 0.279024  [51264/60000]
# loss: 0.247634  [57664/60000]
# Train Error:
#  Accuracy: 90.1%, Avg loss: 0.267462
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.316381
#
# Done training!

# %%
# plotting the graph showing the Train and Test loss and accuracy
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# <span style="color:green"> Here we find the graph of training and testing loss behaving similarly as the both are continuing their descent as the epochs progress. And due to this we get a better model without overfitting. However the accuracy doesnt seem to be as good as the previous graphs. As shown on the plot of Train and Test accuracy, both continue their rise as the epochs progress and we can see the max test accuracy at ##$$ and the max train accuracy at ##$$.
#
# This is due to the fact that the number of parameters(61706) trained here is considerably less than the previous case(94160). Also we have used Sigmoid as the activation function here and in the previous I had used a ReLU, which seems to be working really well for this problem. This indicates the importance of using a better activation function. While in the previous example I used a better activation function I did not do any convolution of pooling, here I did do a couple of convolution and an average pooling after each. This could also have led to the difference in the overfitting value. </span>

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# ### <font color='red'>Your text here.</font>
# <font color='red'>Enter your text descriptions in the cell below:</font>

# %% [markdown]
# ---
# # 3. Modernise LeNet
# ---
#
#
# Modernise LeNet. What are the preferred activation and pooling functions for modern CNNs?
#
# * Update LeNet with these newer functions.
# * Train using the same parameters as above.
# * Compare and discuss with the above using the normal discussion criteria

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>
#
# <font color='green'>An alternate way to implement LeNet5 using nn.Sequential and ReLU and Max Pooling which improves the accuracy</font>

# %%
##############################
# Your code below

import torch.nn as nn
import torch.nn.functional as F

# PyTorch models inherit from torch.nn.Module
class LeNet5_Morderized(nn.Module):
  def __init__(self):
    super(LeNet5_Morderized, self).__init__()
    self.flatten = nn.Flatten()
    '''implementing max pooling and using ReLU activation function
       resulted in greater test and train accuracy(based on trials).'''
    # applying the convolution and ReLU and MaxPooling in sequence for conv1 and conv2
    self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels=1,
                out_channels=6,
                kernel_size=5,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )
    self.conv2 = nn.Sequential(
            nn.Conv2d(6, 16, 5),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
    self.fc1 = nn.Linear(5*5*16, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    # applying the conv1
    x = self.conv1(x)
    # applying conv2 on the result of conv1
    x = self.conv2(x)
    # flatten the output of conv2 to (batch_size, 5*5*16)
    x = self.flatten(x)
    x = self.fc1(x)
    x = self.fc2(x)
    x = self.fc3(x)
    return x

model = LeNet5_Morderized().to(device)
summary(model, (1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               ReLU-2            [-1, 6, 28, 28]               0
#          MaxPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               ReLU-5           [-1, 16, 10, 10]               0
#          MaxPool2d-6             [-1, 16, 5, 5]               0
#            Flatten-7                  [-1, 400]               0
#             Linear-8                  [-1, 120]          48,120
#             Linear-9                   [-1, 84]          10,164
#            Linear-10                   [-1, 10]             850
# ================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.24
# Estimated Total Size (MB): 0.35
# ----------------------------------------------------------------

# %%
# calling the train loop
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.306962  [   64/60000]
# loss: 0.667313  [ 6464/60000]
# loss: 0.671691  [12864/60000]
# loss: 0.363637  [19264/60000]
# loss: 0.587362  [25664/60000]
# loss: 0.358054  [32064/60000]
# loss: 0.471576  [38464/60000]
# loss: 0.344313  [44864/60000]
# loss: 0.331288  [51264/60000]
# loss: 0.304807  [57664/60000]
# Train Error:
#  Accuracy: 86.9%, Avg loss: 0.367128
#
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.395506
#
# Epoch 2:
#
# loss: 0.469939  [   64/60000]
# loss: 0.484572  [ 6464/60000]
# loss: 0.534501  [12864/60000]
# loss: 0.304422  [19264/60000]
# loss: 0.437553  [25664/60000]
# loss: 0.285123  [32064/60000]
# loss: 0.467407  [38464/60000]
# loss: 0.366745  [44864/60000]
# loss: 0.427198  [51264/60000]
# loss: 0.334981  [57664/60000]
# Train Error:
#  Accuracy: 89.3%, Avg loss: 0.299691
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.334035
#
# Epoch 3:
#
# loss: 0.325149  [   64/60000]
# loss: 0.173918  [ 6464/60000]
# loss: 0.336748  [12864/60000]
# loss: 0.270360  [19264/60000]
# loss: 0.201773  [25664/60000]
# loss: 0.265856  [32064/60000]
# loss: 0.240710  [38464/60000]
# loss: 0.417604  [44864/60000]
# loss: 0.226944  [51264/60000]
# loss: 0.205019  [57664/60000]
# Train Error:
#  Accuracy: 89.7%, Avg loss: 0.288247
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.323184
#
# Epoch 4:
#
# loss: 0.271910  [   64/60000]
# loss: 0.305298  [ 6464/60000]
# loss: 0.117258  [12864/60000]
# loss: 0.238080  [19264/60000]
# loss: 0.256268  [25664/60000]
# loss: 0.148682  [32064/60000]
# loss: 0.391087  [38464/60000]
# loss: 0.314198  [44864/60000]
# loss: 0.191006  [51264/60000]
# loss: 0.255122  [57664/60000]
# Train Error:
#  Accuracy: 90.1%, Avg loss: 0.277195
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.327082
#
# Epoch 5:
#
# loss: 0.211469  [   64/60000]
# loss: 0.317659  [ 6464/60000]
# loss: 0.205490  [12864/60000]
# loss: 0.203715  [19264/60000]
# loss: 0.430541  [25664/60000]
# loss: 0.450018  [32064/60000]
# loss: 0.345502  [38464/60000]
# loss: 0.275702  [44864/60000]
# loss: 0.390282  [51264/60000]
# loss: 0.249639  [57664/60000]
# Train Error:
#  Accuracy: 91.0%, Avg loss: 0.249628
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.300142
#
# Epoch 6:
#
# loss: 0.232333  [   64/60000]
# loss: 0.304989  [ 6464/60000]
# loss: 0.231006  [12864/60000]
# loss: 0.226027  [19264/60000]
# loss: 0.194085  [25664/60000]
# loss: 0.235077  [32064/60000]
# loss: 0.258413  [38464/60000]
# loss: 0.286625  [44864/60000]
# loss: 0.249089  [51264/60000]
# loss: 0.329979  [57664/60000]
# Train Error:
#  Accuracy: 90.9%, Avg loss: 0.250419
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.308239
#
# Epoch 7:
#
# loss: 0.121846  [   64/60000]
# loss: 0.300782  [ 6464/60000]
# loss: 0.584462  [12864/60000]
# loss: 0.424051  [19264/60000]
# loss: 0.241319  [25664/60000]
# loss: 0.253815  [32064/60000]
# loss: 0.236025  [38464/60000]
# loss: 0.219426  [44864/60000]
# loss: 0.200088  [51264/60000]
# loss: 0.197624  [57664/60000]
# Train Error:
#  Accuracy: 91.3%, Avg loss: 0.238295
#
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.301732
#
# Epoch 8:
#
# loss: 0.286832  [   64/60000]
# loss: 0.146315  [ 6464/60000]
# loss: 0.265700  [12864/60000]
# loss: 0.299434  [19264/60000]
# loss: 0.225211  [25664/60000]
# loss: 0.314122  [32064/60000]
# loss: 0.273379  [38464/60000]
# loss: 0.211668  [44864/60000]
# loss: 0.353493  [51264/60000]
# loss: 0.210934  [57664/60000]
# Train Error:
#  Accuracy: 91.0%, Avg loss: 0.243070
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.306858
#
# Epoch 9:
#
# loss: 0.231353  [   64/60000]
# loss: 0.230395  [ 6464/60000]
# loss: 0.298723  [12864/60000]
# loss: 0.152142  [19264/60000]
# loss: 0.177173  [25664/60000]
# loss: 0.420631  [32064/60000]
# loss: 0.151049  [38464/60000]
# loss: 0.192828  [44864/60000]
# loss: 0.121906  [51264/60000]
# loss: 0.168926  [57664/60000]
# Train Error:
#  Accuracy: 91.7%, Avg loss: 0.229776
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.299817
#
# Epoch 10:
#
# loss: 0.251384  [   64/60000]
# loss: 0.309377  [ 6464/60000]
# loss: 0.253717  [12864/60000]
# loss: 0.111583  [19264/60000]
# loss: 0.216753  [25664/60000]
# loss: 0.243048  [32064/60000]
# loss: 0.300266  [38464/60000]
# loss: 0.086390  [44864/60000]
# loss: 0.321797  [51264/60000]
# loss: 0.233950  [57664/60000]
# Train Error:
#  Accuracy: 91.9%, Avg loss: 0.227544
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.300586
#
# Epoch 11:
#
# loss: 0.278240  [   64/60000]
# loss: 0.104124  [ 6464/60000]
# loss: 0.266536  [12864/60000]
# loss: 0.240851  [19264/60000]
# loss: 0.181558  [25664/60000]
# loss: 0.146364  [32064/60000]
# loss: 0.147016  [38464/60000]
# loss: 0.083081  [44864/60000]
# loss: 0.210393  [51264/60000]
# loss: 0.281636  [57664/60000]
# Train Error:
#  Accuracy: 91.5%, Avg loss: 0.231327
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.301867
#
# Epoch 12:
#
# loss: 0.222732  [   64/60000]
# loss: 0.129829  [ 6464/60000]
# loss: 0.074512  [12864/60000]
# loss: 0.243980  [19264/60000]
# loss: 0.122551  [25664/60000]
# loss: 0.300656  [32064/60000]
# loss: 0.327205  [38464/60000]
# loss: 0.341413  [44864/60000]
# loss: 0.220884  [51264/60000]
# loss: 0.286063  [57664/60000]
# Train Error:
#  Accuracy: 92.0%, Avg loss: 0.221141
#
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.306613
#
# Epoch 13:
#
# loss: 0.162538  [   64/60000]
# loss: 0.156160  [ 6464/60000]
# loss: 0.262212  [12864/60000]
# loss: 0.206000  [19264/60000]
# loss: 0.137647  [25664/60000]
# loss: 0.264895  [32064/60000]
# loss: 0.236325  [38464/60000]
# loss: 0.223492  [44864/60000]
# loss: 0.358715  [51264/60000]
# loss: 0.206390  [57664/60000]
# Train Error:
#  Accuracy: 91.6%, Avg loss: 0.230868
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.316681
#
# Epoch 14:
#
# loss: 0.208688  [   64/60000]
# loss: 0.245157  [ 6464/60000]
# loss: 0.118993  [12864/60000]
# loss: 0.111141  [19264/60000]
# loss: 0.194200  [25664/60000]
# loss: 0.259992  [32064/60000]
# loss: 0.165208  [38464/60000]
# loss: 0.249402  [44864/60000]
# loss: 0.335386  [51264/60000]
# loss: 0.374572  [57664/60000]
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.213872
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.299052
#
# Epoch 15:
#
# loss: 0.084734  [   64/60000]
# loss: 0.263726  [ 6464/60000]
# loss: 0.220596  [12864/60000]
# loss: 0.290061  [19264/60000]
# loss: 0.195968  [25664/60000]
# loss: 0.284063  [32064/60000]
# loss: 0.184977  [38464/60000]
# loss: 0.174572  [44864/60000]
# loss: 0.153107  [51264/60000]
# loss: 0.197612  [57664/60000]
# Train Error:
#  Accuracy: 91.9%, Avg loss: 0.217100
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.305340
#
# Epoch 16:
#
# loss: 0.322069  [   64/60000]
# loss: 0.279962  [ 6464/60000]
# loss: 0.217445  [12864/60000]
# loss: 0.196076  [19264/60000]
# loss: 0.220319  [25664/60000]
# loss: 0.135773  [32064/60000]
# loss: 0.255424  [38464/60000]
# loss: 0.413511  [44864/60000]
# loss: 0.243569  [51264/60000]
# loss: 0.236159  [57664/60000]
# Train Error:
#  Accuracy: 92.5%, Avg loss: 0.203756
#
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.292285
#
# Epoch 17:
#
# loss: 0.234321  [   64/60000]
# loss: 0.207964  [ 6464/60000]
# loss: 0.290256  [12864/60000]
# loss: 0.310244  [19264/60000]
# loss: 0.222644  [25664/60000]
# loss: 0.505135  [32064/60000]
# loss: 0.169041  [38464/60000]
# loss: 0.132076  [44864/60000]
# loss: 0.193193  [51264/60000]
# loss: 0.100063  [57664/60000]
# Train Error:
#  Accuracy: 92.6%, Avg loss: 0.204505
#
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.297397
#
# Epoch 18:
#
# loss: 0.193717  [   64/60000]
# loss: 0.276666  [ 6464/60000]
# loss: 0.198654  [12864/60000]
# loss: 0.293548  [19264/60000]
# loss: 0.216913  [25664/60000]
# loss: 0.310745  [32064/60000]
# loss: 0.121856  [38464/60000]
# loss: 0.198880  [44864/60000]
# loss: 0.270916  [51264/60000]
# loss: 0.075745  [57664/60000]
# Train Error:
#  Accuracy: 92.6%, Avg loss: 0.202509
#
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.289755
#
# Epoch 19:
#
# loss: 0.264447  [   64/60000]
# loss: 0.235572  [ 6464/60000]
# loss: 0.118388  [12864/60000]
# loss: 0.157229  [19264/60000]
# loss: 0.191133  [25664/60000]
# loss: 0.245645  [32064/60000]
# loss: 0.151289  [38464/60000]
# loss: 0.182951  [44864/60000]
# loss: 0.390008  [51264/60000]
# loss: 0.250988  [57664/60000]
# Train Error:
#  Accuracy: 92.7%, Avg loss: 0.200648
#
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.298847
#
# Epoch 20:
#
# loss: 0.235663  [   64/60000]
# loss: 0.079124  [ 6464/60000]
# loss: 0.255097  [12864/60000]
# loss: 0.210883  [19264/60000]
# loss: 0.206250  [25664/60000]
# loss: 0.261847  [32064/60000]
# loss: 0.250386  [38464/60000]
# loss: 0.127727  [44864/60000]
# loss: 0.174779  [51264/60000]
# loss: 0.262672  [57664/60000]
# Train Error:
#  Accuracy: 92.8%, Avg loss: 0.198650
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.299668
#
# Done training!

# %%
# plotting the train and test loss and accuracy
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# <span style="color:green"> The training and test loss has had a considerable decrease in the first couple of epochs itself, compared to the previous where it took almost half the epoch size specified to reach the loss we obtained here. Here we see parameters used for training

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# ### <font color='red'>Your text here.</font>
# <font color='red'>Enter your text descriptions in the cell below:</font>

# %% [markdown]
# ---
# # 4. Build your own CNN model
# ---
#
# Build your own classifier model - see can you break 90% accuracy. You can use LeNet as a basis if you like.
#
# With some networks I built, I could get 93 to 94% test accuracy.
#
# Some hints:
#  * not every convolutional layer needs a pooling layer afterwards
#  * Consider adding more layers (maybe more 3x3 layers is better than 1 5x5 layer?)
#  * But don't just bung loads of layers in there - you will end up overfitting badly
#  * Use a [batchnorm](https://towardsdatascience.com/batch-norm-explained-visually-how-it-works-and-why-neural-networks-need-it-b18919692739) after each convolutional layer. You get decent performance gains without adding many parameters
#  * Don't be afraid to get to a million or two parameters
#  * Have a look on Google to see what others are doing (you're going to do this anyway, right?). Don't just copy them, though, try to understand.
#
# Explain what you did that improved things for the classification and why they improved things.

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
##############################
# Your code below

import torch.nn as nn
import torch.nn.functional as F

# PyTorch models inherit from torch.nn.Module
class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.conv1 = nn.Conv2d(1, 16, 5, padding=2)

    self.pool = nn.MaxPool2d(2, 2)

    self.conv2 = nn.Conv2d(16, 32, 5, padding = 2)

    self.fc1 = nn.Linear(32*7*7, 10)



  def forward(self, x):
    x = self.pool(F.relu(self.conv1(x)))
    x = self.pool(F.relu(self.conv2(x)))

    x = x.view(-1, 32*7*7)
    x = self.fc1(x)
    return x

model = CNN().to(device)
summary(model, (1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 28, 28]             416
#          MaxPool2d-2           [-1, 16, 14, 14]               0
#             Conv2d-3           [-1, 32, 14, 14]          12,832
#          MaxPool2d-4             [-1, 32, 7, 7]               0
#             Linear-5                   [-1, 10]          15,690
# ================================================================
# Total params: 28,938
# Trainable params: 28,938
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.18
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.29
# ----------------------------------------------------------------

# %%
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.295801  [   64/60000]
# loss: 0.368262  [ 6464/60000]
# loss: 0.388612  [12864/60000]
# loss: 0.368677  [19264/60000]
# loss: 0.230111  [25664/60000]
# loss: 0.475698  [32064/60000]
# loss: 0.233200  [38464/60000]
# loss: 0.448309  [44864/60000]
# loss: 0.325288  [51264/60000]
# loss: 0.212301  [57664/60000]
# Train Error:
#  Accuracy: 88.6%, Avg loss: 0.317484
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.346785
#
# Epoch 2:
#
# loss: 0.298074  [   64/60000]
# loss: 0.219756  [ 6464/60000]
# loss: 0.165010  [12864/60000]
# loss: 0.356153  [19264/60000]
# loss: 0.224000  [25664/60000]
# loss: 0.313871  [32064/60000]
# loss: 0.290619  [38464/60000]
# loss: 0.295766  [44864/60000]
# loss: 0.150655  [51264/60000]
# loss: 0.218216  [57664/60000]
# Train Error:
#  Accuracy: 90.6%, Avg loss: 0.259540
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.298553
#
# Epoch 3:
#
# loss: 0.280407  [   64/60000]
# loss: 0.258500  [ 6464/60000]
# loss: 0.202779  [12864/60000]
# loss: 0.363305  [19264/60000]
# loss: 0.418524  [25664/60000]
# loss: 0.300893  [32064/60000]
# loss: 0.209363  [38464/60000]
# loss: 0.291719  [44864/60000]
# loss: 0.266436  [51264/60000]
# loss: 0.261635  [57664/60000]
# Train Error:
#  Accuracy: 91.2%, Avg loss: 0.242515
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.299274
#
# Epoch 4:
#
# loss: 0.175501  [   64/60000]
# loss: 0.199927  [ 6464/60000]
# loss: 0.205130  [12864/60000]
# loss: 0.234338  [19264/60000]
# loss: 0.200834  [25664/60000]
# loss: 0.253410  [32064/60000]
# loss: 0.156570  [38464/60000]
# loss: 0.241172  [44864/60000]
# loss: 0.147817  [51264/60000]
# loss: 0.282063  [57664/60000]
# Train Error:
#  Accuracy: 92.3%, Avg loss: 0.213433
#
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.275080
#
# Epoch 5:
#
# loss: 0.235188  [   64/60000]
# loss: 0.130905  [ 6464/60000]
# loss: 0.139749  [12864/60000]
# loss: 0.200116  [19264/60000]
# loss: 0.264114  [25664/60000]
# loss: 0.426992  [32064/60000]
# loss: 0.149137  [38464/60000]
# loss: 0.142555  [44864/60000]
# loss: 0.261786  [51264/60000]
# loss: 0.181197  [57664/60000]
# Train Error:
#  Accuracy: 93.0%, Avg loss: 0.190555
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.263368
#
# Epoch 6:
#
# loss: 0.252692  [   64/60000]
# loss: 0.180524  [ 6464/60000]
# loss: 0.259316  [12864/60000]
# loss: 0.102292  [19264/60000]
# loss: 0.202938  [25664/60000]
# loss: 0.201579  [32064/60000]
# loss: 0.121425  [38464/60000]
# loss: 0.255810  [44864/60000]
# loss: 0.107884  [51264/60000]
# loss: 0.257252  [57664/60000]
# Train Error:
#  Accuracy: 93.2%, Avg loss: 0.187853
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.271859
#
# Epoch 7:
#
# loss: 0.187471  [   64/60000]
# loss: 0.254620  [ 6464/60000]
# loss: 0.197272  [12864/60000]
# loss: 0.229587  [19264/60000]
# loss: 0.201695  [25664/60000]
# loss: 0.107189  [32064/60000]
# loss: 0.160033  [38464/60000]
# loss: 0.112514  [44864/60000]
# loss: 0.204696  [51264/60000]
# loss: 0.194293  [57664/60000]
# Train Error:
#  Accuracy: 94.6%, Avg loss: 0.151367
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.247304
#
# Epoch 8:
#
# loss: 0.125183  [   64/60000]
# loss: 0.226294  [ 6464/60000]
# loss: 0.157618  [12864/60000]
# loss: 0.178833  [19264/60000]
# loss: 0.225603  [25664/60000]
# loss: 0.095734  [32064/60000]
# loss: 0.194292  [38464/60000]
# loss: 0.137925  [44864/60000]
# loss: 0.083658  [51264/60000]
# loss: 0.263773  [57664/60000]
# Train Error:
#  Accuracy: 94.2%, Avg loss: 0.161575
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.263747
#
# Epoch 9:
#
# loss: 0.144380  [   64/60000]
# loss: 0.122792  [ 6464/60000]
# loss: 0.128089  [12864/60000]
# loss: 0.174070  [19264/60000]
# loss: 0.132801  [25664/60000]
# loss: 0.275476  [32064/60000]
# loss: 0.117671  [38464/60000]
# loss: 0.054696  [44864/60000]
# loss: 0.133864  [51264/60000]
# loss: 0.218099  [57664/60000]
# Train Error:
#  Accuracy: 94.4%, Avg loss: 0.154944
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.273712
#
# Epoch 10:
#
# loss: 0.280850  [   64/60000]
# loss: 0.156831  [ 6464/60000]
# loss: 0.073999  [12864/60000]
# loss: 0.120937  [19264/60000]
# loss: 0.133566  [25664/60000]
# loss: 0.101989  [32064/60000]
# loss: 0.206793  [38464/60000]
# loss: 0.125420  [44864/60000]
# loss: 0.148938  [51264/60000]
# loss: 0.155883  [57664/60000]
# Train Error:
#  Accuracy: 95.1%, Avg loss: 0.134589
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.265439
#
# Epoch 11:
#
# loss: 0.155424  [   64/60000]
# loss: 0.122216  [ 6464/60000]
# loss: 0.131019  [12864/60000]
# loss: 0.108982  [19264/60000]
# loss: 0.091130  [25664/60000]
# loss: 0.121211  [32064/60000]
# loss: 0.171783  [38464/60000]
# loss: 0.134269  [44864/60000]
# loss: 0.099780  [51264/60000]
# loss: 0.152564  [57664/60000]
# Train Error:
#  Accuracy: 95.6%, Avg loss: 0.121742
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.258716
#
# Epoch 12:
#
# loss: 0.211293  [   64/60000]
# loss: 0.243438  [ 6464/60000]
# loss: 0.095859  [12864/60000]
# loss: 0.306702  [19264/60000]
# loss: 0.120835  [25664/60000]
# loss: 0.118062  [32064/60000]
# loss: 0.133063  [38464/60000]
# loss: 0.074956  [44864/60000]
# loss: 0.108197  [51264/60000]
# loss: 0.040860  [57664/60000]
# Train Error:
#  Accuracy: 95.9%, Avg loss: 0.115487
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.271571
#
# Epoch 13:
#
# loss: 0.122042  [   64/60000]
# loss: 0.199406  [ 6464/60000]
# loss: 0.067217  [12864/60000]
# loss: 0.077762  [19264/60000]
# loss: 0.222596  [25664/60000]
# loss: 0.162058  [32064/60000]
# loss: 0.114471  [38464/60000]
# loss: 0.111037  [44864/60000]
# loss: 0.238807  [51264/60000]
# loss: 0.150437  [57664/60000]
# Train Error:
#  Accuracy: 95.9%, Avg loss: 0.110591
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.283988
#
# Epoch 14:
#
# loss: 0.274628  [   64/60000]
# loss: 0.134499  [ 6464/60000]
# loss: 0.119235  [12864/60000]
# loss: 0.099336  [19264/60000]
# loss: 0.092245  [25664/60000]
# loss: 0.039950  [32064/60000]
# loss: 0.107893  [38464/60000]
# loss: 0.067746  [44864/60000]
# loss: 0.274724  [51264/60000]
# loss: 0.076670  [57664/60000]
# Train Error:
#  Accuracy: 96.5%, Avg loss: 0.101255
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.279931
#
# Epoch 15:
#
# loss: 0.049602  [   64/60000]
# loss: 0.104734  [ 6464/60000]
# loss: 0.141377  [12864/60000]
# loss: 0.096741  [19264/60000]
# loss: 0.161363  [25664/60000]
# loss: 0.121911  [32064/60000]
# loss: 0.348925  [38464/60000]
# loss: 0.105460  [44864/60000]
# loss: 0.092016  [51264/60000]
# loss: 0.143063  [57664/60000]
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.089382
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.283500
#
# Epoch 16:
#
# loss: 0.110769  [   64/60000]
# loss: 0.083887  [ 6464/60000]
# loss: 0.058723  [12864/60000]
# loss: 0.064058  [19264/60000]
# loss: 0.106251  [25664/60000]
# loss: 0.055161  [32064/60000]
# loss: 0.158116  [38464/60000]
# loss: 0.216098  [44864/60000]
# loss: 0.088383  [51264/60000]
# loss: 0.050347  [57664/60000]
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.093052
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.297609
#
# Epoch 17:
#
# loss: 0.041056  [   64/60000]
# loss: 0.131185  [ 6464/60000]
# loss: 0.104777  [12864/60000]
# loss: 0.087182  [19264/60000]
# loss: 0.052949  [25664/60000]
# loss: 0.039050  [32064/60000]
# loss: 0.078607  [38464/60000]
# loss: 0.080072  [44864/60000]
# loss: 0.175401  [51264/60000]
# loss: 0.078794  [57664/60000]
# Train Error:
#  Accuracy: 96.7%, Avg loss: 0.089853
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.303088
#
# Epoch 18:
#
# loss: 0.106329  [   64/60000]
# loss: 0.244851  [ 6464/60000]
# loss: 0.038770  [12864/60000]
# loss: 0.123794  [19264/60000]
# loss: 0.048247  [25664/60000]
# loss: 0.025779  [32064/60000]
# loss: 0.151337  [38464/60000]
# loss: 0.061155  [44864/60000]
# loss: 0.120339  [51264/60000]
# loss: 0.158703  [57664/60000]
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.085264
#
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.309823
#
# Epoch 19:
#
# loss: 0.092620  [   64/60000]
# loss: 0.088814  [ 6464/60000]
# loss: 0.091562  [12864/60000]
# loss: 0.043874  [19264/60000]
# loss: 0.086097  [25664/60000]
# loss: 0.082319  [32064/60000]
# loss: 0.075239  [38464/60000]
# loss: 0.093639  [44864/60000]
# loss: 0.041044  [51264/60000]
# loss: 0.162793  [57664/60000]
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.082513
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.329382
#
# Epoch 20:
#
# loss: 0.018091  [   64/60000]
# loss: 0.114231  [ 6464/60000]
# loss: 0.037917  [12864/60000]
# loss: 0.024713  [19264/60000]
# loss: 0.137811  [25664/60000]
# loss: 0.113902  [32064/60000]
# loss: 0.040343  [38464/60000]
# loss: 0.039345  [44864/60000]
# loss: 0.095517  [51264/60000]
# loss: 0.075000  [57664/60000]
# Train Error:
#  Accuracy: 97.2%, Avg loss: 0.077165
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.330119
#
# Done training!

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, 3, padding=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.pool = nn.MaxPool2d(2, 2)

        self.conv2 = nn.Conv2d(16, 32, 3, padding=2)
        self.bn2 = nn.BatchNorm2d(32)

        # Add a third convolutional layer
        self.conv3 = nn.Conv2d(32, 64, 3)

        self.fc1 = nn.Linear(64 * 6 * 6, 10)  # Adjusted based on the actual size

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = F.relu(self.conv3(x))

        # Adjust the view operation based on the actual size
        x = x.view(-1, 64 * 6 * 6)
        x = self.fc1(x)
        return x

model = CNN().to(device)
summary(model, (1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 30, 30]             160
#        BatchNorm2d-2           [-1, 16, 30, 30]              32
#          MaxPool2d-3           [-1, 16, 15, 15]               0
#             Conv2d-4           [-1, 32, 17, 17]           4,640
#        BatchNorm2d-5           [-1, 32, 17, 17]              64
#          MaxPool2d-6             [-1, 32, 8, 8]               0
#             Conv2d-7             [-1, 64, 6, 6]          18,496
#             Linear-8                   [-1, 10]          23,050
# ================================================================
# Total params: 46,442
# Trainable params: 46,442
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.42
# Params size (MB): 0.18
# Estimated Total Size (MB): 0.60
# ----------------------------------------------------------------

# %%
# calling the train loop
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.297107  [   64/60000]
# loss: 0.371989  [ 6464/60000]
# loss: 0.269827  [12864/60000]
# loss: 0.368531  [19264/60000]
# loss: 0.416721  [25664/60000]
# loss: 0.411179  [32064/60000]
# loss: 0.228913  [38464/60000]
# loss: 0.380477  [44864/60000]
# loss: 0.384830  [51264/60000]
# loss: 0.277660  [57664/60000]
# Train Error:
#  Accuracy: 90.4%, Avg loss: 0.266125
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.304934
#
# Epoch 2:
#
# loss: 0.216611  [   64/60000]
# loss: 0.297134  [ 6464/60000]
# loss: 0.232144  [12864/60000]
# loss: 0.236233  [19264/60000]
# loss: 0.144758  [25664/60000]
# loss: 0.354731  [32064/60000]
# loss: 0.323942  [38464/60000]
# loss: 0.386340  [44864/60000]
# loss: 0.163764  [51264/60000]
# loss: 0.176544  [57664/60000]
# Train Error:
#  Accuracy: 92.0%, Avg loss: 0.219095
#
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.270143
#
# Epoch 3:
#
# loss: 0.336398  [   64/60000]
# loss: 0.136488  [ 6464/60000]
# loss: 0.244760  [12864/60000]
# loss: 0.227256  [19264/60000]
# loss: 0.096288  [25664/60000]
# loss: 0.202315  [32064/60000]
# loss: 0.192811  [38464/60000]
# loss: 0.185168  [44864/60000]
# loss: 0.312060  [51264/60000]
# loss: 0.298989  [57664/60000]
# Train Error:
#  Accuracy: 92.7%, Avg loss: 0.207177
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.268445
#
# Epoch 4:
#
# loss: 0.271634  [   64/60000]
# loss: 0.161584  [ 6464/60000]
# loss: 0.095850  [12864/60000]
# loss: 0.319782  [19264/60000]
# loss: 0.308082  [25664/60000]
# loss: 0.157768  [32064/60000]
# loss: 0.295738  [38464/60000]
# loss: 0.230685  [44864/60000]
# loss: 0.208934  [51264/60000]
# loss: 0.218642  [57664/60000]
# Train Error:
#  Accuracy: 93.6%, Avg loss: 0.177994
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.249602
#
# Epoch 5:
#
# loss: 0.094986  [   64/60000]
# loss: 0.094883  [ 6464/60000]
# loss: 0.089706  [12864/60000]
# loss: 0.117116  [19264/60000]
# loss: 0.161802  [25664/60000]
# loss: 0.143633  [32064/60000]
# loss: 0.244095  [38464/60000]
# loss: 0.187011  [44864/60000]
# loss: 0.111035  [51264/60000]
# loss: 0.196391  [57664/60000]
# Train Error:
#  Accuracy: 93.4%, Avg loss: 0.179095
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.274861
#
# Epoch 6:
#
# loss: 0.239793  [   64/60000]
# loss: 0.161245  [ 6464/60000]
# loss: 0.050227  [12864/60000]
# loss: 0.178653  [19264/60000]
# loss: 0.077603  [25664/60000]
# loss: 0.150937  [32064/60000]
# loss: 0.320647  [38464/60000]
# loss: 0.222564  [44864/60000]
# loss: 0.208151  [51264/60000]
# loss: 0.352491  [57664/60000]
# Train Error:
#  Accuracy: 94.8%, Avg loss: 0.142983
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.251122
#
# Epoch 7:
#
# loss: 0.042728  [   64/60000]
# loss: 0.139560  [ 6464/60000]
# loss: 0.176888  [12864/60000]
# loss: 0.164127  [19264/60000]
# loss: 0.189870  [25664/60000]
# loss: 0.059095  [32064/60000]
# loss: 0.195041  [38464/60000]
# loss: 0.261831  [44864/60000]
# loss: 0.267295  [51264/60000]
# loss: 0.110656  [57664/60000]
# Train Error:
#  Accuracy: 95.1%, Avg loss: 0.133392
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.263065
#
# Epoch 8:
#
# loss: 0.189301  [   64/60000]
# loss: 0.191351  [ 6464/60000]
# loss: 0.155994  [12864/60000]
# loss: 0.237543  [19264/60000]
# loss: 0.078764  [25664/60000]
# loss: 0.112548  [32064/60000]
# loss: 0.123492  [38464/60000]
# loss: 0.077483  [44864/60000]
# loss: 0.176531  [51264/60000]
# loss: 0.246060  [57664/60000]
# Train Error:
#  Accuracy: 96.0%, Avg loss: 0.112407
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.260858
#
# Epoch 9:
#
# loss: 0.107925  [   64/60000]
# loss: 0.062354  [ 6464/60000]
# loss: 0.152160  [12864/60000]
# loss: 0.129283  [19264/60000]
# loss: 0.171574  [25664/60000]
# loss: 0.061628  [32064/60000]
# loss: 0.157938  [38464/60000]
# loss: 0.126526  [44864/60000]
# loss: 0.083205  [51264/60000]
# loss: 0.097483  [57664/60000]
# Train Error:
#  Accuracy: 96.3%, Avg loss: 0.104699
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.254441
#
# Epoch 10:
#
# loss: 0.073046  [   64/60000]
# loss: 0.088421  [ 6464/60000]
# loss: 0.217502  [12864/60000]
# loss: 0.141205  [19264/60000]
# loss: 0.184455  [25664/60000]
# loss: 0.053423  [32064/60000]
# loss: 0.064225  [38464/60000]
# loss: 0.132362  [44864/60000]
# loss: 0.102852  [51264/60000]
# loss: 0.124097  [57664/60000]
# Train Error:
#  Accuracy: 96.7%, Avg loss: 0.090379
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.264074
#
# Epoch 11:
#
# loss: 0.089729  [   64/60000]
# loss: 0.068117  [ 6464/60000]
# loss: 0.139869  [12864/60000]
# loss: 0.027207  [19264/60000]
# loss: 0.090154  [25664/60000]
# loss: 0.037745  [32064/60000]
# loss: 0.035666  [38464/60000]
# loss: 0.053768  [44864/60000]
# loss: 0.066089  [51264/60000]
# loss: 0.103821  [57664/60000]
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.086767
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.281201
#
# Epoch 12:
#
# loss: 0.144176  [   64/60000]
# loss: 0.030925  [ 6464/60000]
# loss: 0.061457  [12864/60000]
# loss: 0.074799  [19264/60000]
# loss: 0.153277  [25664/60000]
# loss: 0.145130  [32064/60000]
# loss: 0.196170  [38464/60000]
# loss: 0.101953  [44864/60000]
# loss: 0.126556  [51264/60000]
# loss: 0.100564  [57664/60000]
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.082530
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.301299
#
# Epoch 13:
#
# loss: 0.039568  [   64/60000]
# loss: 0.096802  [ 6464/60000]
# loss: 0.081710  [12864/60000]
# loss: 0.138434  [19264/60000]
# loss: 0.087134  [25664/60000]
# loss: 0.090945  [32064/60000]
# loss: 0.065058  [38464/60000]
# loss: 0.069216  [44864/60000]
# loss: 0.091163  [51264/60000]
# loss: 0.196660  [57664/60000]
# Train Error:
#  Accuracy: 97.6%, Avg loss: 0.067540
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.300330
#
# Epoch 14:
#
# loss: 0.083803  [   64/60000]
# loss: 0.026047  [ 6464/60000]
# loss: 0.049131  [12864/60000]
# loss: 0.077806  [19264/60000]
# loss: 0.062258  [25664/60000]
# loss: 0.032176  [32064/60000]
# loss: 0.069565  [38464/60000]
# loss: 0.070084  [44864/60000]
# loss: 0.034410  [51264/60000]
# loss: 0.087055  [57664/60000]
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.072543
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.339954
#
# Epoch 15:
#
# loss: 0.013155  [   64/60000]
# loss: 0.029431  [ 6464/60000]
# loss: 0.117197  [12864/60000]
# loss: 0.149676  [19264/60000]
# loss: 0.117313  [25664/60000]
# loss: 0.107201  [32064/60000]
# loss: 0.029733  [38464/60000]
# loss: 0.069873  [44864/60000]
# loss: 0.327484  [51264/60000]
# loss: 0.059275  [57664/60000]
# Train Error:
#  Accuracy: 98.0%, Avg loss: 0.057329
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.327528
#
# Epoch 16:
#
# loss: 0.092587  [   64/60000]
# loss: 0.063219  [ 6464/60000]
# loss: 0.099469  [12864/60000]
# loss: 0.005029  [19264/60000]
# loss: 0.038023  [25664/60000]
# loss: 0.066771  [32064/60000]
# loss: 0.147971  [38464/60000]
# loss: 0.024171  [44864/60000]
# loss: 0.097104  [51264/60000]
# loss: 0.020899  [57664/60000]
# Train Error:
#  Accuracy: 97.9%, Avg loss: 0.057671
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.350871
#
# Epoch 17:
#
# loss: 0.034799  [   64/60000]
# loss: 0.144510  [ 6464/60000]
# loss: 0.086999  [12864/60000]
# loss: 0.043122  [19264/60000]
# loss: 0.078392  [25664/60000]
# loss: 0.057997  [32064/60000]
# loss: 0.058069  [38464/60000]
# loss: 0.026215  [44864/60000]
# loss: 0.022726  [51264/60000]
# loss: 0.035556  [57664/60000]
# Train Error:
#  Accuracy: 98.0%, Avg loss: 0.057548
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.332449
#
# Epoch 18:
#
# loss: 0.038970  [   64/60000]
# loss: 0.051053  [ 6464/60000]
# loss: 0.015661  [12864/60000]
# loss: 0.050468  [19264/60000]
# loss: 0.112389  [25664/60000]
# loss: 0.064444  [32064/60000]
# loss: 0.087275  [38464/60000]
# loss: 0.082566  [44864/60000]
# loss: 0.019560  [51264/60000]
# loss: 0.056017  [57664/60000]
# Train Error:
#  Accuracy: 98.3%, Avg loss: 0.047038
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.364454
#
# Epoch 19:
#
# loss: 0.099254  [   64/60000]
# loss: 0.069609  [ 6464/60000]
# loss: 0.034600  [12864/60000]
# loss: 0.078096  [19264/60000]
# loss: 0.041592  [25664/60000]
# loss: 0.018337  [32064/60000]
# loss: 0.036033  [38464/60000]
# loss: 0.004121  [44864/60000]
# loss: 0.053661  [51264/60000]
# loss: 0.117943  [57664/60000]
# Train Error:
#  Accuracy: 98.3%, Avg loss: 0.046772
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.380695
#
# Epoch 20:
#
# loss: 0.087145  [   64/60000]
# loss: 0.035482  [ 6464/60000]
# loss: 0.009968  [12864/60000]
# loss: 0.042390  [19264/60000]
# loss: 0.021024  [25664/60000]
# loss: 0.071823  [32064/60000]
# loss: 0.084548  [38464/60000]
# loss: 0.028320  [44864/60000]
# loss: 0.197085  [51264/60000]
# loss: 0.016613  [57664/60000]
# Train Error:
#  Accuracy: 98.2%, Avg loss: 0.048703
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.411475
#
# Done training!

# %%
# plotting the train and test loss and accuracy
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# ### <font color='red'>Your text here.</font>
# <font color='red'>Enter your text descriptions in the cell below:</font>

# %% [markdown]
# ---
# # 5. Transfer Learning
# ---
#
# Nobody trains large models from scratch. Rather, they use large pretrained models, that have been trained perhaps for weeks on very large datasets. Then, we can tweak the model for our needs. This allows us to use large models on small datasets and (hopefully) avoid some overfitting.
#
# We are going to load ResNet18, we're going to cut the head off it - in this case, we will replace the very last layer. ResNet18 was trained for 1000 classes, we only have 10.
#
# Do the following:
# 1. From `torchvision.models`, load [`ResNet18`](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html), and use random weights (`weights=None`). Replace the full-connected layer at the end with your own fully connect layer. Train and plot the loss and accuracy.
# 1. Repeat step 1, but use the default paramaters, and retrain. In this case, the default parameters.
# 1. Freeze all but the last layer of your adapted ResNet model, and retrain.
# 1. Provide some commentary on the three approaches. Particularly, what's the difference between all three approaches we outlined here?
#
# For the freezing of layers, the following article is useful:
# https://jimmy-shen.medium.com/pytorch-freeze-part-of-the-layers-4554105e03a6
#
# In step 3 above, we may see that the network doesn't necessarily perform as well as previous networks, in terms of test accuracy. Probably we should unfreeze more of the later layers to allow better fine-tuning of the network to our problem. And there are more complicated and powerful finetuning strategies out there. But you should see that overfitting is, more or less, solved. This is because we are only training a much smaller number of parameters, and freezing all of the convolution layers in the ResNet.

# %%
# We need to recreate the dataloaders, because ResNet expects a three channel
# RGB input, whereas FashionMNIST only has 1 channel (greyscale). Use
# `transforms.Grayscale(3)` to replicated the grayscale image into the three
# channels.

# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=transforms.Compose([
        transforms.Resize((28,28)),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize(mean = 0.2859, std = 0.3530),
    ])
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=transforms.Compose([
        transforms.Resize((28,28)),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize(mean = 0.2859, std = 0.3530),
    ])
)

batch_size = 64
# Recreate the data loaders.
train_dataloader = torch.utils.data.DataLoader(training_data, batch_size=batch_size)
test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 3, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %% [markdown]
# # Approach 1 : Using random weights(weights=None)

# %%
##############################
# Your code below
resnet18_random = torchvision.models.resnet18(weights=None)
resnet18_random.fc = nn.Linear(resnet18_random.fc.in_features, 10)  # Replace the fully connected layer
model = resnet18_random.to(device)
params = resnet18_random.state_dict()
summary(model, (3,7,7))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1             [-1, 64, 4, 4]           9,408
#        BatchNorm2d-2             [-1, 64, 4, 4]             128
#               ReLU-3             [-1, 64, 4, 4]               0
#          MaxPool2d-4             [-1, 64, 2, 2]               0
#             Conv2d-5             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-6             [-1, 64, 2, 2]             128
#               ReLU-7             [-1, 64, 2, 2]               0
#             Conv2d-8             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-9             [-1, 64, 2, 2]             128
#              ReLU-10             [-1, 64, 2, 2]               0
#        BasicBlock-11             [-1, 64, 2, 2]               0
#            Conv2d-12             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-13             [-1, 64, 2, 2]             128
#              ReLU-14             [-1, 64, 2, 2]               0
#            Conv2d-15             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-16             [-1, 64, 2, 2]             128
#              ReLU-17             [-1, 64, 2, 2]               0
#        BasicBlock-18             [-1, 64, 2, 2]               0
#            Conv2d-19            [-1, 128, 1, 1]          73,728
#       BatchNorm2d-20            [-1, 128, 1, 1]             256
#              ReLU-21            [-1, 128, 1, 1]               0
#            Conv2d-22            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-23            [-1, 128, 1, 1]             256
#            Conv2d-24            [-1, 128, 1, 1]           8,192
#       BatchNorm2d-25            [-1, 128, 1, 1]             256
#              ReLU-26            [-1, 128, 1, 1]               0
#        BasicBlock-27            [-1, 128, 1, 1]               0
#            Conv2d-28            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-29            [-1, 128, 1, 1]             256
#              ReLU-30            [-1, 128, 1, 1]               0
#            Conv2d-31            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-32            [-1, 128, 1, 1]             256
#              ReLU-33            [-1, 128, 1, 1]               0
#        BasicBlock-34            [-1, 128, 1, 1]               0
#            Conv2d-35            [-1, 256, 1, 1]         294,912
#       BatchNorm2d-36            [-1, 256, 1, 1]             512
#              ReLU-37            [-1, 256, 1, 1]               0
#            Conv2d-38            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-39            [-1, 256, 1, 1]             512
#            Conv2d-40            [-1, 256, 1, 1]          32,768
#       BatchNorm2d-41            [-1, 256, 1, 1]             512
#              ReLU-42            [-1, 256, 1, 1]               0
#        BasicBlock-43            [-1, 256, 1, 1]               0
#            Conv2d-44            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-45            [-1, 256, 1, 1]             512
#              ReLU-46            [-1, 256, 1, 1]               0
#            Conv2d-47            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-48            [-1, 256, 1, 1]             512
#              ReLU-49            [-1, 256, 1, 1]               0
#        BasicBlock-50            [-1, 256, 1, 1]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.17
# Params size (MB): 42.65
# Estimated Total Size (MB): 42.82
# ----------------------------------------------------------------

# %%
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_dataloader, test_dataloader, model)
# Out:
# Epoch 1:
#
# loss: 2.694325  [   64/60000]
# loss: 0.647353  [ 6464/60000]
# loss: 0.383007  [12864/60000]
# loss: 0.513184  [19264/60000]
# loss: 0.591460  [25664/60000]
# loss: 0.431365  [32064/60000]
# loss: 0.335318  [38464/60000]
# loss: 0.441846  [44864/60000]
# loss: 0.326749  [51264/60000]
# loss: 0.371231  [57664/60000]
# Train Error:
#  Accuracy: 84.5%, Avg loss: 0.391855
#
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.433866
#
# Epoch 2:
#
# loss: 0.323774  [   64/60000]
# loss: 0.308139  [ 6464/60000]
# loss: 0.215470  [12864/60000]
# loss: 0.340367  [19264/60000]
# loss: 0.267223  [25664/60000]
# loss: 0.435196  [32064/60000]
# loss: 0.257724  [38464/60000]
# loss: 0.366892  [44864/60000]
# loss: 0.278629  [51264/60000]
# loss: 0.317219  [57664/60000]
# Train Error:
#  Accuracy: 85.8%, Avg loss: 0.360264
#
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.411132
#
# Epoch 3:
#
# loss: 0.187342  [   64/60000]
# loss: 0.221560  [ 6464/60000]
# loss: 0.195230  [12864/60000]
# loss: 0.304225  [19264/60000]
# loss: 0.284621  [25664/60000]
# loss: 0.399280  [32064/60000]
# loss: 0.217520  [38464/60000]
# loss: 0.307159  [44864/60000]
# loss: 0.231122  [51264/60000]
# loss: 0.283675  [57664/60000]
# Train Error:
#  Accuracy: 89.9%, Avg loss: 0.266909
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.320636
#
# Epoch 4:
#
# loss: 0.216254  [   64/60000]
# loss: 0.146672  [ 6464/60000]
# loss: 0.157196  [12864/60000]
# loss: 0.272368  [19264/60000]
# loss: 0.197657  [25664/60000]
# loss: 0.439622  [32064/60000]
# loss: 0.197426  [38464/60000]
# loss: 0.276955  [44864/60000]
# loss: 0.182071  [51264/60000]
# loss: 0.231277  [57664/60000]
# Train Error:
#  Accuracy: 90.1%, Avg loss: 0.258865
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.317506
#
# Epoch 5:
#
# loss: 0.183805  [   64/60000]
# loss: 0.146473  [ 6464/60000]
# loss: 0.141430  [12864/60000]
# loss: 0.234969  [19264/60000]
# loss: 0.192130  [25664/60000]
# loss: 0.383974  [32064/60000]
# loss: 0.223589  [38464/60000]
# loss: 0.233045  [44864/60000]
# loss: 0.185053  [51264/60000]
# loss: 0.186793  [57664/60000]
# Train Error:
#  Accuracy: 89.6%, Avg loss: 0.289452
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.370926
#
# Epoch 6:
#
# loss: 0.190514  [   64/60000]
# loss: 0.186138  [ 6464/60000]
# loss: 0.137041  [12864/60000]
# loss: 0.231603  [19264/60000]
# loss: 0.203080  [25664/60000]
# loss: 0.371833  [32064/60000]
# loss: 0.224813  [38464/60000]
# loss: 0.216922  [44864/60000]
# loss: 0.169789  [51264/60000]
# loss: 0.176502  [57664/60000]
# Train Error:
#  Accuracy: 91.9%, Avg loss: 0.221931
#
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.324435
#
# Epoch 7:
#
# loss: 0.130246  [   64/60000]
# loss: 0.116352  [ 6464/60000]
# loss: 0.122158  [12864/60000]
# loss: 0.157017  [19264/60000]
# loss: 0.156076  [25664/60000]
# loss: 0.381879  [32064/60000]
# loss: 0.223367  [38464/60000]
# loss: 0.214027  [44864/60000]
# loss: 0.131030  [51264/60000]
# loss: 0.135638  [57664/60000]
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.214387
#
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.328749
#
# Epoch 8:
#
# loss: 0.141591  [   64/60000]
# loss: 0.125899  [ 6464/60000]
# loss: 0.081636  [12864/60000]
# loss: 0.169944  [19264/60000]
# loss: 0.144633  [25664/60000]
# loss: 0.312205  [32064/60000]
# loss: 0.144399  [38464/60000]
# loss: 0.182325  [44864/60000]
# loss: 0.098337  [51264/60000]
# loss: 0.111562  [57664/60000]
# Train Error:
#  Accuracy: 93.0%, Avg loss: 0.196777
#
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.326963
#
# Epoch 9:
#
# loss: 0.096283  [   64/60000]
# loss: 0.133685  [ 6464/60000]
# loss: 0.073572  [12864/60000]
# loss: 0.129740  [19264/60000]
# loss: 0.180368  [25664/60000]
# loss: 0.293796  [32064/60000]
# loss: 0.171674  [38464/60000]
# loss: 0.154739  [44864/60000]
# loss: 0.114274  [51264/60000]
# loss: 0.093327  [57664/60000]
# Train Error:
#  Accuracy: 93.6%, Avg loss: 0.176945
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.330806
#
# Epoch 10:
#
# loss: 0.131891  [   64/60000]
# loss: 0.138312  [ 6464/60000]
# loss: 0.066582  [12864/60000]
# loss: 0.155425  [19264/60000]
# loss: 0.126927  [25664/60000]
# loss: 0.196493  [32064/60000]
# loss: 0.238992  [38464/60000]
# loss: 0.194670  [44864/60000]
# loss: 0.040374  [51264/60000]
# loss: 0.088661  [57664/60000]
# Train Error:
#  Accuracy: 94.3%, Avg loss: 0.157205
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.321432
#
# Epoch 11:
#
# loss: 0.077865  [   64/60000]
# loss: 0.153327  [ 6464/60000]
# loss: 0.040321  [12864/60000]
# loss: 0.096909  [19264/60000]
# loss: 0.101326  [25664/60000]
# loss: 0.249700  [32064/60000]
# loss: 0.100711  [38464/60000]
# loss: 0.154854  [44864/60000]
# loss: 0.075143  [51264/60000]
# loss: 0.087005  [57664/60000]
# Train Error:
#  Accuracy: 94.2%, Avg loss: 0.158581
#
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.352018
#
# Epoch 12:
#
# loss: 0.071999  [   64/60000]
# loss: 0.102453  [ 6464/60000]
# loss: 0.056588  [12864/60000]
# loss: 0.087499  [19264/60000]
# loss: 0.070009  [25664/60000]
# loss: 0.220733  [32064/60000]
# loss: 0.084025  [38464/60000]
# loss: 0.104692  [44864/60000]
# loss: 0.125116  [51264/60000]
# loss: 0.059895  [57664/60000]
# Train Error:
#  Accuracy: 94.2%, Avg loss: 0.170232
#
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.381230
#
# Epoch 13:
#
# loss: 0.118440  [   64/60000]
# loss: 0.098232  [ 6464/60000]
# loss: 0.047450  [12864/60000]
# loss: 0.098372  [19264/60000]
# loss: 0.046024  [25664/60000]
# loss: 0.214723  [32064/60000]
# loss: 0.046631  [38464/60000]
# loss: 0.092762  [44864/60000]
# loss: 0.032228  [51264/60000]
# loss: 0.057791  [57664/60000]
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.117969
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.352300
#
# Epoch 14:
#
# loss: 0.056342  [   64/60000]
# loss: 0.118074  [ 6464/60000]
# loss: 0.023425  [12864/60000]
# loss: 0.044716  [19264/60000]
# loss: 0.076059  [25664/60000]
# loss: 0.274554  [32064/60000]
# loss: 0.067595  [38464/60000]
# loss: 0.054228  [44864/60000]
# loss: 0.108830  [51264/60000]
# loss: 0.070105  [57664/60000]
# Train Error:
#  Accuracy: 95.4%, Avg loss: 0.135602
#
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.399372
#
# Epoch 15:
#
# loss: 0.032959  [   64/60000]
# loss: 0.073026  [ 6464/60000]
# loss: 0.009071  [12864/60000]
# loss: 0.137972  [19264/60000]
# loss: 0.098321  [25664/60000]
# loss: 0.132963  [32064/60000]
# loss: 0.054103  [38464/60000]
# loss: 0.063195  [44864/60000]
# loss: 0.049800  [51264/60000]
# loss: 0.117062  [57664/60000]
# Train Error:
#  Accuracy: 96.2%, Avg loss: 0.104129
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.381047
#
# Epoch 16:
#
# loss: 0.129767  [   64/60000]
# loss: 0.108462  [ 6464/60000]
# loss: 0.003069  [12864/60000]
# loss: 0.018826  [19264/60000]
# loss: 0.075435  [25664/60000]
# loss: 0.082552  [32064/60000]
# loss: 0.069601  [38464/60000]
# loss: 0.057947  [44864/60000]
# loss: 0.150204  [51264/60000]
# loss: 0.108855  [57664/60000]
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.095154
#
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.398609
#
# Epoch 17:
#
# loss: 0.022827  [   64/60000]
# loss: 0.065914  [ 6464/60000]
# loss: 0.031812  [12864/60000]
# loss: 0.041732  [19264/60000]
# loss: 0.043531  [25664/60000]
# loss: 0.088022  [32064/60000]
# loss: 0.025863  [38464/60000]
# loss: 0.030051  [44864/60000]
# loss: 0.041772  [51264/60000]
# loss: 0.024337  [57664/60000]
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.090776
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.399160
#
# Epoch 18:
#
# loss: 0.029985  [   64/60000]
# loss: 0.055989  [ 6464/60000]
# loss: 0.006237  [12864/60000]
# loss: 0.112973  [19264/60000]
# loss: 0.036251  [25664/60000]
# loss: 0.049094  [32064/60000]
# loss: 0.077890  [38464/60000]
# loss: 0.066121  [44864/60000]
# loss: 0.029387  [51264/60000]
# loss: 0.016669  [57664/60000]
# Train Error:
#  Accuracy: 96.2%, Avg loss: 0.116513
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.448797
#
# Epoch 19:
#
# loss: 0.039685  [   64/60000]
# loss: 0.026720  [ 6464/60000]
# loss: 0.009272  [12864/60000]
# loss: 0.034805  [19264/60000]
# loss: 0.097932  [25664/60000]
# loss: 0.077612  [32064/60000]
# loss: 0.106920  [38464/60000]
# loss: 0.124465  [44864/60000]
# loss: 0.029347  [51264/60000]
# loss: 0.016703  [57664/60000]
# Train Error:
#  Accuracy: 96.1%, Avg loss: 0.112765
#
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.453160
#
# Epoch 20:
#
# loss: 0.044263  [   64/60000]
# loss: 0.057073  [ 6464/60000]
# loss: 0.018726  [12864/60000]
# loss: 0.101378  [19264/60000]
# loss: 0.076563  [25664/60000]
# loss: 0.038382  [32064/60000]
# loss: 0.104569  [38464/60000]
# loss: 0.037321  [44864/60000]
# loss: 0.140699  [51264/60000]
# loss: 0.111187  [57664/60000]
# Train Error:
#  Accuracy: 96.5%, Avg loss: 0.113137
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.481532
#
# Done training!

# %%
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %%
##############################
# Your code below
resnet18_default = torchvision.models.resnet18(weights='DEFAULT') # equivalent to weights='IMAGENET1K_V1'
resnet18_default.fc = nn.Linear(resnet18_default.fc.in_features, 10)  # Replace the fully connected layer
model = resnet18_default.to(device)
params = resnet18_default.state_dict()
summary(model, (3,7,7))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 97.6MB/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1             [-1, 64, 4, 4]           9,408
#        BatchNorm2d-2             [-1, 64, 4, 4]             128
#               ReLU-3             [-1, 64, 4, 4]               0
#          MaxPool2d-4             [-1, 64, 2, 2]               0
#             Conv2d-5             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-6             [-1, 64, 2, 2]             128
#               ReLU-7             [-1, 64, 2, 2]               0
#             Conv2d-8             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-9             [-1, 64, 2, 2]             128
#              ReLU-10             [-1, 64, 2, 2]               0
#        BasicBlock-11             [-1, 64, 2, 2]               0
#            Conv2d-12             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-13             [-1, 64, 2, 2]             128
#              ReLU-14             [-1, 64, 2, 2]               0
#            Conv2d-15             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-16             [-1, 64, 2, 2]             128
#              ReLU-17             [-1, 64, 2, 2]               0
#        BasicBlock-18             [-1, 64, 2, 2]               0
#            Conv2d-19            [-1, 128, 1, 1]          73,728
#       BatchNorm2d-20            [-1, 128, 1, 1]             256
#              ReLU-21            [-1, 128, 1, 1]               0
#            Conv2d-22            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-23            [-1, 128, 1, 1]             256
#            Conv2d-24            [-1, 128, 1, 1]           8,192
#       BatchNorm2d-25            [-1, 128, 1, 1]             256
#              ReLU-26            [-1, 128, 1, 1]               0
#        BasicBlock-27            [-1, 128, 1, 1]               0
#            Conv2d-28            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-29            [-1, 128, 1, 1]             256
#              ReLU-30            [-1, 128, 1, 1]               0
#            Conv2d-31            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-32            [-1, 128, 1, 1]             256
#              ReLU-33            [-1, 128, 1, 1]               0
#        BasicBlock-34            [-1, 128, 1, 1]               0
#            Conv2d-35            [-1, 256, 1, 1]         294,912
#       BatchNorm2d-36            [-1, 256, 1, 1]             512
#              ReLU-37            [-1, 256, 1, 1]               0
#            Conv2d-38            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-39            [-1, 256, 1, 1]             512
#            Conv2d-40            [-1, 256, 1, 1]          32,768
#       BatchNorm2d-41            [-1, 256, 1, 1]             512
#              ReLU-42            [-1, 256, 1, 1]               0
#        BasicBlock-43            [-1, 256, 1, 1]               0
#            Conv2d-44            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-45            [-1, 256, 1, 1]             512
#              ReLU-46            [-1, 256, 1, 1]               0
#            Conv2d-47            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-48            [-1, 256, 1, 1]             512
#              ReLU-49            [-1, 256, 1, 1]               0
#        BasicBlock-50            [-1, 256, 1, 1]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.17
# Params size (MB): 42.65
# Estimated Total Size (MB): 42.82
# ----------------------------------------------------------------

# %%
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_dataloader, test_dataloader, model)
# Out:
# Epoch 1:
#
# loss: 2.801699  [   64/60000]
# loss: 0.375606  [ 6464/60000]
# loss: 0.339512  [12864/60000]
# loss: 0.421430  [19264/60000]
# loss: 0.482999  [25664/60000]
# loss: 0.512035  [32064/60000]
# loss: 0.346911  [38464/60000]
# loss: 0.374678  [44864/60000]
# loss: 0.344163  [51264/60000]
# loss: 0.305048  [57664/60000]
# Train Error:
#  Accuracy: 88.6%, Avg loss: 0.310228
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.344764
#
# Epoch 2:
#
# loss: 0.283192  [   64/60000]
# loss: 0.321641  [ 6464/60000]
# loss: 0.261211  [12864/60000]
# loss: 0.261431  [19264/60000]
# loss: 0.324890  [25664/60000]
# loss: 0.395742  [32064/60000]
# loss: 0.248477  [38464/60000]
# loss: 0.396057  [44864/60000]
# loss: 0.253071  [51264/60000]
# loss: 0.198477  [57664/60000]
# Train Error:
#  Accuracy: 90.6%, Avg loss: 0.259574
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.301005
#
# Epoch 3:
#
# loss: 0.181882  [   64/60000]
# loss: 0.232857  [ 6464/60000]
# loss: 0.255083  [12864/60000]
# loss: 0.205621  [19264/60000]
# loss: 0.256225  [25664/60000]
# loss: 0.371049  [32064/60000]
# loss: 0.252309  [38464/60000]
# loss: 0.355696  [44864/60000]
# loss: 0.249665  [51264/60000]
# loss: 0.204072  [57664/60000]
# Train Error:
#  Accuracy: 92.1%, Avg loss: 0.210819
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.267265
#
# Epoch 4:
#
# loss: 0.121018  [   64/60000]
# loss: 0.209538  [ 6464/60000]
# loss: 0.229899  [12864/60000]
# loss: 0.139177  [19264/60000]
# loss: 0.256721  [25664/60000]
# loss: 0.326315  [32064/60000]
# loss: 0.251540  [38464/60000]
# loss: 0.262149  [44864/60000]
# loss: 0.214359  [51264/60000]
# loss: 0.201829  [57664/60000]
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.211043
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.286881
#
# Epoch 5:
#
# loss: 0.120787  [   64/60000]
# loss: 0.206548  [ 6464/60000]
# loss: 0.196184  [12864/60000]
# loss: 0.113383  [19264/60000]
# loss: 0.263092  [25664/60000]
# loss: 0.308382  [32064/60000]
# loss: 0.270599  [38464/60000]
# loss: 0.207174  [44864/60000]
# loss: 0.162734  [51264/60000]
# loss: 0.128343  [57664/60000]
# Train Error:
#  Accuracy: 93.7%, Avg loss: 0.172776
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.266726
#
# Epoch 6:
#
# loss: 0.127503  [   64/60000]
# loss: 0.122321  [ 6464/60000]
# loss: 0.196896  [12864/60000]
# loss: 0.101181  [19264/60000]
# loss: 0.167089  [25664/60000]
# loss: 0.302519  [32064/60000]
# loss: 0.261393  [38464/60000]
# loss: 0.203556  [44864/60000]
# loss: 0.145814  [51264/60000]
# loss: 0.103242  [57664/60000]
# Train Error:
#  Accuracy: 94.3%, Avg loss: 0.161327
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.275299
#
# Epoch 7:
#
# loss: 0.112260  [   64/60000]
# loss: 0.123168  [ 6464/60000]
# loss: 0.151581  [12864/60000]
# loss: 0.053887  [19264/60000]
# loss: 0.161011  [25664/60000]
# loss: 0.287645  [32064/60000]
# loss: 0.216581  [38464/60000]
# loss: 0.151533  [44864/60000]
# loss: 0.104979  [51264/60000]
# loss: 0.115297  [57664/60000]
# Train Error:
#  Accuracy: 94.8%, Avg loss: 0.144410
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.279184
#
# Epoch 8:
#
# loss: 0.131565  [   64/60000]
# loss: 0.159358  [ 6464/60000]
# loss: 0.106722  [12864/60000]
# loss: 0.123971  [19264/60000]
# loss: 0.136601  [25664/60000]
# loss: 0.279904  [32064/60000]
# loss: 0.091208  [38464/60000]
# loss: 0.121219  [44864/60000]
# loss: 0.129257  [51264/60000]
# loss: 0.094402  [57664/60000]
# Train Error:
#  Accuracy: 94.7%, Avg loss: 0.149085
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.314078
#
# Epoch 9:
#
# loss: 0.177998  [   64/60000]
# loss: 0.105901  [ 6464/60000]
# loss: 0.093287  [12864/60000]
# loss: 0.140028  [19264/60000]
# loss: 0.137159  [25664/60000]
# loss: 0.214452  [32064/60000]
# loss: 0.088285  [38464/60000]
# loss: 0.088953  [44864/60000]
# loss: 0.035553  [51264/60000]
# loss: 0.078084  [57664/60000]
# Train Error:
#  Accuracy: 95.5%, Avg loss: 0.123899
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.324431
#
# Epoch 10:
#
# loss: 0.101582  [   64/60000]
# loss: 0.066421  [ 6464/60000]
# loss: 0.110697  [12864/60000]
# loss: 0.067722  [19264/60000]
# loss: 0.138350  [25664/60000]
# loss: 0.233930  [32064/60000]
# loss: 0.314312  [38464/60000]
# loss: 0.073096  [44864/60000]
# loss: 0.054487  [51264/60000]
# loss: 0.136028  [57664/60000]
# Train Error:
#  Accuracy: 96.4%, Avg loss: 0.100786
#
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.319782
#
# Epoch 11:
#
# loss: 0.056699  [   64/60000]
# loss: 0.088825  [ 6464/60000]
# loss: 0.054265  [12864/60000]
# loss: 0.078812  [19264/60000]
# loss: 0.065132  [25664/60000]
# loss: 0.277213  [32064/60000]
# loss: 0.044002  [38464/60000]
# loss: 0.083696  [44864/60000]
# loss: 0.040810  [51264/60000]
# loss: 0.058937  [57664/60000]
# Train Error:
#  Accuracy: 96.4%, Avg loss: 0.109004
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.371313
#
# Epoch 12:
#
# loss: 0.151998  [   64/60000]
# loss: 0.052793  [ 6464/60000]
# loss: 0.057253  [12864/60000]
# loss: 0.052179  [19264/60000]
# loss: 0.073242  [25664/60000]
# loss: 0.107460  [32064/60000]
# loss: 0.067916  [38464/60000]
# loss: 0.041132  [44864/60000]
# loss: 0.070758  [51264/60000]
# loss: 0.110806  [57664/60000]
# Train Error:
#  Accuracy: 96.0%, Avg loss: 0.118607
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.388344
#
# Epoch 13:
#
# loss: 0.069139  [   64/60000]
# loss: 0.025137  [ 6464/60000]
# loss: 0.049506  [12864/60000]
# loss: 0.064242  [19264/60000]
# loss: 0.116967  [25664/60000]
# loss: 0.152282  [32064/60000]
# loss: 0.030620  [38464/60000]
# loss: 0.104789  [44864/60000]
# loss: 0.105001  [51264/60000]
# loss: 0.131949  [57664/60000]
# Train Error:
#  Accuracy: 95.6%, Avg loss: 0.122214
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.387987
#
# Epoch 14:
#
# loss: 0.035470  [   64/60000]
# loss: 0.084911  [ 6464/60000]
# loss: 0.010435  [12864/60000]
# loss: 0.044888  [19264/60000]
# loss: 0.040690  [25664/60000]
# loss: 0.146806  [32064/60000]
# loss: 0.029683  [38464/60000]
# loss: 0.030062  [44864/60000]
# loss: 0.023526  [51264/60000]
# loss: 0.077154  [57664/60000]
# Train Error:
#  Accuracy: 95.9%, Avg loss: 0.118617
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.426062
#
# Epoch 15:
#
# loss: 0.074370  [   64/60000]
# loss: 0.041493  [ 6464/60000]
# loss: 0.018846  [12864/60000]
# loss: 0.014754  [19264/60000]
# loss: 0.026657  [25664/60000]
# loss: 0.027228  [32064/60000]
# loss: 0.012782  [38464/60000]
# loss: 0.033112  [44864/60000]
# loss: 0.051920  [51264/60000]
# loss: 0.062726  [57664/60000]
# Train Error:
#  Accuracy: 96.7%, Avg loss: 0.097576
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.426950
#
# Epoch 16:
#
# loss: 0.051267  [   64/60000]
# loss: 0.007889  [ 6464/60000]
# loss: 0.011595  [12864/60000]
# loss: 0.067289  [19264/60000]
# loss: 0.074531  [25664/60000]
# loss: 0.097950  [32064/60000]
# loss: 0.175927  [38464/60000]
# loss: 0.058183  [44864/60000]
# loss: 0.049880  [51264/60000]
# loss: 0.027104  [57664/60000]
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.100145
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.447852
#
# Epoch 17:
#
# loss: 0.096566  [   64/60000]
# loss: 0.022248  [ 6464/60000]
# loss: 0.088241  [12864/60000]
# loss: 0.067122  [19264/60000]
# loss: 0.011633  [25664/60000]
# loss: 0.019482  [32064/60000]
# loss: 0.037983  [38464/60000]
# loss: 0.047366  [44864/60000]
# loss: 0.039666  [51264/60000]
# loss: 0.030704  [57664/60000]
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.071134
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.396799
#
# Epoch 18:
#
# loss: 0.063425  [   64/60000]
# loss: 0.045633  [ 6464/60000]
# loss: 0.044161  [12864/60000]
# loss: 0.008961  [19264/60000]
# loss: 0.054972  [25664/60000]
# loss: 0.110614  [32064/60000]
# loss: 0.026466  [38464/60000]
# loss: 0.049195  [44864/60000]
# loss: 0.014535  [51264/60000]
# loss: 0.070260  [57664/60000]
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.082734
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.425302
#
# Epoch 19:
#
# loss: 0.059013  [   64/60000]
# loss: 0.024676  [ 6464/60000]
# loss: 0.003160  [12864/60000]
# loss: 0.036734  [19264/60000]
# loss: 0.041374  [25664/60000]
# loss: 0.053291  [32064/60000]
# loss: 0.053752  [38464/60000]
# loss: 0.074393  [44864/60000]
# loss: 0.049261  [51264/60000]
# loss: 0.032660  [57664/60000]
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.059366
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.368426
#
# Epoch 20:
#
# loss: 0.037886  [   64/60000]
# loss: 0.008558  [ 6464/60000]
# loss: 0.004185  [12864/60000]
# loss: 0.021104  [19264/60000]
# loss: 0.058005  [25664/60000]
# loss: 0.051474  [32064/60000]
# loss: 0.063776  [38464/60000]
# loss: 0.003528  [44864/60000]
# loss: 0.114664  [51264/60000]
# loss: 0.009238  [57664/60000]
# Train Error:
#  Accuracy: 98.5%, Avg loss: 0.043887
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.427300
#
# Done training!

# %%
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %%
resnet18_3 = torchvision.models.resnet18(weights='DEFAULT') # equivalent to weights='IMAGENET1K_V1'
for name, param in resnet18_3.named_parameters():
  if name not in ['fc.weight', 'fc.bias']:
    param.requires_grad = False
resnet18_3.fc = nn.Linear(resnet18_3.fc.in_features, 10)
model = resnet18_3.to(device)
summary(model, (3,7,7))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1             [-1, 64, 4, 4]           9,408
#        BatchNorm2d-2             [-1, 64, 4, 4]             128
#               ReLU-3             [-1, 64, 4, 4]               0
#          MaxPool2d-4             [-1, 64, 2, 2]               0
#             Conv2d-5             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-6             [-1, 64, 2, 2]             128
#               ReLU-7             [-1, 64, 2, 2]               0
#             Conv2d-8             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-9             [-1, 64, 2, 2]             128
#              ReLU-10             [-1, 64, 2, 2]               0
#        BasicBlock-11             [-1, 64, 2, 2]               0
#            Conv2d-12             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-13             [-1, 64, 2, 2]             128
#              ReLU-14             [-1, 64, 2, 2]               0
#            Conv2d-15             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-16             [-1, 64, 2, 2]             128
#              ReLU-17             [-1, 64, 2, 2]               0
#        BasicBlock-18             [-1, 64, 2, 2]               0
#            Conv2d-19            [-1, 128, 1, 1]          73,728
#       BatchNorm2d-20            [-1, 128, 1, 1]             256
#              ReLU-21            [-1, 128, 1, 1]               0
#            Conv2d-22            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-23            [-1, 128, 1, 1]             256
#            Conv2d-24            [-1, 128, 1, 1]           8,192
#       BatchNorm2d-25            [-1, 128, 1, 1]             256
#              ReLU-26            [-1, 128, 1, 1]               0
#        BasicBlock-27            [-1, 128, 1, 1]               0
#            Conv2d-28            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-29            [-1, 128, 1, 1]             256
#              ReLU-30            [-1, 128, 1, 1]               0
#            Conv2d-31            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-32            [-1, 128, 1, 1]             256
#              ReLU-33            [-1, 128, 1, 1]               0
#        BasicBlock-34            [-1, 128, 1, 1]               0
#            Conv2d-35            [-1, 256, 1, 1]         294,912
#       BatchNorm2d-36            [-1, 256, 1, 1]             512
#              ReLU-37            [-1, 256, 1, 1]               0
#            Conv2d-38            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-39            [-1, 256, 1, 1]             512
#            Conv2d-40            [-1, 256, 1, 1]          32,768
#       BatchNorm2d-41            [-1, 256, 1, 1]             512
#              ReLU-42            [-1, 256, 1, 1]               0
#        BasicBlock-43            [-1, 256, 1, 1]               0
#            Conv2d-44            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-45            [-1, 256, 1, 1]             512
#              ReLU-46            [-1, 256, 1, 1]               0
#            Conv2d-47            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-48            [-1, 256, 1, 1]             512
#              ReLU-49            [-1, 256, 1, 1]               0
#        BasicBlock-50            [-1, 256, 1, 1]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 5,130
# Non-trainable params: 11,176,512
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.17
# Params size (MB): 42.65
# Estimated Total Size (MB): 42.82
# ----------------------------------------------------------------

# %%
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_dataloader, test_dataloader, model)
# Out:
# Epoch 1:
#
# loss: 2.398278  [   64/60000]
# loss: 1.255037  [ 6464/60000]
# loss: 0.880544  [12864/60000]
# loss: 0.951668  [19264/60000]
# loss: 0.973721  [25664/60000]
# loss: 0.987518  [32064/60000]
# loss: 0.873921  [38464/60000]
# loss: 0.854138  [44864/60000]
# loss: 1.128478  [51264/60000]
# loss: 0.952974  [57664/60000]
# Train Error:
#  Accuracy: 71.9%, Avg loss: 0.830174
#
# Test Error:
#  Accuracy: 70.6%, Avg loss: 0.858487
#
# Epoch 2:
#
# loss: 0.854357  [   64/60000]
# loss: 0.849561  [ 6464/60000]
# loss: 0.780259  [12864/60000]
# loss: 0.791754  [19264/60000]
# loss: 0.830518  [25664/60000]
# loss: 0.897472  [32064/60000]
# loss: 0.816176  [38464/60000]
# loss: 0.817268  [44864/60000]
# loss: 1.092097  [51264/60000]
# loss: 0.891817  [57664/60000]
# Train Error:
#  Accuracy: 73.1%, Avg loss: 0.789026
#
# Test Error:
#  Accuracy: 71.6%, Avg loss: 0.828502
#
# Epoch 3:
#
# loss: 0.848140  [   64/60000]
# loss: 0.789184  [ 6464/60000]
# loss: 0.761960  [12864/60000]
# loss: 0.770791  [19264/60000]
# loss: 0.787579  [25664/60000]
# loss: 0.865166  [32064/60000]
# loss: 0.787900  [38464/60000]
# loss: 0.804414  [44864/60000]
# loss: 1.081586  [51264/60000]
# loss: 0.862341  [57664/60000]
# Train Error:
#  Accuracy: 73.6%, Avg loss: 0.773316
#
# Test Error:
#  Accuracy: 71.9%, Avg loss: 0.819381
#
# Epoch 4:
#
# loss: 0.840602  [   64/60000]
# loss: 0.760933  [ 6464/60000]
# loss: 0.752577  [12864/60000]
# loss: 0.763486  [19264/60000]
# loss: 0.764449  [25664/60000]
# loss: 0.846047  [32064/60000]
# loss: 0.769456  [38464/60000]
# loss: 0.797302  [44864/60000]
# loss: 1.079202  [51264/60000]
# loss: 0.845241  [57664/60000]
# Train Error:
#  Accuracy: 73.8%, Avg loss: 0.765386
#
# Test Error:
#  Accuracy: 71.9%, Avg loss: 0.815985
#
# Epoch 5:
#
# loss: 0.834454  [   64/60000]
# loss: 0.744527  [ 6464/60000]
# loss: 0.746426  [12864/60000]
# loss: 0.759844  [19264/60000]
# loss: 0.749485  [25664/60000]
# loss: 0.833308  [32064/60000]
# loss: 0.756588  [38464/60000]
# loss: 0.792733  [44864/60000]
# loss: 1.079760  [51264/60000]
# loss: 0.834734  [57664/60000]
# Train Error:
#  Accuracy: 73.9%, Avg loss: 0.760811
#
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.814820
#
# Epoch 6:
#
# loss: 0.829713  [   64/60000]
# loss: 0.733954  [ 6464/60000]
# loss: 0.741900  [12864/60000]
# loss: 0.757636  [19264/60000]
# loss: 0.738896  [25664/60000]
# loss: 0.824327  [32064/60000]
# loss: 0.747280  [38464/60000]
# loss: 0.789520  [44864/60000]
# loss: 1.081331  [51264/60000]
# loss: 0.827955  [57664/60000]
# Train Error:
#  Accuracy: 73.9%, Avg loss: 0.757952
#
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.814679
#
# Epoch 7:
#
# loss: 0.825984  [   64/60000]
# loss: 0.726740  [ 6464/60000]
# loss: 0.738375  [12864/60000]
# loss: 0.756126  [19264/60000]
# loss: 0.731013  [25664/60000]
# loss: 0.817755  [32064/60000]
# loss: 0.740357  [38464/60000]
# loss: 0.787115  [44864/60000]
# loss: 1.083125  [51264/60000]
# loss: 0.823313  [57664/60000]
# Train Error:
#  Accuracy: 74.0%, Avg loss: 0.756065
#
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.815032
#
# Epoch 8:
#
# loss: 0.822873  [   64/60000]
# loss: 0.721641  [ 6464/60000]
# loss: 0.735544  [12864/60000]
# loss: 0.755006  [19264/60000]
# loss: 0.724955  [25664/60000]
# loss: 0.812811  [32064/60000]
# loss: 0.735081  [38464/60000]
# loss: 0.785231  [44864/60000]
# loss: 1.084832  [51264/60000]
# loss: 0.819951  [57664/60000]
# Train Error:
#  Accuracy: 74.1%, Avg loss: 0.754775
#
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.815616
#
# Epoch 9:
#
# loss: 0.820163  [   64/60000]
# loss: 0.717942  [ 6464/60000]
# loss: 0.733235  [12864/60000]
# loss: 0.754121  [19264/60000]
# loss: 0.720194  [25664/60000]
# loss: 0.809008  [32064/60000]
# loss: 0.730973  [38464/60000]
# loss: 0.783701  [44864/60000]
# loss: 1.086350  [51264/60000]
# loss: 0.817409  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.753870
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.816293
#
# Epoch 10:
#
# loss: 0.817759  [   64/60000]
# loss: 0.715201  [ 6464/60000]
# loss: 0.731339  [12864/60000]
# loss: 0.753380  [19264/60000]
# loss: 0.716387  [25664/60000]
# loss: 0.806023  [32064/60000]
# loss: 0.727714  [38464/60000]
# loss: 0.782419  [44864/60000]
# loss: 1.087662  [51264/60000]
# loss: 0.815425  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.753227
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.816995
#
# Epoch 11:
#
# loss: 0.815615  [   64/60000]
# loss: 0.713133  [ 6464/60000]
# loss: 0.729777  [12864/60000]
# loss: 0.752728  [19264/60000]
# loss: 0.713296  [25664/60000]
# loss: 0.803634  [32064/60000]
# loss: 0.725084  [38464/60000]
# loss: 0.781318  [44864/60000]
# loss: 1.088782  [51264/60000]
# loss: 0.813838  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.752765
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.817683
#
# Epoch 12:
#
# loss: 0.813701  [   64/60000]
# loss: 0.711552  [ 6464/60000]
# loss: 0.728486  [12864/60000]
# loss: 0.752134  [19264/60000]
# loss: 0.710753  [25664/60000]
# loss: 0.801689  [32064/60000]
# loss: 0.722929  [38464/60000]
# loss: 0.780351  [44864/60000]
# loss: 1.089735  [51264/60000]
# loss: 0.812545  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.752432
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.818341
#
# Epoch 13:
#
# loss: 0.811995  [   64/60000]
# loss: 0.710331  [ 6464/60000]
# loss: 0.727418  [12864/60000]
# loss: 0.751576  [19264/60000]
# loss: 0.708634  [25664/60000]
# loss: 0.800081  [32064/60000]
# loss: 0.721136  [38464/60000]
# loss: 0.779487  [44864/60000]
# loss: 1.090545  [51264/60000]
# loss: 0.811473  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.752192
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.818959
#
# Epoch 14:
#
# loss: 0.810475  [   64/60000]
# loss: 0.709384  [ 6464/60000]
# loss: 0.726534  [12864/60000]
# loss: 0.751043  [19264/60000]
# loss: 0.706849  [25664/60000]
# loss: 0.798733  [32064/60000]
# loss: 0.719625  [38464/60000]
# loss: 0.778701  [44864/60000]
# loss: 1.091234  [51264/60000]
# loss: 0.810571  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.752020
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.819535
#
# Epoch 15:
#
# loss: 0.809124  [   64/60000]
# loss: 0.708646  [ 6464/60000]
# loss: 0.725802  [12864/60000]
# loss: 0.750530  [19264/60000]
# loss: 0.705329  [25664/60000]
# loss: 0.797592  [32064/60000]
# loss: 0.718335  [38464/60000]
# loss: 0.777978  [44864/60000]
# loss: 1.091821  [51264/60000]
# loss: 0.809803  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.751898
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.820068
#
# Epoch 16:
#
# loss: 0.807920  [   64/60000]
# loss: 0.708072  [ 6464/60000]
# loss: 0.725192  [12864/60000]
# loss: 0.750034  [19264/60000]
# loss: 0.704022  [25664/60000]
# loss: 0.796615  [32064/60000]
# loss: 0.717219  [38464/60000]
# loss: 0.777305  [44864/60000]
# loss: 1.092319  [51264/60000]
# loss: 0.809142  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.751814
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.820560
#
# Epoch 17:
#
# loss: 0.806849  [   64/60000]
# loss: 0.707628  [ 6464/60000]
# loss: 0.724685  [12864/60000]
# loss: 0.749553  [19264/60000]
# loss: 0.702887  [25664/60000]
# loss: 0.795773  [32064/60000]
# loss: 0.716243  [38464/60000]
# loss: 0.776673  [44864/60000]
# loss: 1.092742  [51264/60000]
# loss: 0.808567  [57664/60000]
# Train Error:
#  Accuracy: 74.3%, Avg loss: 0.751757
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.821013
#
# Epoch 18:
#
# loss: 0.805895  [   64/60000]
# loss: 0.707288  [ 6464/60000]
# loss: 0.724261  [12864/60000]
# loss: 0.749088  [19264/60000]
# loss: 0.701893  [25664/60000]
# loss: 0.795042  [32064/60000]
# loss: 0.715379  [38464/60000]
# loss: 0.776075  [44864/60000]
# loss: 1.093100  [51264/60000]
# loss: 0.808062  [57664/60000]
# Train Error:
#  Accuracy: 74.3%, Avg loss: 0.751721
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.821431
#
# Epoch 19:
#
# loss: 0.805043  [   64/60000]
# loss: 0.707032  [ 6464/60000]
# loss: 0.723906  [12864/60000]
# loss: 0.748640  [19264/60000]
# loss: 0.701015  [25664/60000]
# loss: 0.794405  [32064/60000]
# loss: 0.714607  [38464/60000]
# loss: 0.775507  [44864/60000]
# loss: 1.093400  [51264/60000]
# loss: 0.807615  [57664/60000]
# Train Error:
#  Accuracy: 74.3%, Avg loss: 0.751701
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.821814
#
# Epoch 20:
#
# loss: 0.804281  [   64/60000]
# loss: 0.706844  [ 6464/60000]
# loss: 0.723606  [12864/60000]
# loss: 0.748208  [19264/60000]
# loss: 0.700234  [25664/60000]
# loss: 0.793847  [32064/60000]
# loss: 0.713910  [38464/60000]
# loss: 0.774963  [44864/60000]
# loss: 1.093649  [51264/60000]
# loss: 0.807216  [57664/60000]
# Train Error:
#  Accuracy: 74.3%, Avg loss: 0.751694
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.822167
#
# Done training!

# %%
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %%
# Define the loss function and the optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Note, replace model with the instance name of your model

##############################
# Your code below

...
# Out:
# Ellipsis

# %%
##############################
# Your code below

...
# Out:
# Ellipsis

# %%
# Define the loss function and the optimizer

...
# Out:
# Ellipsis

# %%
##############################
# Your code below

...
# Out:
# Ellipsis

# %%
# Define the loss function and the optimizer

...
# Out:
# Ellipsis

# %% [markdown]
# ### <font color='red'>Your text here.</font>
# <font color='red'>Enter your text descriptions in the cell below:</font>
