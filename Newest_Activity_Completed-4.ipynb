# %% [markdown]
# Student Name: Sajin Mohamed Pallikkathodi Erathali
#
# Student ID: 23037601

# %% [markdown]
# # Activity 6: Pytorch and CNNs for Fashion-MNIST
#
# In this activity, we are going to explore designing various neural networks for the FashionMNIST classification problem. This is, of course, a 'toy' problem, but the fundamentals of classification of images is here.

# %% [markdown]
# ## Hints, tips, and notes
#
# * Here I'm not going to mandate TensorBoard. In Colab, this is a little bit more involved. Instead, we'll just put the losses and accuracies in a list and print them after training. However, TensorBoard is very useful, particularly for projects, so I suggest playing around with it.
# * Some of these runs will take several minutes to complete. This is the nature of ML. Grab a beer, or a coffee.
#
# As usual, we will give you some code that you use to build the rest of the activity.

# %% [markdown]
# # Common Code

# %% [markdown]
# All the imports

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Normalize, transforms
from torchsummary import summary
import matplotlib.pyplot as plt
from torchvision import models

# %% [markdown]
# ### 1. Select the device to use.
#
# To access the GPU on Google Colab, `Select Runtime` -> `Change Runtime Type` and pick `GPU` from the `Hardware Accelerator` dropdown menu. In the free version, the GPU is modest. If you buy credits, you get access to a much nice A100 GPU. In both cases, you may find contention for the resource is an issue, but less likely to happen if you use credits.

# %%
# Get appropriate device for training
device = ( "cuda"     # CUDA is a programming interface for certain Nvidia GPUs
           if torch.cuda.is_available()
           else "mps"  # Kind of like CUDA for a mac, I guess? I don't use macs
           if torch.backends.mps.is_available()
           else "cpu" )   # If you end up with CPU, go use Google Colab and get a GPU

print(f"{device} device available")
# Out:
# cuda device available

# %% [markdown]
# ### 2. Code for training the models
#
# I'm going to provide this code, rather than you having to struggle creating it. This is a normal training cycle with PyTorch. However, I do want you to explain the PyTorch functions called in the train function. I will marke them with comments.

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()        #<--- what is this function for?
                         # used to place the model in training mode

    for batch, (X, y) in enumerate(dataloader):
        # print(type(X))
        X, y = X.to(device), y.to(device)   #<--- this is a bit funny, explain it
                                            # Moving the input data to the GPU/CPU device we are using for efficient computation
        # Compute prediction error
        pred = model(X)                     #<--- what is this for?
                                            # predicting the results for the input provided
        loss = loss_fn(pred, y)             #<--- what is this for?
                                            # difference between outputs and true labels are calculated as loss. How far off is the predicted result from the expected results

        # This is the backprop set up. Explain what each of the steps do
        loss.backward()                     #<--- what is this for?
                                            # does the backward pass calculate the gradients that will direct the learning. Using the gradients it changes the weightes nad baises to reduce the loss
        optimizer.step()                    #<--- what is this for?
                                            # based on the optimizer(driving the learning) defined, one learning step is performed, here the gradients from the backward call made above are used to move the learning weights to reduce the loss
        optimizer.zero_grad()               #<--- what is this for?
                                            # gradients accumulated over each batch is reset else the gradients would keep accuumulating and provide incorrect values and learning would be incorrect

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    loss, accuracy = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss += loss_fn(pred, y).item()
            accuracy += (pred.argmax(1) == y).type(torch.float).sum().item()
    loss /= num_batches
    accuracy /= size

    return loss, accuracy

def train_loop(train_dataloader, test_dataloader, model, loss_fn, optimizer, epochs):
    train_loss = []
    train_accuracy = []
    test_loss = []
    test_accuracy = []

    # Iterate over each epoch
    for t in range(epochs):
        print(f"Epoch {t+1}:\n")
        train(train_dataloader, model, loss_fn, optimizer)

        # Get the overall loss and accuracy for both train and test datasets
        tr_loss, tr_acc = test(train_dataloader, model, loss_fn)
        ts_loss, ts_acc = test(test_dataloader, model, loss_fn)

        print(f"Train Error: \n Accuracy: {(100*tr_acc):>0.1f}%, Avg loss: {tr_loss:>8f} \n")
        print(f"Test Error: \n Accuracy: {(100*ts_acc):>0.1f}%, Avg loss: {ts_loss:>8f} \n")

        # Store and return the losses and accuracies. We can graph these later
        train_loss = train_loss + [tr_loss]
        train_accuracy = train_accuracy + [tr_acc]
        test_loss = test_loss + [ts_loss]
        test_accuracy = test_accuracy + [ts_acc]

    print("Done training!")
    return train_loss, train_accuracy, test_loss, test_accuracy

# %% [markdown]
# ### <font color='red'>Your input here.</font>
# <font color='red'>Enter you description of the above parts:</font>

# %% [markdown]
# ### 3. Load the data
#
# 1. Load the Fashion-MNIST dataset using `torchvision`'s `datasets` library (e.g., [`datasets.FashionMNIST...`](https://pytorch.org/vision/stable/generated/torchvision.datasets.FashionMNIST.html)...)
# 2. When loading the data, convert it to tensor format ([`transforms.ToTensor`](https://pytorch.org/vision/stable/generated/torchvision.transforms.ToTensor.html)), and apply the standard scaler to the data (using [`transforms.Normalize`](https://pytorch.org/vision/main/generated/torchvision.transforms.Normalize.html)). Use the [`transforms.Resize`](https://pytorch.org/vision/main/generated/torchvision.transforms.Resize.html) transform to turn it into a 28x28 image rather than a 784-vector
#     * Rather than loading the data, and caluclating the mean and std, you can use the values `mean = 0.2859` and `std = 0.3530`. I pre-calculated these for you!
# 3. Create the [`DataLoader`](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)s. Here we're going to use a batch size of 64.
# 4. Display a few examples of the dataset - this is always a good idea to make sure the data has loaded correctly
#
# We haven't really touched on batch size yet, because up to now we have used plain old gradient descent. Later on, we will use the Adam optimiser, because it is quicker and uses less memory. But Adam is a mini-batch optimizer, and you have to pick that mini-batch size. Bit more info on this, if you are interested:
#  * https://sebastianraschka.com/faq/docs/gradient-optimization.html
#  * https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/
#
# We need to set the batch size when we create the dataloaders.

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
##############################
# Your code below

import numpy as np

# defining a transform to normalize and resize the data
transform = transforms.Compose([transforms.Resize((28,28)),
                                transforms.ToTensor(),
                                transforms.Normalize((0.2859,), (0.3530))])

# downloading the data(train and test)
train_dataset = datasets.FashionMNIST('./data', train = True, download = True, transform = transform)
# note the use of train = False to denote the download of test data
test_dataset = datasets.FashionMNIST('./data', train = False, download = True, transform = transform)

# print("train data set is ", train_dataset ,"end")
batch_size = 64
# defining a dataloader for train and test with batch size of 64 as required
train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True, num_workers = 2)
test_loader = DataLoader(test_dataset, batch_size = batch_size, shuffle = False, num_workers = 2)

# forming a map for prining later
class_labels = {0: 'T-shirt/top', 1: 'Trouser', 2: 'Pullover', 3: 'Dress', 4: 'Coat',
                5: 'Sandal', 6: 'Shirt', 7: 'Sneaker', 8: 'Bag', 9: 'Ankle boot'}


# below obtained from the material provided
def imshow(img):
  img = img / 2 + 0.5 # unnormalize
  npimg = img.numpy ()
  plt.imshow (np.transpose(npimg, (1, 2, 0)))

# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.__next__()

import torchvision
# show 4 images with its labels
imshow (torchvision.utils.make_grid(images[:4]))
print(' '. join('%5s' % class_labels[labels[j].item()] for j in range(4)))
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:02<00:00, 10733530.72it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 173845.78it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 3187483.28it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 18129535.68it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# T-shirt/top Pullover Shirt Sneaker

# %% [markdown]
# ---
# ## 1. Replicate the Neural Network from the previous tasks for the FashionMNIST dataset
# ---
#
#
# In the previous activity, you designed a fully connected neural network (a multi-layer perceptron) to predict on Fashion-MNIST.
#
# 1. Replicate the best network that you found in that activity, but in PyTorch.
# 1. Use [`summary`](https://pypi.org/project/torch-summary/) to display a summary of your model.
# 1. Use some random inputs to test the model. This will be meaningless, as the model is not trained yet (and the inputs are random). However, it is useful to test that you have defined the model at leats without any coding errors.
#
# Hints and notes:
#  * We need to [`Flatten`](https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html) the incoming data. In the previous step, you loaded the dataset as a 28x28 image (because, later on we will be using CNNs that require image inputs). However, fully connected layers require vector inputs. `nn.Flatten` converts the image input to a vector (i.e., a 28x28 image to a 784 vector).
#  * Use [`.to(device)`](https://pytorch.org/docs/stable/generated/torch.Tensor.to.html) to "send" objects to the GPU (if you have one). E.g., once you define your class for the neural network, you will create an instance of that NN - you need to send this object to the GPU.
#  * Generally, at inference time, we will use a [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.Softmax.html) on the output of the model. Prior to the softmax, the model outputs a score per class. That is, there will be 10 outputs. However, here we will ignore the softmax part.

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
##############################
# Your code below

'''Define model called Neural network that takes in 784 input parameters
   and uses 3 hidden layers of size 100, 100 and 50 and applies ReLU after each
   fully connected layer and produces an output layer of 10'''
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(784, 100) # 100, 100, 50 relu after each linear
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(100, 100)
        self.fc3 = nn.Linear(100, 50)
        self.fc4 = nn.Linear(50, 10)

    def forward(self, x):
        out = self.flatten(x)
        # print(out)
        out = self.fc1(out)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.fc3(out)
        out = self.relu(out)
        out = self.fc4(out)
        return out

# moving it to the device(GPU) selected above
model = NeuralNetwork().to(device)
summary(model, (1,28*28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                  [-1, 100]          78,500
#               ReLU-3                  [-1, 100]               0
#             Linear-4                  [-1, 100]          10,100
#               ReLU-5                  [-1, 100]               0
#             Linear-6                   [-1, 50]           5,050
#               ReLU-7                   [-1, 50]               0
#             Linear-8                   [-1, 10]             510
# ================================================================
# Total params: 94,160
# Trainable params: 94,160
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.36
# Estimated Total Size (MB): 0.37
# ----------------------------------------------------------------

# %% [markdown]
# Now train the model.
#
# We will use [Cross Entropy Loss](https://towardsdatascience.com/cross-entropy-loss-function-f38c4ec8643e), and as discussed, the Adam optimiser (with learning rate = 0.001).
#
# * Call the training loop - I would suggest a max of ~20 epochs
# * Use matplotlib to plot the train and test loss, and the train and test accuracy
# * Describe what you see in the graphs
#
# This training could take a few minutes. But note how you will see a bunch of losses reported in each epoch? These are the mini-batches in Adam that we discussed before. Then there will be an overall Train and Test error reported for the Epoch.

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
def Train_model(train_loader, test_loader, model):
  # Define the loss function and the Adam optimizer with a learning rate of 0.001
  loss_fn = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
  # Note, replace model with the instance name of your model

  ##############################
  # Your code below
  epochs = 20
  train_loss, train_accuracy, test_loss, test_accuracy = train_loop(train_loader, test_loader, model, loss_fn, optimizer, epochs)
  return train_loss, train_accuracy, test_loss, test_accuracy

# %%
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.284388  [   64/60000]
# loss: 0.595560  [ 6464/60000]
# loss: 0.467041  [12864/60000]
# loss: 0.431289  [19264/60000]
# loss: 0.406511  [25664/60000]
# loss: 0.306850  [32064/60000]
# loss: 0.544876  [38464/60000]
# loss: 0.521935  [44864/60000]
# loss: 0.390816  [51264/60000]
# loss: 0.229429  [57664/60000]
# Train Error:
#  Accuracy: 84.1%, Avg loss: 0.421538
#
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.464013
#
# Epoch 2:
#
# loss: 0.305858  [   64/60000]
# loss: 0.511443  [ 6464/60000]
# loss: 0.393022  [12864/60000]
# loss: 0.459787  [19264/60000]
# loss: 0.270652  [25664/60000]
# loss: 0.339316  [32064/60000]
# loss: 0.215400  [38464/60000]
# loss: 0.452787  [44864/60000]
# loss: 0.395685  [51264/60000]
# loss: 0.354080  [57664/60000]
# Train Error:
#  Accuracy: 88.0%, Avg loss: 0.321919
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.374852
#
# Epoch 3:
#
# loss: 0.412515  [   64/60000]
# loss: 0.395478  [ 6464/60000]
# loss: 0.349502  [12864/60000]
# loss: 0.336994  [19264/60000]
# loss: 0.440962  [25664/60000]
# loss: 0.261035  [32064/60000]
# loss: 0.480996  [38464/60000]
# loss: 0.228120  [44864/60000]
# loss: 0.207530  [51264/60000]
# loss: 0.239746  [57664/60000]
# Train Error:
#  Accuracy: 89.0%, Avg loss: 0.300813
#
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.362605
#
# Epoch 4:
#
# loss: 0.306474  [   64/60000]
# loss: 0.325084  [ 6464/60000]
# loss: 0.423120  [12864/60000]
# loss: 0.301281  [19264/60000]
# loss: 0.474403  [25664/60000]
# loss: 0.433849  [32064/60000]
# loss: 0.269756  [38464/60000]
# loss: 0.435307  [44864/60000]
# loss: 0.260774  [51264/60000]
# loss: 0.220387  [57664/60000]
# Train Error:
#  Accuracy: 89.3%, Avg loss: 0.283456
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.357137
#
# Epoch 5:
#
# loss: 0.252278  [   64/60000]
# loss: 0.227773  [ 6464/60000]
# loss: 0.349675  [12864/60000]
# loss: 0.238315  [19264/60000]
# loss: 0.290961  [25664/60000]
# loss: 0.483072  [32064/60000]
# loss: 0.206731  [38464/60000]
# loss: 0.232644  [44864/60000]
# loss: 0.174603  [51264/60000]
# loss: 0.081131  [57664/60000]
# Train Error:
#  Accuracy: 90.6%, Avg loss: 0.254584
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.332309
#
# Epoch 6:
#
# loss: 0.142313  [   64/60000]
# loss: 0.130959  [ 6464/60000]
# loss: 0.252925  [12864/60000]
# loss: 0.360050  [19264/60000]
# loss: 0.330135  [25664/60000]
# loss: 0.214439  [32064/60000]
# loss: 0.309466  [38464/60000]
# loss: 0.137169  [44864/60000]
# loss: 0.234686  [51264/60000]
# loss: 0.247423  [57664/60000]
# Train Error:
#  Accuracy: 90.8%, Avg loss: 0.247092
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.338429
#
# Epoch 7:
#
# loss: 0.157973  [   64/60000]
# loss: 0.221607  [ 6464/60000]
# loss: 0.393095  [12864/60000]
# loss: 0.155328  [19264/60000]
# loss: 0.235420  [25664/60000]
# loss: 0.171458  [32064/60000]
# loss: 0.223757  [38464/60000]
# loss: 0.289191  [44864/60000]
# loss: 0.272428  [51264/60000]
# loss: 0.210205  [57664/60000]
# Train Error:
#  Accuracy: 91.5%, Avg loss: 0.226958
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.330726
#
# Epoch 8:
#
# loss: 0.300361  [   64/60000]
# loss: 0.267618  [ 6464/60000]
# loss: 0.301615  [12864/60000]
# loss: 0.219343  [19264/60000]
# loss: 0.316931  [25664/60000]
# loss: 0.150193  [32064/60000]
# loss: 0.157630  [38464/60000]
# loss: 0.261858  [44864/60000]
# loss: 0.135515  [51264/60000]
# loss: 0.299593  [57664/60000]
# Train Error:
#  Accuracy: 91.5%, Avg loss: 0.224750
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.343717
#
# Epoch 9:
#
# loss: 0.278884  [   64/60000]
# loss: 0.249629  [ 6464/60000]
# loss: 0.264371  [12864/60000]
# loss: 0.154076  [19264/60000]
# loss: 0.322355  [25664/60000]
# loss: 0.154254  [32064/60000]
# loss: 0.162465  [38464/60000]
# loss: 0.249087  [44864/60000]
# loss: 0.081027  [51264/60000]
# loss: 0.121496  [57664/60000]
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.208907
#
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.332946
#
# Epoch 10:
#
# loss: 0.154026  [   64/60000]
# loss: 0.083108  [ 6464/60000]
# loss: 0.223770  [12864/60000]
# loss: 0.228290  [19264/60000]
# loss: 0.216673  [25664/60000]
# loss: 0.152438  [32064/60000]
# loss: 0.128591  [38464/60000]
# loss: 0.197422  [44864/60000]
# loss: 0.098673  [51264/60000]
# loss: 0.281619  [57664/60000]
# Train Error:
#  Accuracy: 92.0%, Avg loss: 0.206473
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.336539
#
# Epoch 11:
#
# loss: 0.169373  [   64/60000]
# loss: 0.367835  [ 6464/60000]
# loss: 0.074577  [12864/60000]
# loss: 0.315587  [19264/60000]
# loss: 0.143573  [25664/60000]
# loss: 0.181950  [32064/60000]
# loss: 0.175995  [38464/60000]
# loss: 0.142092  [44864/60000]
# loss: 0.175268  [51264/60000]
# loss: 0.291576  [57664/60000]
# Train Error:
#  Accuracy: 91.9%, Avg loss: 0.212063
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.352130
#
# Epoch 12:
#
# loss: 0.283513  [   64/60000]
# loss: 0.085744  [ 6464/60000]
# loss: 0.170043  [12864/60000]
# loss: 0.171305  [19264/60000]
# loss: 0.168300  [25664/60000]
# loss: 0.146980  [32064/60000]
# loss: 0.247005  [38464/60000]
# loss: 0.148506  [44864/60000]
# loss: 0.244202  [51264/60000]
# loss: 0.149197  [57664/60000]
# Train Error:
#  Accuracy: 92.8%, Avg loss: 0.187952
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.347096
#
# Epoch 13:
#
# loss: 0.201359  [   64/60000]
# loss: 0.096973  [ 6464/60000]
# loss: 0.237250  [12864/60000]
# loss: 0.190191  [19264/60000]
# loss: 0.150164  [25664/60000]
# loss: 0.255540  [32064/60000]
# loss: 0.088906  [38464/60000]
# loss: 0.129064  [44864/60000]
# loss: 0.282830  [51264/60000]
# loss: 0.131285  [57664/60000]
# Train Error:
#  Accuracy: 92.7%, Avg loss: 0.188843
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.355701
#
# Epoch 14:
#
# loss: 0.176036  [   64/60000]
# loss: 0.252527  [ 6464/60000]
# loss: 0.233579  [12864/60000]
# loss: 0.284946  [19264/60000]
# loss: 0.117716  [25664/60000]
# loss: 0.163589  [32064/60000]
# loss: 0.128452  [38464/60000]
# loss: 0.282543  [44864/60000]
# loss: 0.172930  [51264/60000]
# loss: 0.290026  [57664/60000]
# Train Error:
#  Accuracy: 93.3%, Avg loss: 0.175811
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.344743
#
# Epoch 15:
#
# loss: 0.127160  [   64/60000]
# loss: 0.152222  [ 6464/60000]
# loss: 0.178905  [12864/60000]
# loss: 0.189108  [19264/60000]
# loss: 0.158101  [25664/60000]
# loss: 0.157386  [32064/60000]
# loss: 0.109152  [38464/60000]
# loss: 0.090989  [44864/60000]
# loss: 0.109240  [51264/60000]
# loss: 0.200053  [57664/60000]
# Train Error:
#  Accuracy: 93.5%, Avg loss: 0.172493
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.346695
#
# Epoch 16:
#
# loss: 0.151923  [   64/60000]
# loss: 0.126281  [ 6464/60000]
# loss: 0.099779  [12864/60000]
# loss: 0.155456  [19264/60000]
# loss: 0.340842  [25664/60000]
# loss: 0.162737  [32064/60000]
# loss: 0.248431  [38464/60000]
# loss: 0.106974  [44864/60000]
# loss: 0.228980  [51264/60000]
# loss: 0.169235  [57664/60000]
# Train Error:
#  Accuracy: 93.9%, Avg loss: 0.159362
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.361179
#
# Epoch 17:
#
# loss: 0.146982  [   64/60000]
# loss: 0.256490  [ 6464/60000]
# loss: 0.168167  [12864/60000]
# loss: 0.180420  [19264/60000]
# loss: 0.218591  [25664/60000]
# loss: 0.149905  [32064/60000]
# loss: 0.203748  [38464/60000]
# loss: 0.200957  [44864/60000]
# loss: 0.199239  [51264/60000]
# loss: 0.171289  [57664/60000]
# Train Error:
#  Accuracy: 94.1%, Avg loss: 0.155405
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.345876
#
# Epoch 18:
#
# loss: 0.130803  [   64/60000]
# loss: 0.054933  [ 6464/60000]
# loss: 0.159150  [12864/60000]
# loss: 0.131822  [19264/60000]
# loss: 0.103214  [25664/60000]
# loss: 0.089907  [32064/60000]
# loss: 0.075101  [38464/60000]
# loss: 0.273402  [44864/60000]
# loss: 0.178731  [51264/60000]
# loss: 0.128556  [57664/60000]
# Train Error:
#  Accuracy: 94.5%, Avg loss: 0.144534
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.363908
#
# Epoch 19:
#
# loss: 0.260449  [   64/60000]
# loss: 0.118851  [ 6464/60000]
# loss: 0.277975  [12864/60000]
# loss: 0.106386  [19264/60000]
# loss: 0.220594  [25664/60000]
# loss: 0.150453  [32064/60000]
# loss: 0.132603  [38464/60000]
# loss: 0.176390  [44864/60000]
# loss: 0.191689  [51264/60000]
# loss: 0.104938  [57664/60000]
# Train Error:
#  Accuracy: 93.8%, Avg loss: 0.159792
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.403403
#
# Epoch 20:
#
# loss: 0.148588  [   64/60000]
# loss: 0.191696  [ 6464/60000]
# loss: 0.130136  [12864/60000]
# loss: 0.102943  [19264/60000]
# loss: 0.243606  [25664/60000]
# loss: 0.157980  [32064/60000]
# loss: 0.092410  [38464/60000]
# loss: 0.123651  [44864/60000]
# loss: 0.166806  [51264/60000]
# loss: 0.194493  [57664/60000]
# Train Error:
#  Accuracy: 94.3%, Avg loss: 0.148506
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.393536
#
# Done training!

# %%
# defining function for later use
def plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy) :
  train_loss_percent = [loss * 100 for loss in train_loss]
  test_loss_percent = [loss * 100 for loss in test_loss]
  train_accuracy_percent = [acc * 100 for acc in train_accuracy]
  test_accuracy_percent = [acc * 100 for acc in test_accuracy]

  # Plotting the training and testing loss
  plt.figure(figsize=(10,5))
  plt.subplot(1,2,1)
  plt.title("Training and Testing Loss over Epochs")
  plt.plot(range(1,len(train_loss) + 1), train_loss_percent, label="Train")
  plt.plot(range(1,len(test_loss) + 1), test_loss_percent, label="Test")
  plt.xlabel("Epochs")
  plt.ylabel("Loss(%)")
  plt.xticks(range(1, len(train_loss) + 1, 2))
  plt.legend()

  # Plotting the training and testing accuracy
  plt.subplot(1,2,2)
  plt.title("Training and Testing Accuracy over Epochs")
  plt.plot(range(1,len(train_accuracy) + 1), train_accuracy_percent, label="Train")
  plt.plot(range(1,len(test_accuracy) + 1), test_accuracy_percent, label="Test")
  plt.grid()
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy(%)")
  plt.legend()
  plt.xticks(range(1, len(train_accuracy) + 1, 2))
  plt.tight_layout()
  plt.show()

# %%
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# <span style="color:green"> The graphs show training and test loss over the 20 epochs and the accuracy of test and train. Both the training and test loss decrease for initial few epochs, and then we see a divergence in behaviour of the loss between the test and train. While the train loss does decrease with a slope the test loss seems to fall initially but then start to rise. This implies there is the model is overfitting the data using the train data.
#
# On the right we see the train and test accuracy plotted. The graph shows a steady rise in accuracy for the initial few epochs, then the train accuracy does increase, however, the rise in test accuracy declines after 5 epochs. The maximum test accuracy I can observe with the model described above is 88.9% and the train accuracy is 94.5%. This wide gap in the test and train accuracy shows overfitting.</span>

# %% [markdown]
# ---
#
# # 2. Replicate LeNet-5 for Fashion-MNIST
#
# ---
#
#
# Below is the LeNet architecture (from https://en.wikipedia.org/wiki/LeNet). If you search on the internet, you will find slightly different implementations and descriptions of LeNet-5, but below is what was actually in LeCun's [original paper](https://ieeexplore.ieee.org/document/726791). Of course, LeCun was applying this to the digit recognition problem (MNIST), but we are looking at Fashion-MNIST.
#
#  * Create the model in PyTorch.
#  * Train the model using the same parameters as above, and plot the loss and accuracy.
#  * Discuss and compare (in a markdown cell) with the fully connected model above. Particularly consider - number of parameters, performance, and overfitting?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
##############################
# Your code below

import torch.nn as nn
import torch.nn.functional as F

# PyTorch models inherit from torch.nn.Module
class LeNet5 (nn.Module):
  def __init__(self):
    super(LeNet5, self).__init__()
    # define first convolution with 6 output and 5 * 5 filters(kernels) and padding = 2
    self.conv1 = nn.Conv2d(1, 6, 5, padding=2)
    # define sigmoid function
    self.sigmoid = nn.Sigmoid()
    # define flatten
    self.flatten = nn.Flatten()
    # using average pooling
    self.pool = nn.AvgPool2d(2, 2)
    # define 2nd convolution with 6 inputs(output from the previous layer) and 5 * 5 kernels
    self.conv2 = nn.Conv2d(6, 16, 5)
    # defining fully connected layer 1
    self.fc1 = nn.Linear(5*5*16, 120)
    # defining fully connected layer 2 taking 120 input(output from the previous) and forming 84 outputs
    self.fc2 = nn.Linear(120, 84)
    # defining fully connected layer 2 taking 84 input(output from the previous) and forming 10 outputs
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    # convolve with 5 x 5 kernel and padding 2
    x = self.conv1(x)
    # apply sigmoid activation function as described in the question
    x = self.sigmoid(x)
    # using average pooling as is used in LeNet5
    x = self.pool(x)

    # 2nd convolution with 5 x 5 kernel
    x = self.conv2(x)
    # apply sigmoid activation function as described in the question
    x = self.sigmoid(x)
    # using average pooling as is used in LeNet5
    x = self.pool(x)

    # flatten before moving it to fully connected layers since they expect a 1D input
    x = self.flatten(x)
    x = self.fc1(x)
    # applying sigmoid activation between fully connected layers
    x = self.sigmoid(x)
    x = self.fc2(x)
    x = self.sigmoid(x)
    x = self.fc3(x)
    return x

model = LeNet5().to(device)
summary(model, (1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#            Sigmoid-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#            Sigmoid-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#            Flatten-7                  [-1, 400]               0
#             Linear-8                  [-1, 120]          48,120
#            Sigmoid-9                  [-1, 120]               0
#            Linear-10                   [-1, 84]          10,164
#           Sigmoid-11                   [-1, 84]               0
#            Linear-12                   [-1, 10]             850
# ================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.24
# Estimated Total Size (MB): 0.35
# ----------------------------------------------------------------

# %%
# calling the train loop
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.379992  [   64/60000]
# loss: 1.851085  [ 6464/60000]
# loss: 1.235602  [12864/60000]
# loss: 0.990789  [19264/60000]
# loss: 0.959769  [25664/60000]
# loss: 0.950894  [32064/60000]
# loss: 0.802555  [38464/60000]
# loss: 0.536476  [44864/60000]
# loss: 0.609443  [51264/60000]
# loss: 0.626273  [57664/60000]
# Train Error:
#  Accuracy: 75.2%, Avg loss: 0.665704
#
# Test Error:
#  Accuracy: 74.5%, Avg loss: 0.685291
#
# Epoch 2:
#
# loss: 0.625382  [   64/60000]
# loss: 0.811724  [ 6464/60000]
# loss: 0.638781  [12864/60000]
# loss: 0.609995  [19264/60000]
# loss: 0.671372  [25664/60000]
# loss: 0.658901  [32064/60000]
# loss: 0.521809  [38464/60000]
# loss: 0.713878  [44864/60000]
# loss: 0.499793  [51264/60000]
# loss: 0.521507  [57664/60000]
# Train Error:
#  Accuracy: 78.8%, Avg loss: 0.556584
#
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.578455
#
# Epoch 3:
#
# loss: 0.411249  [   64/60000]
# loss: 0.442355  [ 6464/60000]
# loss: 0.533544  [12864/60000]
# loss: 0.601855  [19264/60000]
# loss: 0.451710  [25664/60000]
# loss: 0.688161  [32064/60000]
# loss: 0.677438  [38464/60000]
# loss: 0.607016  [44864/60000]
# loss: 0.711127  [51264/60000]
# loss: 0.519509  [57664/60000]
# Train Error:
#  Accuracy: 81.4%, Avg loss: 0.491062
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 0.513084
#
# Epoch 4:
#
# loss: 0.492353  [   64/60000]
# loss: 0.377768  [ 6464/60000]
# loss: 0.415360  [12864/60000]
# loss: 0.476537  [19264/60000]
# loss: 0.534914  [25664/60000]
# loss: 0.407598  [32064/60000]
# loss: 0.377616  [38464/60000]
# loss: 0.352923  [44864/60000]
# loss: 0.650057  [51264/60000]
# loss: 0.410551  [57664/60000]
# Train Error:
#  Accuracy: 83.7%, Avg loss: 0.447211
#
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.473593
#
# Epoch 5:
#
# loss: 0.294616  [   64/60000]
# loss: 0.430239  [ 6464/60000]
# loss: 0.570883  [12864/60000]
# loss: 0.328677  [19264/60000]
# loss: 0.286385  [25664/60000]
# loss: 0.535245  [32064/60000]
# loss: 0.528763  [38464/60000]
# loss: 0.475864  [44864/60000]
# loss: 0.422239  [51264/60000]
# loss: 0.292190  [57664/60000]
# Train Error:
#  Accuracy: 84.0%, Avg loss: 0.429793
#
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.457545
#
# Epoch 6:
#
# loss: 0.376132  [   64/60000]
# loss: 0.466800  [ 6464/60000]
# loss: 0.248476  [12864/60000]
# loss: 0.487515  [19264/60000]
# loss: 0.312119  [25664/60000]
# loss: 0.378314  [32064/60000]
# loss: 0.550075  [38464/60000]
# loss: 0.389094  [44864/60000]
# loss: 0.348556  [51264/60000]
# loss: 0.475094  [57664/60000]
# Train Error:
#  Accuracy: 85.3%, Avg loss: 0.396517
#
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.425364
#
# Epoch 7:
#
# loss: 0.471545  [   64/60000]
# loss: 0.490151  [ 6464/60000]
# loss: 0.471399  [12864/60000]
# loss: 0.433113  [19264/60000]
# loss: 0.539983  [25664/60000]
# loss: 0.225470  [32064/60000]
# loss: 0.258248  [38464/60000]
# loss: 0.273189  [44864/60000]
# loss: 0.418983  [51264/60000]
# loss: 0.289281  [57664/60000]
# Train Error:
#  Accuracy: 85.6%, Avg loss: 0.391988
#
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.427580
#
# Epoch 8:
#
# loss: 0.319638  [   64/60000]
# loss: 0.399243  [ 6464/60000]
# loss: 0.364933  [12864/60000]
# loss: 0.367204  [19264/60000]
# loss: 0.480007  [25664/60000]
# loss: 0.505885  [32064/60000]
# loss: 0.336888  [38464/60000]
# loss: 0.370676  [44864/60000]
# loss: 0.356422  [51264/60000]
# loss: 0.375621  [57664/60000]
# Train Error:
#  Accuracy: 85.5%, Avg loss: 0.389448
#
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.423743
#
# Epoch 9:
#
# loss: 0.411761  [   64/60000]
# loss: 0.294620  [ 6464/60000]
# loss: 0.356087  [12864/60000]
# loss: 0.305254  [19264/60000]
# loss: 0.281228  [25664/60000]
# loss: 0.459713  [32064/60000]
# loss: 0.216569  [38464/60000]
# loss: 0.490539  [44864/60000]
# loss: 0.369509  [51264/60000]
# loss: 0.296128  [57664/60000]
# Train Error:
#  Accuracy: 87.0%, Avg loss: 0.352757
#
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.386376
#
# Epoch 10:
#
# loss: 0.338424  [   64/60000]
# loss: 0.484040  [ 6464/60000]
# loss: 0.430391  [12864/60000]
# loss: 0.495262  [19264/60000]
# loss: 0.251642  [25664/60000]
# loss: 0.348381  [32064/60000]
# loss: 0.284295  [38464/60000]
# loss: 0.262546  [44864/60000]
# loss: 0.385680  [51264/60000]
# loss: 0.267654  [57664/60000]
# Train Error:
#  Accuracy: 86.9%, Avg loss: 0.349260
#
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.390284
#
# Epoch 11:
#
# loss: 0.347564  [   64/60000]
# loss: 0.286203  [ 6464/60000]
# loss: 0.414424  [12864/60000]
# loss: 0.318606  [19264/60000]
# loss: 0.257548  [25664/60000]
# loss: 0.548428  [32064/60000]
# loss: 0.333530  [38464/60000]
# loss: 0.314180  [44864/60000]
# loss: 0.365364  [51264/60000]
# loss: 0.266617  [57664/60000]
# Train Error:
#  Accuracy: 88.1%, Avg loss: 0.324705
#
# Test Error:
#  Accuracy: 86.3%, Avg loss: 0.364577
#
# Epoch 12:
#
# loss: 0.218117  [   64/60000]
# loss: 0.341386  [ 6464/60000]
# loss: 0.256104  [12864/60000]
# loss: 0.279745  [19264/60000]
# loss: 0.328212  [25664/60000]
# loss: 0.346314  [32064/60000]
# loss: 0.204752  [38464/60000]
# loss: 0.451615  [44864/60000]
# loss: 0.330540  [51264/60000]
# loss: 0.309372  [57664/60000]
# Train Error:
#  Accuracy: 88.0%, Avg loss: 0.325136
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.361085
#
# Epoch 13:
#
# loss: 0.406215  [   64/60000]
# loss: 0.287428  [ 6464/60000]
# loss: 0.217639  [12864/60000]
# loss: 0.480139  [19264/60000]
# loss: 0.222606  [25664/60000]
# loss: 0.416318  [32064/60000]
# loss: 0.386116  [38464/60000]
# loss: 0.205157  [44864/60000]
# loss: 0.381048  [51264/60000]
# loss: 0.524514  [57664/60000]
# Train Error:
#  Accuracy: 88.5%, Avg loss: 0.314308
#
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.354887
#
# Epoch 14:
#
# loss: 0.366904  [   64/60000]
# loss: 0.263742  [ 6464/60000]
# loss: 0.286114  [12864/60000]
# loss: 0.382545  [19264/60000]
# loss: 0.138352  [25664/60000]
# loss: 0.289713  [32064/60000]
# loss: 0.159191  [38464/60000]
# loss: 0.220993  [44864/60000]
# loss: 0.295438  [51264/60000]
# loss: 0.345015  [57664/60000]
# Train Error:
#  Accuracy: 88.9%, Avg loss: 0.300412
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.341212
#
# Epoch 15:
#
# loss: 0.369292  [   64/60000]
# loss: 0.277256  [ 6464/60000]
# loss: 0.228286  [12864/60000]
# loss: 0.254602  [19264/60000]
# loss: 0.239770  [25664/60000]
# loss: 0.269167  [32064/60000]
# loss: 0.208581  [38464/60000]
# loss: 0.221308  [44864/60000]
# loss: 0.203874  [51264/60000]
# loss: 0.378184  [57664/60000]
# Train Error:
#  Accuracy: 89.3%, Avg loss: 0.290400
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.333260
#
# Epoch 16:
#
# loss: 0.264822  [   64/60000]
# loss: 0.174180  [ 6464/60000]
# loss: 0.342939  [12864/60000]
# loss: 0.230068  [19264/60000]
# loss: 0.315292  [25664/60000]
# loss: 0.300757  [32064/60000]
# loss: 0.165492  [38464/60000]
# loss: 0.192282  [44864/60000]
# loss: 0.414082  [51264/60000]
# loss: 0.196190  [57664/60000]
# Train Error:
#  Accuracy: 89.0%, Avg loss: 0.294136
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.339842
#
# Epoch 17:
#
# loss: 0.241925  [   64/60000]
# loss: 0.210806  [ 6464/60000]
# loss: 0.394628  [12864/60000]
# loss: 0.226676  [19264/60000]
# loss: 0.377128  [25664/60000]
# loss: 0.384584  [32064/60000]
# loss: 0.253211  [38464/60000]
# loss: 0.378706  [44864/60000]
# loss: 0.354762  [51264/60000]
# loss: 0.328004  [57664/60000]
# Train Error:
#  Accuracy: 88.7%, Avg loss: 0.303126
#
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.348711
#
# Epoch 18:
#
# loss: 0.217385  [   64/60000]
# loss: 0.243872  [ 6464/60000]
# loss: 0.293657  [12864/60000]
# loss: 0.205887  [19264/60000]
# loss: 0.277548  [25664/60000]
# loss: 0.252362  [32064/60000]
# loss: 0.264528  [38464/60000]
# loss: 0.198670  [44864/60000]
# loss: 0.119789  [51264/60000]
# loss: 0.257379  [57664/60000]
# Train Error:
#  Accuracy: 89.4%, Avg loss: 0.283201
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.330782
#
# Epoch 19:
#
# loss: 0.209222  [   64/60000]
# loss: 0.373224  [ 6464/60000]
# loss: 0.174845  [12864/60000]
# loss: 0.565283  [19264/60000]
# loss: 0.190673  [25664/60000]
# loss: 0.335191  [32064/60000]
# loss: 0.273603  [38464/60000]
# loss: 0.335816  [44864/60000]
# loss: 0.255224  [51264/60000]
# loss: 0.314663  [57664/60000]
# Train Error:
#  Accuracy: 89.9%, Avg loss: 0.271844
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.319549
#
# Epoch 20:
#
# loss: 0.238745  [   64/60000]
# loss: 0.309005  [ 6464/60000]
# loss: 0.409812  [12864/60000]
# loss: 0.269328  [19264/60000]
# loss: 0.275914  [25664/60000]
# loss: 0.324553  [32064/60000]
# loss: 0.336163  [38464/60000]
# loss: 0.244333  [44864/60000]
# loss: 0.339964  [51264/60000]
# loss: 0.245521  [57664/60000]
# Train Error:
#  Accuracy: 89.6%, Avg loss: 0.277442
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.323593
#
# Done training!

# %%
# plotting the graph showing the Train and Test loss and accuracy
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# ### <font color='red'>Your text here.</font>
# <font color='red'>Enter your text descriptions in the cell below:</font>

# %% [markdown]
# <span style="color:green"> Here we find the graph of training and testing loss behaving similarly as the both are continuing their descent as the epochs progress. And due to this we get a better model without overfitting. However the accuracy doesnt seem to improve from the previous graphs. As shown on the plot of Train and Test accuracy, both continue their rise as the epochs progress and we can see the max test accuracy at 88.8% and the max train accuracy at 90.2%.
#
# This is due to the fact that the number of parameters(61706) trained here is much less than the previous case(94160). Also we have used Sigmoid as the activation function here and in the previous I had used a ReLU, which seems to be working really well for this problem(see below). This indicates the importance of using a better activation function. While in the previous example I used a better activation function I did not do any convolution or pooling, here I did do a couple of convolution and an average pooling after each convolution. This could also have led to the difference in the rate of overfitting as it is considerably less compared to the previous graph. </span>

# %% [markdown]
# ---
# # 3. Modernise LeNet
# ---
#
#
# Modernise LeNet. What are the preferred activation and pooling functions for modern CNNs?
#
# * Update LeNet with these newer functions.
# * Train using the same parameters as above.
# * Compare and discuss with the above using the normal discussion criteria

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>
#
# <font color='green'>An alternate way to implement LeNet5 using nn.Sequential and ReLU and Max Pooling which improves the accuracy</font>

# %%
##############################
# Your code below

import torch.nn as nn
import torch.nn.functional as F

# PyTorch models inherit from torch.nn.Module
class LeNet5_Morderized(nn.Module):
  def __init__(self):
    super(LeNet5_Morderized, self).__init__()
    self.flatten = nn.Flatten()
    '''implementing max pooling and using ReLU activation function
       resulted in greater test and train accuracy(based on trials).'''
    # applying the convolution and ReLU and MaxPooling in sequence for conv1 and conv2
    self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels=1,
                out_channels=6,
                kernel_size=5,
                stride=1,
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )
    self.conv2 = nn.Sequential(
            nn.Conv2d(6, 16, 5),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
    self.fc1 = nn.Linear(5*5*16, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    # applying the conv1
    x = self.conv1(x)
    # applying conv2 on the result of conv1
    x = self.conv2(x)
    # flatten the output of conv2 to (batch_size, 5*5*16)
    x = self.flatten(x)
    x = self.fc1(x)
    x = self.fc2(x)
    x = self.fc3(x)
    return x

model = LeNet5_Morderized().to(device)
summary(model, (1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               ReLU-2            [-1, 6, 28, 28]               0
#          MaxPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               ReLU-5           [-1, 16, 10, 10]               0
#          MaxPool2d-6             [-1, 16, 5, 5]               0
#            Flatten-7                  [-1, 400]               0
#             Linear-8                  [-1, 120]          48,120
#             Linear-9                   [-1, 84]          10,164
#            Linear-10                   [-1, 10]             850
# ================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.24
# Estimated Total Size (MB): 0.35
# ----------------------------------------------------------------

# %%
# calling the train loop
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.295954  [   64/60000]
# loss: 0.596198  [ 6464/60000]
# loss: 0.677904  [12864/60000]
# loss: 0.394692  [19264/60000]
# loss: 0.690481  [25664/60000]
# loss: 0.320751  [32064/60000]
# loss: 0.457055  [38464/60000]
# loss: 0.380589  [44864/60000]
# loss: 0.476552  [51264/60000]
# loss: 0.285838  [57664/60000]
# Train Error:
#  Accuracy: 85.2%, Avg loss: 0.402773
#
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.435256
#
# Epoch 2:
#
# loss: 0.553656  [   64/60000]
# loss: 0.245080  [ 6464/60000]
# loss: 0.533624  [12864/60000]
# loss: 0.575278  [19264/60000]
# loss: 0.245438  [25664/60000]
# loss: 0.208109  [32064/60000]
# loss: 0.359926  [38464/60000]
# loss: 0.190952  [44864/60000]
# loss: 0.353078  [51264/60000]
# loss: 0.103919  [57664/60000]
# Train Error:
#  Accuracy: 88.6%, Avg loss: 0.312921
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.349149
#
# Epoch 3:
#
# loss: 0.346930  [   64/60000]
# loss: 0.243224  [ 6464/60000]
# loss: 0.282605  [12864/60000]
# loss: 0.509799  [19264/60000]
# loss: 0.226199  [25664/60000]
# loss: 0.375861  [32064/60000]
# loss: 0.378432  [38464/60000]
# loss: 0.313343  [44864/60000]
# loss: 0.408694  [51264/60000]
# loss: 0.347687  [57664/60000]
# Train Error:
#  Accuracy: 88.6%, Avg loss: 0.312224
#
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.353498
#
# Epoch 4:
#
# loss: 0.386200  [   64/60000]
# loss: 0.192801  [ 6464/60000]
# loss: 0.262847  [12864/60000]
# loss: 0.290682  [19264/60000]
# loss: 0.322813  [25664/60000]
# loss: 0.193724  [32064/60000]
# loss: 0.215562  [38464/60000]
# loss: 0.278585  [44864/60000]
# loss: 0.243889  [51264/60000]
# loss: 0.277910  [57664/60000]
# Train Error:
#  Accuracy: 89.6%, Avg loss: 0.284517
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.332589
#
# Epoch 5:
#
# loss: 0.300536  [   64/60000]
# loss: 0.231955  [ 6464/60000]
# loss: 0.271448  [12864/60000]
# loss: 0.142176  [19264/60000]
# loss: 0.350831  [25664/60000]
# loss: 0.152232  [32064/60000]
# loss: 0.168486  [38464/60000]
# loss: 0.309896  [44864/60000]
# loss: 0.251909  [51264/60000]
# loss: 0.275418  [57664/60000]
# Train Error:
#  Accuracy: 90.5%, Avg loss: 0.257628
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.309138
#
# Epoch 6:
#
# loss: 0.243725  [   64/60000]
# loss: 0.299451  [ 6464/60000]
# loss: 0.183629  [12864/60000]
# loss: 0.214562  [19264/60000]
# loss: 0.368274  [25664/60000]
# loss: 0.173496  [32064/60000]
# loss: 0.219614  [38464/60000]
# loss: 0.453969  [44864/60000]
# loss: 0.200540  [51264/60000]
# loss: 0.259939  [57664/60000]
# Train Error:
#  Accuracy: 90.2%, Avg loss: 0.271605
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.332152
#
# Epoch 7:
#
# loss: 0.345206  [   64/60000]
# loss: 0.362790  [ 6464/60000]
# loss: 0.534334  [12864/60000]
# loss: 0.211937  [19264/60000]
# loss: 0.270867  [25664/60000]
# loss: 0.204195  [32064/60000]
# loss: 0.216488  [38464/60000]
# loss: 0.318925  [44864/60000]
# loss: 0.300542  [51264/60000]
# loss: 0.198653  [57664/60000]
# Train Error:
#  Accuracy: 90.9%, Avg loss: 0.250902
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.315898
#
# Epoch 8:
#
# loss: 0.164031  [   64/60000]
# loss: 0.295067  [ 6464/60000]
# loss: 0.220280  [12864/60000]
# loss: 0.340674  [19264/60000]
# loss: 0.182878  [25664/60000]
# loss: 0.343569  [32064/60000]
# loss: 0.143450  [38464/60000]
# loss: 0.273862  [44864/60000]
# loss: 0.113508  [51264/60000]
# loss: 0.458856  [57664/60000]
# Train Error:
#  Accuracy: 91.5%, Avg loss: 0.234146
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.301360
#
# Epoch 9:
#
# loss: 0.168406  [   64/60000]
# loss: 0.345423  [ 6464/60000]
# loss: 0.354276  [12864/60000]
# loss: 0.235418  [19264/60000]
# loss: 0.151667  [25664/60000]
# loss: 0.249897  [32064/60000]
# loss: 0.362717  [38464/60000]
# loss: 0.230314  [44864/60000]
# loss: 0.245944  [51264/60000]
# loss: 0.271853  [57664/60000]
# Train Error:
#  Accuracy: 91.4%, Avg loss: 0.236188
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.307549
#
# Epoch 10:
#
# loss: 0.239914  [   64/60000]
# loss: 0.165810  [ 6464/60000]
# loss: 0.246452  [12864/60000]
# loss: 0.214719  [19264/60000]
# loss: 0.250115  [25664/60000]
# loss: 0.216547  [32064/60000]
# loss: 0.372965  [38464/60000]
# loss: 0.174247  [44864/60000]
# loss: 0.323593  [51264/60000]
# loss: 0.234975  [57664/60000]
# Train Error:
#  Accuracy: 91.1%, Avg loss: 0.236280
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.308038
#
# Epoch 11:
#
# loss: 0.265340  [   64/60000]
# loss: 0.248806  [ 6464/60000]
# loss: 0.302710  [12864/60000]
# loss: 0.314922  [19264/60000]
# loss: 0.048803  [25664/60000]
# loss: 0.171230  [32064/60000]
# loss: 0.196194  [38464/60000]
# loss: 0.234847  [44864/60000]
# loss: 0.398519  [51264/60000]
# loss: 0.247541  [57664/60000]
# Train Error:
#  Accuracy: 91.1%, Avg loss: 0.238676
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.320275
#
# Epoch 12:
#
# loss: 0.197008  [   64/60000]
# loss: 0.222787  [ 6464/60000]
# loss: 0.137177  [12864/60000]
# loss: 0.334014  [19264/60000]
# loss: 0.289860  [25664/60000]
# loss: 0.218596  [32064/60000]
# loss: 0.133786  [38464/60000]
# loss: 0.250719  [44864/60000]
# loss: 0.399990  [51264/60000]
# loss: 0.202829  [57664/60000]
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.214459
#
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.294353
#
# Epoch 13:
#
# loss: 0.289124  [   64/60000]
# loss: 0.127158  [ 6464/60000]
# loss: 0.220829  [12864/60000]
# loss: 0.211724  [19264/60000]
# loss: 0.187704  [25664/60000]
# loss: 0.279041  [32064/60000]
# loss: 0.321487  [38464/60000]
# loss: 0.215376  [44864/60000]
# loss: 0.189741  [51264/60000]
# loss: 0.212193  [57664/60000]
# Train Error:
#  Accuracy: 91.7%, Avg loss: 0.224407
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.304349
#
# Epoch 14:
#
# loss: 0.153400  [   64/60000]
# loss: 0.204046  [ 6464/60000]
# loss: 0.209975  [12864/60000]
# loss: 0.189336  [19264/60000]
# loss: 0.241365  [25664/60000]
# loss: 0.224803  [32064/60000]
# loss: 0.160480  [38464/60000]
# loss: 0.308068  [44864/60000]
# loss: 0.423938  [51264/60000]
# loss: 0.156411  [57664/60000]
# Train Error:
#  Accuracy: 91.9%, Avg loss: 0.218886
#
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.301180
#
# Epoch 15:
#
# loss: 0.305202  [   64/60000]
# loss: 0.247794  [ 6464/60000]
# loss: 0.104249  [12864/60000]
# loss: 0.061055  [19264/60000]
# loss: 0.190578  [25664/60000]
# loss: 0.323376  [32064/60000]
# loss: 0.302692  [38464/60000]
# loss: 0.275779  [44864/60000]
# loss: 0.276169  [51264/60000]
# loss: 0.276547  [57664/60000]
# Train Error:
#  Accuracy: 92.6%, Avg loss: 0.202831
#
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.289847
#
# Epoch 16:
#
# loss: 0.154616  [   64/60000]
# loss: 0.133638  [ 6464/60000]
# loss: 0.230015  [12864/60000]
# loss: 0.096461  [19264/60000]
# loss: 0.301970  [25664/60000]
# loss: 0.135844  [32064/60000]
# loss: 0.139560  [38464/60000]
# loss: 0.257752  [44864/60000]
# loss: 0.242320  [51264/60000]
# loss: 0.173339  [57664/60000]
# Train Error:
#  Accuracy: 92.4%, Avg loss: 0.206717
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.299066
#
# Epoch 17:
#
# loss: 0.206435  [   64/60000]
# loss: 0.275057  [ 6464/60000]
# loss: 0.124701  [12864/60000]
# loss: 0.450775  [19264/60000]
# loss: 0.228033  [25664/60000]
# loss: 0.311130  [32064/60000]
# loss: 0.360076  [38464/60000]
# loss: 0.282491  [44864/60000]
# loss: 0.139831  [51264/60000]
# loss: 0.181617  [57664/60000]
# Train Error:
#  Accuracy: 91.6%, Avg loss: 0.224205
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.317954
#
# Epoch 18:
#
# loss: 0.369424  [   64/60000]
# loss: 0.159938  [ 6464/60000]
# loss: 0.217277  [12864/60000]
# loss: 0.153319  [19264/60000]
# loss: 0.096996  [25664/60000]
# loss: 0.286999  [32064/60000]
# loss: 0.319936  [38464/60000]
# loss: 0.263088  [44864/60000]
# loss: 0.292444  [51264/60000]
# loss: 0.158200  [57664/60000]
# Train Error:
#  Accuracy: 91.6%, Avg loss: 0.219397
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.311094
#
# Epoch 19:
#
# loss: 0.190204  [   64/60000]
# loss: 0.143546  [ 6464/60000]
# loss: 0.354225  [12864/60000]
# loss: 0.297163  [19264/60000]
# loss: 0.378012  [25664/60000]
# loss: 0.140881  [32064/60000]
# loss: 0.197009  [38464/60000]
# loss: 0.206398  [44864/60000]
# loss: 0.172057  [51264/60000]
# loss: 0.103018  [57664/60000]
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.210617
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.309571
#
# Epoch 20:
#
# loss: 0.235831  [   64/60000]
# loss: 0.315199  [ 6464/60000]
# loss: 0.305877  [12864/60000]
# loss: 0.165573  [19264/60000]
# loss: 0.181146  [25664/60000]
# loss: 0.234208  [32064/60000]
# loss: 0.207817  [38464/60000]
# loss: 0.148834  [44864/60000]
# loss: 0.155330  [51264/60000]
# loss: 0.197113  [57664/60000]
# Train Error:
#  Accuracy: 92.7%, Avg loss: 0.198488
#
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.294898
#
# Done training!

# %%
# plotting the train and test loss and accuracy
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# ### <font color='red'>Your text here.</font>
# <font color='red'>Enter your text descriptions in the cell below:</font>

# %% [markdown]
# <span style="color:green"> The mordernized LeNet 5 is an adaptation of the LeNet 5 model described above with the change in activation function to ReLU from the Sigmoid and the pooling from the Average pooling to MaxPooling. The training and test loss has had a considerable decrease in the first couple of epochs itself, compared to the previous where it took almost half the epoch size specified to reach the loss we obtained here. The initial test and train loss was also less here. Here we see number of parameters used for training are identical to the previous one(61706), however, we see there exist considerable overfitting compared to the above. The best test accuracy received here is 90% and train accuracy is 92.6%. Here as we can see the overfitting has increased compared to the previous, however, we see an increase in the test accuracy.</span>

# %% [markdown]
# ---
# # 4. Build your own CNN model
# ---
#
# Build your own classifier model - see can you break 90% accuracy. You can use LeNet as a basis if you like.
#
# With some networks I built, I could get 93 to 94% test accuracy.
#
# Some hints:
#  * not every convolutional layer needs a pooling layer afterwards
#  * Consider adding more layers (maybe more 3x3 layers is better than 1 5x5 layer?)
#  * But don't just bung loads of layers in there - you will end up overfitting badly
#  * Use a [batchnorm](https://towardsdatascience.com/batch-norm-explained-visually-how-it-works-and-why-neural-networks-need-it-b18919692739) after each convolutional layer. You get decent performance gains without adding many parameters
#  * Don't be afraid to get to a million or two parameters
#  * Have a look on Google to see what others are doing (you're going to do this anyway, right?). Don't just copy them, though, try to understand.
#
# Explain what you did that improved things for the classification and why they improved things.

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %%
##############################
# Your code below

import torch.nn as nn
import torch.nn.functional as F

# PyTorch models inherit from torch.nn.Module
class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.conv1 = nn.Conv2d(1, 16, 5, padding=2)

    self.pool = nn.MaxPool2d(2, 2)

    self.conv2 = nn.Conv2d(16, 32, 5, padding = 2)

    self.fc1 = nn.Linear(32*7*7, 10)



  def forward(self, x):
    x = self.pool(F.relu(self.conv1(x)))
    x = self.pool(F.relu(self.conv2(x)))

    x = x.view(-1, 32*7*7)
    x = self.fc1(x)
    return x

model = CNN().to(device)
summary(model, (1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 28, 28]             416
#          MaxPool2d-2           [-1, 16, 14, 14]               0
#             Conv2d-3           [-1, 32, 14, 14]          12,832
#          MaxPool2d-4             [-1, 32, 7, 7]               0
#             Linear-5                   [-1, 10]          15,690
# ================================================================
# Total params: 28,938
# Trainable params: 28,938
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.18
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.29
# ----------------------------------------------------------------

# %%
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.318772  [   64/60000]
# loss: 0.507422  [ 6464/60000]
# loss: 0.494984  [12864/60000]
# loss: 0.363311  [19264/60000]
# loss: 0.402517  [25664/60000]
# loss: 0.289994  [32064/60000]
# loss: 0.401751  [38464/60000]
# loss: 0.439598  [44864/60000]
# loss: 0.478492  [51264/60000]
# loss: 0.339236  [57664/60000]
# Train Error:
#  Accuracy: 88.8%, Avg loss: 0.313825
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.344453
#
# Epoch 2:
#
# loss: 0.254735  [   64/60000]
# loss: 0.166123  [ 6464/60000]
# loss: 0.208141  [12864/60000]
# loss: 0.213461  [19264/60000]
# loss: 0.353458  [25664/60000]
# loss: 0.227532  [32064/60000]
# loss: 0.279786  [38464/60000]
# loss: 0.216303  [44864/60000]
# loss: 0.210648  [51264/60000]
# loss: 0.154123  [57664/60000]
# Train Error:
#  Accuracy: 90.8%, Avg loss: 0.256498
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.298417
#
# Epoch 3:
#
# loss: 0.125618  [   64/60000]
# loss: 0.220829  [ 6464/60000]
# loss: 0.221441  [12864/60000]
# loss: 0.268027  [19264/60000]
# loss: 0.281232  [25664/60000]
# loss: 0.310502  [32064/60000]
# loss: 0.260289  [38464/60000]
# loss: 0.335422  [44864/60000]
# loss: 0.183991  [51264/60000]
# loss: 0.152845  [57664/60000]
# Train Error:
#  Accuracy: 91.7%, Avg loss: 0.231223
#
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.280469
#
# Epoch 4:
#
# loss: 0.313640  [   64/60000]
# loss: 0.277123  [ 6464/60000]
# loss: 0.084510  [12864/60000]
# loss: 0.248734  [19264/60000]
# loss: 0.158948  [25664/60000]
# loss: 0.357433  [32064/60000]
# loss: 0.131820  [38464/60000]
# loss: 0.511441  [44864/60000]
# loss: 0.318258  [51264/60000]
# loss: 0.255872  [57664/60000]
# Train Error:
#  Accuracy: 92.6%, Avg loss: 0.207896
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.263744
#
# Epoch 5:
#
# loss: 0.125892  [   64/60000]
# loss: 0.196057  [ 6464/60000]
# loss: 0.217440  [12864/60000]
# loss: 0.178583  [19264/60000]
# loss: 0.252504  [25664/60000]
# loss: 0.187136  [32064/60000]
# loss: 0.262066  [38464/60000]
# loss: 0.256741  [44864/60000]
# loss: 0.198097  [51264/60000]
# loss: 0.256054  [57664/60000]
# Train Error:
#  Accuracy: 92.6%, Avg loss: 0.202051
#
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.266841
#
# Epoch 6:
#
# loss: 0.214713  [   64/60000]
# loss: 0.208923  [ 6464/60000]
# loss: 0.248766  [12864/60000]
# loss: 0.195886  [19264/60000]
# loss: 0.075489  [25664/60000]
# loss: 0.098929  [32064/60000]
# loss: 0.301075  [38464/60000]
# loss: 0.368473  [44864/60000]
# loss: 0.199590  [51264/60000]
# loss: 0.193862  [57664/60000]
# Train Error:
#  Accuracy: 93.7%, Avg loss: 0.171880
#
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.253044
#
# Epoch 7:
#
# loss: 0.150280  [   64/60000]
# loss: 0.213041  [ 6464/60000]
# loss: 0.327345  [12864/60000]
# loss: 0.287870  [19264/60000]
# loss: 0.119722  [25664/60000]
# loss: 0.147893  [32064/60000]
# loss: 0.246472  [38464/60000]
# loss: 0.261633  [44864/60000]
# loss: 0.151144  [51264/60000]
# loss: 0.128634  [57664/60000]
# Train Error:
#  Accuracy: 93.5%, Avg loss: 0.173002
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.258200
#
# Epoch 8:
#
# loss: 0.125093  [   64/60000]
# loss: 0.231046  [ 6464/60000]
# loss: 0.212299  [12864/60000]
# loss: 0.156408  [19264/60000]
# loss: 0.194713  [25664/60000]
# loss: 0.214988  [32064/60000]
# loss: 0.085341  [38464/60000]
# loss: 0.127522  [44864/60000]
# loss: 0.170322  [51264/60000]
# loss: 0.083511  [57664/60000]
# Train Error:
#  Accuracy: 94.3%, Avg loss: 0.159766
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.254814
#
# Epoch 9:
#
# loss: 0.109453  [   64/60000]
# loss: 0.161199  [ 6464/60000]
# loss: 0.240201  [12864/60000]
# loss: 0.226706  [19264/60000]
# loss: 0.110938  [25664/60000]
# loss: 0.133586  [32064/60000]
# loss: 0.091332  [38464/60000]
# loss: 0.245516  [44864/60000]
# loss: 0.088309  [51264/60000]
# loss: 0.126355  [57664/60000]
# Train Error:
#  Accuracy: 95.0%, Avg loss: 0.142697
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.259472
#
# Epoch 10:
#
# loss: 0.112971  [   64/60000]
# loss: 0.139946  [ 6464/60000]
# loss: 0.133496  [12864/60000]
# loss: 0.266038  [19264/60000]
# loss: 0.159656  [25664/60000]
# loss: 0.246990  [32064/60000]
# loss: 0.181676  [38464/60000]
# loss: 0.177476  [44864/60000]
# loss: 0.168141  [51264/60000]
# loss: 0.140949  [57664/60000]
# Train Error:
#  Accuracy: 95.1%, Avg loss: 0.136701
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.262620
#
# Epoch 11:
#
# loss: 0.317840  [   64/60000]
# loss: 0.062273  [ 6464/60000]
# loss: 0.033418  [12864/60000]
# loss: 0.103717  [19264/60000]
# loss: 0.237912  [25664/60000]
# loss: 0.204272  [32064/60000]
# loss: 0.108124  [38464/60000]
# loss: 0.183232  [44864/60000]
# loss: 0.147659  [51264/60000]
# loss: 0.154429  [57664/60000]
# Train Error:
#  Accuracy: 95.3%, Avg loss: 0.130673
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.267228
#
# Epoch 12:
#
# loss: 0.071283  [   64/60000]
# loss: 0.165132  [ 6464/60000]
# loss: 0.162549  [12864/60000]
# loss: 0.103970  [19264/60000]
# loss: 0.081709  [25664/60000]
# loss: 0.279709  [32064/60000]
# loss: 0.119950  [38464/60000]
# loss: 0.109977  [44864/60000]
# loss: 0.174112  [51264/60000]
# loss: 0.272148  [57664/60000]
# Train Error:
#  Accuracy: 95.6%, Avg loss: 0.121549
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.271593
#
# Epoch 13:
#
# loss: 0.157200  [   64/60000]
# loss: 0.102504  [ 6464/60000]
# loss: 0.097677  [12864/60000]
# loss: 0.125875  [19264/60000]
# loss: 0.080494  [25664/60000]
# loss: 0.132509  [32064/60000]
# loss: 0.118014  [38464/60000]
# loss: 0.223399  [44864/60000]
# loss: 0.115960  [51264/60000]
# loss: 0.151156  [57664/60000]
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.117425
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.281370
#
# Epoch 14:
#
# loss: 0.105184  [   64/60000]
# loss: 0.064986  [ 6464/60000]
# loss: 0.135145  [12864/60000]
# loss: 0.068578  [19264/60000]
# loss: 0.117560  [25664/60000]
# loss: 0.068815  [32064/60000]
# loss: 0.208910  [38464/60000]
# loss: 0.132389  [44864/60000]
# loss: 0.168715  [51264/60000]
# loss: 0.132932  [57664/60000]
# Train Error:
#  Accuracy: 96.0%, Avg loss: 0.111306
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.291081
#
# Epoch 15:
#
# loss: 0.064751  [   64/60000]
# loss: 0.079593  [ 6464/60000]
# loss: 0.072392  [12864/60000]
# loss: 0.154625  [19264/60000]
# loss: 0.046948  [25664/60000]
# loss: 0.075334  [32064/60000]
# loss: 0.242519  [38464/60000]
# loss: 0.133099  [44864/60000]
# loss: 0.109585  [51264/60000]
# loss: 0.104298  [57664/60000]
# Train Error:
#  Accuracy: 95.9%, Avg loss: 0.111752
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.299610
#
# Epoch 16:
#
# loss: 0.146930  [   64/60000]
# loss: 0.096261  [ 6464/60000]
# loss: 0.022614  [12864/60000]
# loss: 0.144659  [19264/60000]
# loss: 0.019102  [25664/60000]
# loss: 0.044215  [32064/60000]
# loss: 0.087108  [38464/60000]
# loss: 0.164156  [44864/60000]
# loss: 0.095170  [51264/60000]
# loss: 0.161799  [57664/60000]
# Train Error:
#  Accuracy: 96.7%, Avg loss: 0.093081
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.305618
#
# Epoch 17:
#
# loss: 0.191637  [   64/60000]
# loss: 0.111004  [ 6464/60000]
# loss: 0.085291  [12864/60000]
# loss: 0.071941  [19264/60000]
# loss: 0.092463  [25664/60000]
# loss: 0.112038  [32064/60000]
# loss: 0.051802  [38464/60000]
# loss: 0.064448  [44864/60000]
# loss: 0.062350  [51264/60000]
# loss: 0.027144  [57664/60000]
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.090819
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.296540
#
# Epoch 18:
#
# loss: 0.063695  [   64/60000]
# loss: 0.035609  [ 6464/60000]
# loss: 0.099076  [12864/60000]
# loss: 0.154862  [19264/60000]
# loss: 0.123754  [25664/60000]
# loss: 0.041754  [32064/60000]
# loss: 0.065113  [38464/60000]
# loss: 0.053621  [44864/60000]
# loss: 0.164730  [51264/60000]
# loss: 0.101658  [57664/60000]
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.077974
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.312206
#
# Epoch 19:
#
# loss: 0.120781  [   64/60000]
# loss: 0.147560  [ 6464/60000]
# loss: 0.147193  [12864/60000]
# loss: 0.072148  [19264/60000]
# loss: 0.080612  [25664/60000]
# loss: 0.089040  [32064/60000]
# loss: 0.142134  [38464/60000]
# loss: 0.180021  [44864/60000]
# loss: 0.105544  [51264/60000]
# loss: 0.099178  [57664/60000]
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.088226
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.337287
#
# Epoch 20:
#
# loss: 0.094257  [   64/60000]
# loss: 0.070724  [ 6464/60000]
# loss: 0.094335  [12864/60000]
# loss: 0.043913  [19264/60000]
# loss: 0.039387  [25664/60000]
# loss: 0.148069  [32064/60000]
# loss: 0.140176  [38464/60000]
# loss: 0.050126  [44864/60000]
# loss: 0.062998  [51264/60000]
# loss: 0.143707  [57664/60000]
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.075015
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.348753
#
# Done training!

# %% [markdown]
# <span style="color:green"> With 28938 training parameters I was able to raise the test accuracy to 91.7%. However the train accuracy also climbed to 97.2% which is a clear indicator of overfitting. I used a 5x5 kernel and MaxPooling and ReLU for this.</span>

# %% [markdown]
# #An improved CNN

# %%
import torch.nn as nn
import torch.nn.functional as F
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, 3, padding=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.pool = nn.MaxPool2d(2, 2)

        self.conv2 = nn.Conv2d(16, 32, 3, padding=2)
        self.bn2 = nn.BatchNorm2d(32)

        # Add a third convolutional layer that takes in 32 parameters and produces 64 output without padding and using the same the 3x3 kernel
        self.conv3 = nn.Conv2d(32, 64, 3)
        self.bn3 = nn.BatchNorm2d(64)

        self.fc1 = nn.Linear(64 * 3 * 3, 120)
        self.fc2 = nn.Linear(120, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.pool(F.relu(self.bn3(self.conv3(x))))

        x = x.view(-1, 64 * 3 * 3)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 30, 30]             160
#        BatchNorm2d-2           [-1, 16, 30, 30]              32
#          MaxPool2d-3           [-1, 16, 15, 15]               0
#             Conv2d-4           [-1, 32, 17, 17]           4,640
#        BatchNorm2d-5           [-1, 32, 17, 17]              64
#          MaxPool2d-6             [-1, 32, 8, 8]               0
#             Conv2d-7             [-1, 64, 6, 6]          18,496
#        BatchNorm2d-8             [-1, 64, 6, 6]             128
#          MaxPool2d-9             [-1, 64, 3, 3]               0
#            Linear-10                  [-1, 120]          69,240
#            Linear-11                   [-1, 10]           1,210
# ================================================================
# Total params: 93,970
# Trainable params: 93,970
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.44
# Params size (MB): 0.36
# Estimated Total Size (MB): 0.81
# ----------------------------------------------------------------

# %%
# calling the train loop
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_loader, test_loader, model)
# Out:
# Epoch 1:
#
# loss: 2.301211  [   64/60000]
# loss: 0.465317  [ 6464/60000]
# loss: 0.452121  [12864/60000]
# loss: 0.554264  [19264/60000]
# loss: 0.342431  [25664/60000]
# loss: 0.283026  [32064/60000]
# loss: 0.365415  [38464/60000]
# loss: 0.297937  [44864/60000]
# loss: 0.420311  [51264/60000]
# loss: 0.438433  [57664/60000]
# Train Error:
#  Accuracy: 90.1%, Avg loss: 0.273699
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.308041
#
# Epoch 2:
#
# loss: 0.100580  [   64/60000]
# loss: 0.196121  [ 6464/60000]
# loss: 0.360688  [12864/60000]
# loss: 0.401820  [19264/60000]
# loss: 0.155938  [25664/60000]
# loss: 0.269517  [32064/60000]
# loss: 0.231656  [38464/60000]
# loss: 0.102481  [44864/60000]
# loss: 0.192268  [51264/60000]
# loss: 0.134395  [57664/60000]
# Train Error:
#  Accuracy: 91.7%, Avg loss: 0.227131
#
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.286539
#
# Epoch 3:
#
# loss: 0.226147  [   64/60000]
# loss: 0.261389  [ 6464/60000]
# loss: 0.191701  [12864/60000]
# loss: 0.429631  [19264/60000]
# loss: 0.172855  [25664/60000]
# loss: 0.314439  [32064/60000]
# loss: 0.191618  [38464/60000]
# loss: 0.308493  [44864/60000]
# loss: 0.203681  [51264/60000]
# loss: 0.265378  [57664/60000]
# Train Error:
#  Accuracy: 92.3%, Avg loss: 0.207478
#
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.273392
#
# Epoch 4:
#
# loss: 0.217697  [   64/60000]
# loss: 0.152996  [ 6464/60000]
# loss: 0.126180  [12864/60000]
# loss: 0.183154  [19264/60000]
# loss: 0.131652  [25664/60000]
# loss: 0.169298  [32064/60000]
# loss: 0.201982  [38464/60000]
# loss: 0.135233  [44864/60000]
# loss: 0.272438  [51264/60000]
# loss: 0.254886  [57664/60000]
# Train Error:
#  Accuracy: 93.7%, Avg loss: 0.173067
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.250569
#
# Epoch 5:
#
# loss: 0.226822  [   64/60000]
# loss: 0.288197  [ 6464/60000]
# loss: 0.114438  [12864/60000]
# loss: 0.265575  [19264/60000]
# loss: 0.243814  [25664/60000]
# loss: 0.180057  [32064/60000]
# loss: 0.116727  [38464/60000]
# loss: 0.236683  [44864/60000]
# loss: 0.291464  [51264/60000]
# loss: 0.243508  [57664/60000]
# Train Error:
#  Accuracy: 94.4%, Avg loss: 0.149959
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.231430
#
# Epoch 6:
#
# loss: 0.270199  [   64/60000]
# loss: 0.168803  [ 6464/60000]
# loss: 0.118332  [12864/60000]
# loss: 0.167876  [19264/60000]
# loss: 0.198526  [25664/60000]
# loss: 0.123800  [32064/60000]
# loss: 0.087493  [38464/60000]
# loss: 0.112325  [44864/60000]
# loss: 0.188929  [51264/60000]
# loss: 0.165629  [57664/60000]
# Train Error:
#  Accuracy: 93.4%, Avg loss: 0.171472
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.282430
#
# Epoch 7:
#
# loss: 0.255017  [   64/60000]
# loss: 0.132951  [ 6464/60000]
# loss: 0.199813  [12864/60000]
# loss: 0.205960  [19264/60000]
# loss: 0.097961  [25664/60000]
# loss: 0.076477  [32064/60000]
# loss: 0.163145  [38464/60000]
# loss: 0.113524  [44864/60000]
# loss: 0.165402  [51264/60000]
# loss: 0.152859  [57664/60000]
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.114737
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.242034
#
# Epoch 8:
#
# loss: 0.137526  [   64/60000]
# loss: 0.091947  [ 6464/60000]
# loss: 0.239606  [12864/60000]
# loss: 0.109552  [19264/60000]
# loss: 0.224606  [25664/60000]
# loss: 0.167397  [32064/60000]
# loss: 0.062235  [38464/60000]
# loss: 0.113516  [44864/60000]
# loss: 0.089047  [51264/60000]
# loss: 0.268728  [57664/60000]
# Train Error:
#  Accuracy: 96.0%, Avg loss: 0.109785
#
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.237778
#
# Epoch 9:
#
# loss: 0.152860  [   64/60000]
# loss: 0.266118  [ 6464/60000]
# loss: 0.082446  [12864/60000]
# loss: 0.083395  [19264/60000]
# loss: 0.059201  [25664/60000]
# loss: 0.072952  [32064/60000]
# loss: 0.135731  [38464/60000]
# loss: 0.271133  [44864/60000]
# loss: 0.119856  [51264/60000]
# loss: 0.143669  [57664/60000]
# Train Error:
#  Accuracy: 96.2%, Avg loss: 0.104127
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.248545
#
# Epoch 10:
#
# loss: 0.078645  [   64/60000]
# loss: 0.116694  [ 6464/60000]
# loss: 0.073764  [12864/60000]
# loss: 0.121405  [19264/60000]
# loss: 0.137926  [25664/60000]
# loss: 0.067864  [32064/60000]
# loss: 0.117326  [38464/60000]
# loss: 0.273753  [44864/60000]
# loss: 0.116651  [51264/60000]
# loss: 0.068163  [57664/60000]
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.086692
#
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.244144
#
# Epoch 11:
#
# loss: 0.148601  [   64/60000]
# loss: 0.113991  [ 6464/60000]
# loss: 0.080799  [12864/60000]
# loss: 0.068615  [19264/60000]
# loss: 0.150824  [25664/60000]
# loss: 0.053583  [32064/60000]
# loss: 0.095102  [38464/60000]
# loss: 0.065667  [44864/60000]
# loss: 0.174115  [51264/60000]
# loss: 0.128386  [57664/60000]
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.072496
#
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.248424
#
# Epoch 12:
#
# loss: 0.108183  [   64/60000]
# loss: 0.096834  [ 6464/60000]
# loss: 0.038366  [12864/60000]
# loss: 0.123208  [19264/60000]
# loss: 0.086892  [25664/60000]
# loss: 0.028748  [32064/60000]
# loss: 0.097302  [38464/60000]
# loss: 0.097823  [44864/60000]
# loss: 0.166351  [51264/60000]
# loss: 0.049486  [57664/60000]
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.069627
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.273813
#
# Epoch 13:
#
# loss: 0.023109  [   64/60000]
# loss: 0.116905  [ 6464/60000]
# loss: 0.027654  [12864/60000]
# loss: 0.262639  [19264/60000]
# loss: 0.061981  [25664/60000]
# loss: 0.107510  [32064/60000]
# loss: 0.161699  [38464/60000]
# loss: 0.082851  [44864/60000]
# loss: 0.078123  [51264/60000]
# loss: 0.064648  [57664/60000]
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.061621
#
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.284372
#
# Epoch 14:
#
# loss: 0.116149  [   64/60000]
# loss: 0.085513  [ 6464/60000]
# loss: 0.040350  [12864/60000]
# loss: 0.044503  [19264/60000]
# loss: 0.108626  [25664/60000]
# loss: 0.017745  [32064/60000]
# loss: 0.134069  [38464/60000]
# loss: 0.012176  [44864/60000]
# loss: 0.108541  [51264/60000]
# loss: 0.085435  [57664/60000]
# Train Error:
#  Accuracy: 97.6%, Avg loss: 0.063673
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.292680
#
# Epoch 15:
#
# loss: 0.032447  [   64/60000]
# loss: 0.256018  [ 6464/60000]
# loss: 0.023965  [12864/60000]
# loss: 0.100661  [19264/60000]
# loss: 0.022521  [25664/60000]
# loss: 0.082658  [32064/60000]
# loss: 0.140296  [38464/60000]
# loss: 0.058091  [44864/60000]
# loss: 0.062804  [51264/60000]
# loss: 0.050533  [57664/60000]
# Train Error:
#  Accuracy: 97.9%, Avg loss: 0.056470
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.306652
#
# Epoch 16:
#
# loss: 0.011627  [   64/60000]
# loss: 0.077677  [ 6464/60000]
# loss: 0.008109  [12864/60000]
# loss: 0.107121  [19264/60000]
# loss: 0.095231  [25664/60000]
# loss: 0.036488  [32064/60000]
# loss: 0.038896  [38464/60000]
# loss: 0.075674  [44864/60000]
# loss: 0.146463  [51264/60000]
# loss: 0.021417  [57664/60000]
# Train Error:
#  Accuracy: 98.1%, Avg loss: 0.053026
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.334809
#
# Epoch 17:
#
# loss: 0.020378  [   64/60000]
# loss: 0.105085  [ 6464/60000]
# loss: 0.076753  [12864/60000]
# loss: 0.076988  [19264/60000]
# loss: 0.058064  [25664/60000]
# loss: 0.096774  [32064/60000]
# loss: 0.009785  [38464/60000]
# loss: 0.029124  [44864/60000]
# loss: 0.069505  [51264/60000]
# loss: 0.046499  [57664/60000]
# Train Error:
#  Accuracy: 98.7%, Avg loss: 0.037704
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.334686
#
# Epoch 18:
#
# loss: 0.006175  [   64/60000]
# loss: 0.102699  [ 6464/60000]
# loss: 0.044517  [12864/60000]
# loss: 0.173507  [19264/60000]
# loss: 0.030877  [25664/60000]
# loss: 0.130426  [32064/60000]
# loss: 0.071626  [38464/60000]
# loss: 0.064161  [44864/60000]
# loss: 0.009693  [51264/60000]
# loss: 0.008602  [57664/60000]
# Train Error:
#  Accuracy: 98.3%, Avg loss: 0.045582
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.348325
#
# Epoch 19:
#
# loss: 0.047176  [   64/60000]
# loss: 0.037178  [ 6464/60000]
# loss: 0.016331  [12864/60000]
# loss: 0.019614  [19264/60000]
# loss: 0.041230  [25664/60000]
# loss: 0.004671  [32064/60000]
# loss: 0.037812  [38464/60000]
# loss: 0.018797  [44864/60000]
# loss: 0.062823  [51264/60000]
# loss: 0.039482  [57664/60000]
# Train Error:
#  Accuracy: 98.4%, Avg loss: 0.043902
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.354752
#
# Epoch 20:
#
# loss: 0.038371  [   64/60000]
# loss: 0.038378  [ 6464/60000]
# loss: 0.077766  [12864/60000]
# loss: 0.049896  [19264/60000]
# loss: 0.035672  [25664/60000]
# loss: 0.062064  [32064/60000]
# loss: 0.064903  [38464/60000]
# loss: 0.043681  [44864/60000]
# loss: 0.014593  [51264/60000]
# loss: 0.081614  [57664/60000]
# Train Error:
#  Accuracy: 98.5%, Avg loss: 0.038973
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.366819
#
# Done training!

# %%
# plotting the train and test loss and accuracy
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# ### <font color='red'>Your text here.</font>
# <font color='red'>Enter your text descriptions in the cell below:</font>

# %% [markdown]
# <span style="color:green"> Here I have adapted the LeNet5 classifier model and added another layer with 3x3 kernel with no padding and applied batchnorm after each layer. This increased the number of parameters to 93970. I also used the ReLU after the batch normalization. I also added another fully connected layer at the end. This gives me a maximum test accuracy as 92.4% and train accuracy as 97.4%.</span>

# %% [markdown]
# ---
# # 5. Transfer Learning
# ---
#
# Nobody trains large models from scratch. Rather, they use large pretrained models, that have been trained perhaps for weeks on very large datasets. Then, we can tweak the model for our needs. This allows us to use large models on small datasets and (hopefully) avoid some overfitting.
#
# We are going to load ResNet18, we're going to cut the head off it - in this case, we will replace the very last layer. ResNet18 was trained for 1000 classes, we only have 10.
#
# Do the following:
# 1. From `torchvision.models`, load [`ResNet18`](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html), and use random weights (`weights=None`). Replace the full-connected layer at the end with your own fully connect layer. Train and plot the loss and accuracy.
# 1. Repeat step 1, but use the default paramaters, and retrain. In this case, the default parameters.
# 1. Freeze all but the last layer of your adapted ResNet model, and retrain.
# 1. Provide some commentary on the three approaches. Particularly, what's the difference between all three approaches we outlined here?
#
# For the freezing of layers, the following article is useful:
# https://jimmy-shen.medium.com/pytorch-freeze-part-of-the-layers-4554105e03a6
#
# In step 3 above, we may see that the network doesn't necessarily perform as well as previous networks, in terms of test accuracy. Probably we should unfreeze more of the later layers to allow better fine-tuning of the network to our problem. And there are more complicated and powerful finetuning strategies out there. But you should see that overfitting is, more or less, solved. This is because we are only training a much smaller number of parameters, and freezing all of the convolution layers in the ResNet.

# %%
# We need to recreate the dataloaders, because ResNet expects a three channel
# RGB input, whereas FashionMNIST only has 1 channel (greyscale). Use
# `transforms.Grayscale(3)` to replicated the grayscale image into the three
# channels.

# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=transforms.Compose([
        transforms.Resize((28,28)),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize(mean = 0.2859, std = 0.3530),
    ])
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=transforms.Compose([
        transforms.Resize((28,28)),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize(mean = 0.2859, std = 0.3530),
    ])
)

batch_size = 64
# Recreate the data loaders.
train_dataloader = torch.utils.data.DataLoader(training_data, batch_size=batch_size)
test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 3, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# ### <font color='red'>Your code here.</font>
# <font color='red'>Enter your code in the cell(s) below:</font>

# %% [markdown]
# # Approach 1 : Using random weights(weights=None)

# %%
##############################
# Your code below
resnet18_random = torchvision.models.resnet18(weights=None)
resnet18_random.fc = nn.Linear(resnet18_random.fc.in_features, 10)  # Replace the fully connected layer
model = resnet18_random.to(device)
params = resnet18_random.state_dict()
summary(model, (3,7,7))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1             [-1, 64, 4, 4]           9,408
#        BatchNorm2d-2             [-1, 64, 4, 4]             128
#               ReLU-3             [-1, 64, 4, 4]               0
#          MaxPool2d-4             [-1, 64, 2, 2]               0
#             Conv2d-5             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-6             [-1, 64, 2, 2]             128
#               ReLU-7             [-1, 64, 2, 2]               0
#             Conv2d-8             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-9             [-1, 64, 2, 2]             128
#              ReLU-10             [-1, 64, 2, 2]               0
#        BasicBlock-11             [-1, 64, 2, 2]               0
#            Conv2d-12             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-13             [-1, 64, 2, 2]             128
#              ReLU-14             [-1, 64, 2, 2]               0
#            Conv2d-15             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-16             [-1, 64, 2, 2]             128
#              ReLU-17             [-1, 64, 2, 2]               0
#        BasicBlock-18             [-1, 64, 2, 2]               0
#            Conv2d-19            [-1, 128, 1, 1]          73,728
#       BatchNorm2d-20            [-1, 128, 1, 1]             256
#              ReLU-21            [-1, 128, 1, 1]               0
#            Conv2d-22            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-23            [-1, 128, 1, 1]             256
#            Conv2d-24            [-1, 128, 1, 1]           8,192
#       BatchNorm2d-25            [-1, 128, 1, 1]             256
#              ReLU-26            [-1, 128, 1, 1]               0
#        BasicBlock-27            [-1, 128, 1, 1]               0
#            Conv2d-28            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-29            [-1, 128, 1, 1]             256
#              ReLU-30            [-1, 128, 1, 1]               0
#            Conv2d-31            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-32            [-1, 128, 1, 1]             256
#              ReLU-33            [-1, 128, 1, 1]               0
#        BasicBlock-34            [-1, 128, 1, 1]               0
#            Conv2d-35            [-1, 256, 1, 1]         294,912
#       BatchNorm2d-36            [-1, 256, 1, 1]             512
#              ReLU-37            [-1, 256, 1, 1]               0
#            Conv2d-38            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-39            [-1, 256, 1, 1]             512
#            Conv2d-40            [-1, 256, 1, 1]          32,768
#       BatchNorm2d-41            [-1, 256, 1, 1]             512
#              ReLU-42            [-1, 256, 1, 1]               0
#        BasicBlock-43            [-1, 256, 1, 1]               0
#            Conv2d-44            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-45            [-1, 256, 1, 1]             512
#              ReLU-46            [-1, 256, 1, 1]               0
#            Conv2d-47            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-48            [-1, 256, 1, 1]             512
#              ReLU-49            [-1, 256, 1, 1]               0
#        BasicBlock-50            [-1, 256, 1, 1]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.17
# Params size (MB): 42.65
# Estimated Total Size (MB): 42.82
# ----------------------------------------------------------------

# %%
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_dataloader, test_dataloader, model)
# Out:
# Epoch 1:
#
# loss: 2.569363  [   64/60000]
# loss: 0.469928  [ 6464/60000]
# loss: 0.350273  [12864/60000]
# loss: 0.495145  [19264/60000]
# loss: 0.551975  [25664/60000]
# loss: 0.429372  [32064/60000]
# loss: 0.291007  [38464/60000]
# loss: 0.477166  [44864/60000]
# loss: 0.297339  [51264/60000]
# loss: 0.449782  [57664/60000]
# Train Error:
#  Accuracy: 85.0%, Avg loss: 0.389709
#
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.430191
#
# Epoch 2:
#
# loss: 0.274123  [   64/60000]
# loss: 0.298254  [ 6464/60000]
# loss: 0.259653  [12864/60000]
# loss: 0.302924  [19264/60000]
# loss: 0.290978  [25664/60000]
# loss: 0.368102  [32064/60000]
# loss: 0.222048  [38464/60000]
# loss: 0.370145  [44864/60000]
# loss: 0.269540  [51264/60000]
# loss: 0.288602  [57664/60000]
# Train Error:
#  Accuracy: 85.9%, Avg loss: 0.362848
#
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.415537
#
# Epoch 3:
#
# loss: 0.222771  [   64/60000]
# loss: 0.270327  [ 6464/60000]
# loss: 0.223037  [12864/60000]
# loss: 0.304202  [19264/60000]
# loss: 0.283217  [25664/60000]
# loss: 0.379570  [32064/60000]
# loss: 0.258351  [38464/60000]
# loss: 0.327904  [44864/60000]
# loss: 0.246321  [51264/60000]
# loss: 0.258983  [57664/60000]
# Train Error:
#  Accuracy: 88.0%, Avg loss: 0.316267
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.375777
#
# Epoch 4:
#
# loss: 0.188252  [   64/60000]
# loss: 0.248951  [ 6464/60000]
# loss: 0.192902  [12864/60000]
# loss: 0.237868  [19264/60000]
# loss: 0.245034  [25664/60000]
# loss: 0.368761  [32064/60000]
# loss: 0.222755  [38464/60000]
# loss: 0.291314  [44864/60000]
# loss: 0.222717  [51264/60000]
# loss: 0.207933  [57664/60000]
# Train Error:
#  Accuracy: 90.0%, Avg loss: 0.264803
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.338739
#
# Epoch 5:
#
# loss: 0.129355  [   64/60000]
# loss: 0.198230  [ 6464/60000]
# loss: 0.205782  [12864/60000]
# loss: 0.182174  [19264/60000]
# loss: 0.242045  [25664/60000]
# loss: 0.305275  [32064/60000]
# loss: 0.196802  [38464/60000]
# loss: 0.249707  [44864/60000]
# loss: 0.251199  [51264/60000]
# loss: 0.242966  [57664/60000]
# Train Error:
#  Accuracy: 91.3%, Avg loss: 0.237362
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.319548
#
# Epoch 6:
#
# loss: 0.141715  [   64/60000]
# loss: 0.141839  [ 6464/60000]
# loss: 0.168604  [12864/60000]
# loss: 0.153384  [19264/60000]
# loss: 0.160055  [25664/60000]
# loss: 0.341730  [32064/60000]
# loss: 0.260415  [38464/60000]
# loss: 0.227468  [44864/60000]
# loss: 0.181130  [51264/60000]
# loss: 0.164897  [57664/60000]
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.210991
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.310099
#
# Epoch 7:
#
# loss: 0.168828  [   64/60000]
# loss: 0.177094  [ 6464/60000]
# loss: 0.131634  [12864/60000]
# loss: 0.146582  [19264/60000]
# loss: 0.167341  [25664/60000]
# loss: 0.278346  [32064/60000]
# loss: 0.260093  [38464/60000]
# loss: 0.220260  [44864/60000]
# loss: 0.141654  [51264/60000]
# loss: 0.169131  [57664/60000]
# Train Error:
#  Accuracy: 92.9%, Avg loss: 0.188465
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.304540
#
# Epoch 8:
#
# loss: 0.115253  [   64/60000]
# loss: 0.158809  [ 6464/60000]
# loss: 0.096811  [12864/60000]
# loss: 0.128520  [19264/60000]
# loss: 0.155655  [25664/60000]
# loss: 0.279736  [32064/60000]
# loss: 0.260696  [38464/60000]
# loss: 0.180755  [44864/60000]
# loss: 0.134091  [51264/60000]
# loss: 0.176514  [57664/60000]
# Train Error:
#  Accuracy: 92.8%, Avg loss: 0.197187
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.334206
#
# Epoch 9:
#
# loss: 0.119646  [   64/60000]
# loss: 0.161593  [ 6464/60000]
# loss: 0.099752  [12864/60000]
# loss: 0.104036  [19264/60000]
# loss: 0.156548  [25664/60000]
# loss: 0.196188  [32064/60000]
# loss: 0.264375  [38464/60000]
# loss: 0.159298  [44864/60000]
# loss: 0.122829  [51264/60000]
# loss: 0.121587  [57664/60000]
# Train Error:
#  Accuracy: 93.8%, Avg loss: 0.164605
#
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.312630
#
# Epoch 10:
#
# loss: 0.056112  [   64/60000]
# loss: 0.141357  [ 6464/60000]
# loss: 0.072710  [12864/60000]
# loss: 0.233345  [19264/60000]
# loss: 0.149373  [25664/60000]
# loss: 0.199232  [32064/60000]
# loss: 0.197321  [38464/60000]
# loss: 0.190039  [44864/60000]
# loss: 0.076088  [51264/60000]
# loss: 0.122182  [57664/60000]
# Train Error:
#  Accuracy: 94.6%, Avg loss: 0.146260
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.323528
#
# Epoch 11:
#
# loss: 0.078621  [   64/60000]
# loss: 0.095313  [ 6464/60000]
# loss: 0.039623  [12864/60000]
# loss: 0.099634  [19264/60000]
# loss: 0.124491  [25664/60000]
# loss: 0.220986  [32064/60000]
# loss: 0.125024  [38464/60000]
# loss: 0.071414  [44864/60000]
# loss: 0.088483  [51264/60000]
# loss: 0.090682  [57664/60000]
# Train Error:
#  Accuracy: 94.0%, Avg loss: 0.159210
#
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.353300
#
# Epoch 12:
#
# loss: 0.087973  [   64/60000]
# loss: 0.163937  [ 6464/60000]
# loss: 0.022977  [12864/60000]
# loss: 0.104393  [19264/60000]
# loss: 0.096602  [25664/60000]
# loss: 0.238532  [32064/60000]
# loss: 0.093608  [38464/60000]
# loss: 0.172635  [44864/60000]
# loss: 0.063218  [51264/60000]
# loss: 0.079837  [57664/60000]
# Train Error:
#  Accuracy: 94.8%, Avg loss: 0.140506
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.344952
#
# Epoch 13:
#
# loss: 0.086683  [   64/60000]
# loss: 0.097566  [ 6464/60000]
# loss: 0.053951  [12864/60000]
# loss: 0.078222  [19264/60000]
# loss: 0.119711  [25664/60000]
# loss: 0.101178  [32064/60000]
# loss: 0.061267  [38464/60000]
# loss: 0.060785  [44864/60000]
# loss: 0.042654  [51264/60000]
# loss: 0.104573  [57664/60000]
# Train Error:
#  Accuracy: 95.5%, Avg loss: 0.119721
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.328801
#
# Epoch 14:
#
# loss: 0.058590  [   64/60000]
# loss: 0.108856  [ 6464/60000]
# loss: 0.044384  [12864/60000]
# loss: 0.064351  [19264/60000]
# loss: 0.057281  [25664/60000]
# loss: 0.125084  [32064/60000]
# loss: 0.206257  [38464/60000]
# loss: 0.186167  [44864/60000]
# loss: 0.066849  [51264/60000]
# loss: 0.090234  [57664/60000]
# Train Error:
#  Accuracy: 95.0%, Avg loss: 0.139297
#
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.370295
#
# Epoch 15:
#
# loss: 0.064878  [   64/60000]
# loss: 0.077517  [ 6464/60000]
# loss: 0.067759  [12864/60000]
# loss: 0.088799  [19264/60000]
# loss: 0.028686  [25664/60000]
# loss: 0.090970  [32064/60000]
# loss: 0.027179  [38464/60000]
# loss: 0.076084  [44864/60000]
# loss: 0.085258  [51264/60000]
# loss: 0.019034  [57664/60000]
# Train Error:
#  Accuracy: 95.7%, Avg loss: 0.121771
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.381903
#
# Epoch 16:
#
# loss: 0.147366  [   64/60000]
# loss: 0.052936  [ 6464/60000]
# loss: 0.011268  [12864/60000]
# loss: 0.030259  [19264/60000]
# loss: 0.043197  [25664/60000]
# loss: 0.115680  [32064/60000]
# loss: 0.100084  [38464/60000]
# loss: 0.027073  [44864/60000]
# loss: 0.114765  [51264/60000]
# loss: 0.036065  [57664/60000]
# Train Error:
#  Accuracy: 96.2%, Avg loss: 0.107937
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.372244
#
# Epoch 17:
#
# loss: 0.068020  [   64/60000]
# loss: 0.071340  [ 6464/60000]
# loss: 0.009160  [12864/60000]
# loss: 0.104721  [19264/60000]
# loss: 0.041306  [25664/60000]
# loss: 0.063179  [32064/60000]
# loss: 0.042004  [38464/60000]
# loss: 0.114239  [44864/60000]
# loss: 0.067059  [51264/60000]
# loss: 0.127715  [57664/60000]
# Train Error:
#  Accuracy: 95.4%, Avg loss: 0.130221
#
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.417951
#
# Epoch 18:
#
# loss: 0.040358  [   64/60000]
# loss: 0.110979  [ 6464/60000]
# loss: 0.006190  [12864/60000]
# loss: 0.018981  [19264/60000]
# loss: 0.052686  [25664/60000]
# loss: 0.125585  [32064/60000]
# loss: 0.052285  [38464/60000]
# loss: 0.020624  [44864/60000]
# loss: 0.045079  [51264/60000]
# loss: 0.032968  [57664/60000]
# Train Error:
#  Accuracy: 94.7%, Avg loss: 0.149746
#
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.484398
#
# Epoch 19:
#
# loss: 0.070142  [   64/60000]
# loss: 0.066927  [ 6464/60000]
# loss: 0.019004  [12864/60000]
# loss: 0.027355  [19264/60000]
# loss: 0.009650  [25664/60000]
# loss: 0.110794  [32064/60000]
# loss: 0.082319  [38464/60000]
# loss: 0.013139  [44864/60000]
# loss: 0.089018  [51264/60000]
# loss: 0.049046  [57664/60000]
# Train Error:
#  Accuracy: 96.3%, Avg loss: 0.106870
#
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.458993
#
# Epoch 20:
#
# loss: 0.098690  [   64/60000]
# loss: 0.074420  [ 6464/60000]
# loss: 0.004372  [12864/60000]
# loss: 0.132630  [19264/60000]
# loss: 0.020223  [25664/60000]
# loss: 0.079026  [32064/60000]
# loss: 0.053867  [38464/60000]
# loss: 0.055165  [44864/60000]
# loss: 0.013492  [51264/60000]
# loss: 0.038239  [57664/60000]
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.083531
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.431449
#
# Done training!

# %%
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# # Approach 2 : Default or IMAGENET1K_V1 weights

# %%
##############################
# Your code below
resnet18_default = torchvision.models.resnet18(weights='DEFAULT') # equivalent to weights='IMAGENET1K_V1'
resnet18_default.fc = nn.Linear(resnet18_default.fc.in_features, 10)  # Replace the fully connected layer
model = resnet18_default.to(device)
params = resnet18_default.state_dict()
summary(model, (3,7,7))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 145MB/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1             [-1, 64, 4, 4]           9,408
#        BatchNorm2d-2             [-1, 64, 4, 4]             128
#               ReLU-3             [-1, 64, 4, 4]               0
#          MaxPool2d-4             [-1, 64, 2, 2]               0
#             Conv2d-5             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-6             [-1, 64, 2, 2]             128
#               ReLU-7             [-1, 64, 2, 2]               0
#             Conv2d-8             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-9             [-1, 64, 2, 2]             128
#              ReLU-10             [-1, 64, 2, 2]               0
#        BasicBlock-11             [-1, 64, 2, 2]               0
#            Conv2d-12             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-13             [-1, 64, 2, 2]             128
#              ReLU-14             [-1, 64, 2, 2]               0
#            Conv2d-15             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-16             [-1, 64, 2, 2]             128
#              ReLU-17             [-1, 64, 2, 2]               0
#        BasicBlock-18             [-1, 64, 2, 2]               0
#            Conv2d-19            [-1, 128, 1, 1]          73,728
#       BatchNorm2d-20            [-1, 128, 1, 1]             256
#              ReLU-21            [-1, 128, 1, 1]               0
#            Conv2d-22            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-23            [-1, 128, 1, 1]             256
#            Conv2d-24            [-1, 128, 1, 1]           8,192
#       BatchNorm2d-25            [-1, 128, 1, 1]             256
#              ReLU-26            [-1, 128, 1, 1]               0
#        BasicBlock-27            [-1, 128, 1, 1]               0
#            Conv2d-28            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-29            [-1, 128, 1, 1]             256
#              ReLU-30            [-1, 128, 1, 1]               0
#            Conv2d-31            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-32            [-1, 128, 1, 1]             256
#              ReLU-33            [-1, 128, 1, 1]               0
#        BasicBlock-34            [-1, 128, 1, 1]               0
#            Conv2d-35            [-1, 256, 1, 1]         294,912
#       BatchNorm2d-36            [-1, 256, 1, 1]             512
#              ReLU-37            [-1, 256, 1, 1]               0
#            Conv2d-38            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-39            [-1, 256, 1, 1]             512
#            Conv2d-40            [-1, 256, 1, 1]          32,768
#       BatchNorm2d-41            [-1, 256, 1, 1]             512
#              ReLU-42            [-1, 256, 1, 1]               0
#        BasicBlock-43            [-1, 256, 1, 1]               0
#            Conv2d-44            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-45            [-1, 256, 1, 1]             512
#              ReLU-46            [-1, 256, 1, 1]               0
#            Conv2d-47            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-48            [-1, 256, 1, 1]             512
#              ReLU-49            [-1, 256, 1, 1]               0
#        BasicBlock-50            [-1, 256, 1, 1]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.17
# Params size (MB): 42.65
# Estimated Total Size (MB): 42.82
# ----------------------------------------------------------------

# %%
# calling train loop
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_dataloader, test_dataloader, model)
# Out:
# Epoch 1:
#
# loss: 2.699613  [   64/60000]
# loss: 0.413341  [ 6464/60000]
# loss: 0.358605  [12864/60000]
# loss: 0.417501  [19264/60000]
# loss: 0.469249  [25664/60000]
# loss: 0.404571  [32064/60000]
# loss: 0.299139  [38464/60000]
# loss: 0.446641  [44864/60000]
# loss: 0.263488  [51264/60000]
# loss: 0.239800  [57664/60000]
# Train Error:
#  Accuracy: 88.3%, Avg loss: 0.315919
#
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.351691
#
# Epoch 2:
#
# loss: 0.289517  [   64/60000]
# loss: 0.350188  [ 6464/60000]
# loss: 0.234294  [12864/60000]
# loss: 0.241655  [19264/60000]
# loss: 0.314756  [25664/60000]
# loss: 0.343560  [32064/60000]
# loss: 0.267379  [38464/60000]
# loss: 0.397909  [44864/60000]
# loss: 0.227364  [51264/60000]
# loss: 0.260563  [57664/60000]
# Train Error:
#  Accuracy: 90.4%, Avg loss: 0.260115
#
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.303243
#
# Epoch 3:
#
# loss: 0.179399  [   64/60000]
# loss: 0.232486  [ 6464/60000]
# loss: 0.317447  [12864/60000]
# loss: 0.165263  [19264/60000]
# loss: 0.343207  [25664/60000]
# loss: 0.290739  [32064/60000]
# loss: 0.195653  [38464/60000]
# loss: 0.348688  [44864/60000]
# loss: 0.209038  [51264/60000]
# loss: 0.299725  [57664/60000]
# Train Error:
#  Accuracy: 90.1%, Avg loss: 0.259165
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.309290
#
# Epoch 4:
#
# loss: 0.220068  [   64/60000]
# loss: 0.195938  [ 6464/60000]
# loss: 0.211809  [12864/60000]
# loss: 0.129647  [19264/60000]
# loss: 0.226597  [25664/60000]
# loss: 0.297987  [32064/60000]
# loss: 0.197968  [38464/60000]
# loss: 0.332016  [44864/60000]
# loss: 0.222947  [51264/60000]
# loss: 0.178591  [57664/60000]
# Train Error:
#  Accuracy: 92.5%, Avg loss: 0.202919
#
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.275627
#
# Epoch 5:
#
# loss: 0.126935  [   64/60000]
# loss: 0.176541  [ 6464/60000]
# loss: 0.202864  [12864/60000]
# loss: 0.207205  [19264/60000]
# loss: 0.232593  [25664/60000]
# loss: 0.277371  [32064/60000]
# loss: 0.107041  [38464/60000]
# loss: 0.273593  [44864/60000]
# loss: 0.143847  [51264/60000]
# loss: 0.129776  [57664/60000]
# Train Error:
#  Accuracy: 93.9%, Avg loss: 0.168374
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.261763
#
# Epoch 6:
#
# loss: 0.108307  [   64/60000]
# loss: 0.154029  [ 6464/60000]
# loss: 0.158071  [12864/60000]
# loss: 0.101268  [19264/60000]
# loss: 0.178242  [25664/60000]
# loss: 0.291666  [32064/60000]
# loss: 0.210166  [38464/60000]
# loss: 0.196939  [44864/60000]
# loss: 0.186639  [51264/60000]
# loss: 0.107088  [57664/60000]
# Train Error:
#  Accuracy: 94.3%, Avg loss: 0.157164
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.271004
#
# Epoch 7:
#
# loss: 0.126755  [   64/60000]
# loss: 0.143742  [ 6464/60000]
# loss: 0.162884  [12864/60000]
# loss: 0.093747  [19264/60000]
# loss: 0.158251  [25664/60000]
# loss: 0.283207  [32064/60000]
# loss: 0.163929  [38464/60000]
# loss: 0.172903  [44864/60000]
# loss: 0.102712  [51264/60000]
# loss: 0.058485  [57664/60000]
# Train Error:
#  Accuracy: 94.6%, Avg loss: 0.152856
#
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.293481
#
# Epoch 8:
#
# loss: 0.073913  [   64/60000]
# loss: 0.107586  [ 6464/60000]
# loss: 0.134664  [12864/60000]
# loss: 0.087171  [19264/60000]
# loss: 0.129203  [25664/60000]
# loss: 0.228114  [32064/60000]
# loss: 0.145052  [38464/60000]
# loss: 0.104573  [44864/60000]
# loss: 0.099945  [51264/60000]
# loss: 0.081792  [57664/60000]
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.117233
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.283029
#
# Epoch 9:
#
# loss: 0.109320  [   64/60000]
# loss: 0.126318  [ 6464/60000]
# loss: 0.125459  [12864/60000]
# loss: 0.061831  [19264/60000]
# loss: 0.125214  [25664/60000]
# loss: 0.182316  [32064/60000]
# loss: 0.063804  [38464/60000]
# loss: 0.207746  [44864/60000]
# loss: 0.104197  [51264/60000]
# loss: 0.042068  [57664/60000]
# Train Error:
#  Accuracy: 95.4%, Avg loss: 0.136147
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.321889
#
# Epoch 10:
#
# loss: 0.126904  [   64/60000]
# loss: 0.113235  [ 6464/60000]
# loss: 0.132544  [12864/60000]
# loss: 0.074600  [19264/60000]
# loss: 0.093688  [25664/60000]
# loss: 0.337797  [32064/60000]
# loss: 0.089982  [38464/60000]
# loss: 0.127494  [44864/60000]
# loss: 0.126086  [51264/60000]
# loss: 0.148031  [57664/60000]
# Train Error:
#  Accuracy: 96.3%, Avg loss: 0.101713
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.318972
#
# Epoch 11:
#
# loss: 0.067258  [   64/60000]
# loss: 0.085982  [ 6464/60000]
# loss: 0.078027  [12864/60000]
# loss: 0.049371  [19264/60000]
# loss: 0.043853  [25664/60000]
# loss: 0.141359  [32064/60000]
# loss: 0.179692  [38464/60000]
# loss: 0.119495  [44864/60000]
# loss: 0.058901  [51264/60000]
# loss: 0.042303  [57664/60000]
# Train Error:
#  Accuracy: 95.0%, Avg loss: 0.144328
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.346182
#
# Epoch 12:
#
# loss: 0.089135  [   64/60000]
# loss: 0.105696  [ 6464/60000]
# loss: 0.047059  [12864/60000]
# loss: 0.039104  [19264/60000]
# loss: 0.038277  [25664/60000]
# loss: 0.086407  [32064/60000]
# loss: 0.108386  [38464/60000]
# loss: 0.073047  [44864/60000]
# loss: 0.024915  [51264/60000]
# loss: 0.053456  [57664/60000]
# Train Error:
#  Accuracy: 96.0%, Avg loss: 0.119353
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.395545
#
# Epoch 13:
#
# loss: 0.137522  [   64/60000]
# loss: 0.096918  [ 6464/60000]
# loss: 0.015018  [12864/60000]
# loss: 0.083249  [19264/60000]
# loss: 0.043630  [25664/60000]
# loss: 0.092528  [32064/60000]
# loss: 0.110431  [38464/60000]
# loss: 0.180068  [44864/60000]
# loss: 0.089692  [51264/60000]
# loss: 0.038970  [57664/60000]
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.115481
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.369299
#
# Epoch 14:
#
# loss: 0.080596  [   64/60000]
# loss: 0.072925  [ 6464/60000]
# loss: 0.043247  [12864/60000]
# loss: 0.032425  [19264/60000]
# loss: 0.086218  [25664/60000]
# loss: 0.077062  [32064/60000]
# loss: 0.049139  [38464/60000]
# loss: 0.042233  [44864/60000]
# loss: 0.103495  [51264/60000]
# loss: 0.055896  [57664/60000]
# Train Error:
#  Accuracy: 97.2%, Avg loss: 0.078141
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.349244
#
# Epoch 15:
#
# loss: 0.150461  [   64/60000]
# loss: 0.021893  [ 6464/60000]
# loss: 0.037925  [12864/60000]
# loss: 0.007785  [19264/60000]
# loss: 0.075034  [25664/60000]
# loss: 0.038056  [32064/60000]
# loss: 0.074652  [38464/60000]
# loss: 0.089525  [44864/60000]
# loss: 0.051489  [51264/60000]
# loss: 0.037871  [57664/60000]
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.085430
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.372719
#
# Epoch 16:
#
# loss: 0.048447  [   64/60000]
# loss: 0.044206  [ 6464/60000]
# loss: 0.053298  [12864/60000]
# loss: 0.033579  [19264/60000]
# loss: 0.055885  [25664/60000]
# loss: 0.054022  [32064/60000]
# loss: 0.056510  [38464/60000]
# loss: 0.097086  [44864/60000]
# loss: 0.034384  [51264/60000]
# loss: 0.029309  [57664/60000]
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.069569
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.401588
#
# Epoch 17:
#
# loss: 0.061135  [   64/60000]
# loss: 0.049344  [ 6464/60000]
# loss: 0.013186  [12864/60000]
# loss: 0.063197  [19264/60000]
# loss: 0.091129  [25664/60000]
# loss: 0.028516  [32064/60000]
# loss: 0.034531  [38464/60000]
# loss: 0.040570  [44864/60000]
# loss: 0.056262  [51264/60000]
# loss: 0.037140  [57664/60000]
# Train Error:
#  Accuracy: 97.6%, Avg loss: 0.068555
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.380988
#
# Epoch 18:
#
# loss: 0.079869  [   64/60000]
# loss: 0.060019  [ 6464/60000]
# loss: 0.002895  [12864/60000]
# loss: 0.088912  [19264/60000]
# loss: 0.004987  [25664/60000]
# loss: 0.119878  [32064/60000]
# loss: 0.021169  [38464/60000]
# loss: 0.051829  [44864/60000]
# loss: 0.064611  [51264/60000]
# loss: 0.011921  [57664/60000]
# Train Error:
#  Accuracy: 97.9%, Avg loss: 0.059585
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.379371
#
# Epoch 19:
#
# loss: 0.066810  [   64/60000]
# loss: 0.068909  [ 6464/60000]
# loss: 0.006719  [12864/60000]
# loss: 0.009612  [19264/60000]
# loss: 0.016449  [25664/60000]
# loss: 0.025330  [32064/60000]
# loss: 0.082195  [38464/60000]
# loss: 0.056651  [44864/60000]
# loss: 0.031895  [51264/60000]
# loss: 0.012062  [57664/60000]
# Train Error:
#  Accuracy: 98.3%, Avg loss: 0.049056
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.410782
#
# Epoch 20:
#
# loss: 0.095480  [   64/60000]
# loss: 0.089506  [ 6464/60000]
# loss: 0.059052  [12864/60000]
# loss: 0.039409  [19264/60000]
# loss: 0.012884  [25664/60000]
# loss: 0.129536  [32064/60000]
# loss: 0.014982  [38464/60000]
# loss: 0.032781  [44864/60000]
# loss: 0.035049  [51264/60000]
# loss: 0.169518  [57664/60000]
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.126617
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.466370
#
# Done training!

# %%
# plotting test and train loss and accuracy
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# # Approach 3 : Freeze all but the last fully connected layer

# %%
resnet18_3 = torchvision.models.resnet18(weights='DEFAULT') # equivalent to weights='IMAGENET1K_V1'
for name, param in resnet18_3.named_parameters():
  if name not in ['fc.weight', 'fc.bias']:
    param.requires_grad = False  # freezing all but the last layer 'fc'
resnet18_3.fc = nn.Linear(resnet18_3.fc.in_features, 10)
model = resnet18_3.to(device)
summary(model, (3,7,7))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1             [-1, 64, 4, 4]           9,408
#        BatchNorm2d-2             [-1, 64, 4, 4]             128
#               ReLU-3             [-1, 64, 4, 4]               0
#          MaxPool2d-4             [-1, 64, 2, 2]               0
#             Conv2d-5             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-6             [-1, 64, 2, 2]             128
#               ReLU-7             [-1, 64, 2, 2]               0
#             Conv2d-8             [-1, 64, 2, 2]          36,864
#        BatchNorm2d-9             [-1, 64, 2, 2]             128
#              ReLU-10             [-1, 64, 2, 2]               0
#        BasicBlock-11             [-1, 64, 2, 2]               0
#            Conv2d-12             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-13             [-1, 64, 2, 2]             128
#              ReLU-14             [-1, 64, 2, 2]               0
#            Conv2d-15             [-1, 64, 2, 2]          36,864
#       BatchNorm2d-16             [-1, 64, 2, 2]             128
#              ReLU-17             [-1, 64, 2, 2]               0
#        BasicBlock-18             [-1, 64, 2, 2]               0
#            Conv2d-19            [-1, 128, 1, 1]          73,728
#       BatchNorm2d-20            [-1, 128, 1, 1]             256
#              ReLU-21            [-1, 128, 1, 1]               0
#            Conv2d-22            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-23            [-1, 128, 1, 1]             256
#            Conv2d-24            [-1, 128, 1, 1]           8,192
#       BatchNorm2d-25            [-1, 128, 1, 1]             256
#              ReLU-26            [-1, 128, 1, 1]               0
#        BasicBlock-27            [-1, 128, 1, 1]               0
#            Conv2d-28            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-29            [-1, 128, 1, 1]             256
#              ReLU-30            [-1, 128, 1, 1]               0
#            Conv2d-31            [-1, 128, 1, 1]         147,456
#       BatchNorm2d-32            [-1, 128, 1, 1]             256
#              ReLU-33            [-1, 128, 1, 1]               0
#        BasicBlock-34            [-1, 128, 1, 1]               0
#            Conv2d-35            [-1, 256, 1, 1]         294,912
#       BatchNorm2d-36            [-1, 256, 1, 1]             512
#              ReLU-37            [-1, 256, 1, 1]               0
#            Conv2d-38            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-39            [-1, 256, 1, 1]             512
#            Conv2d-40            [-1, 256, 1, 1]          32,768
#       BatchNorm2d-41            [-1, 256, 1, 1]             512
#              ReLU-42            [-1, 256, 1, 1]               0
#        BasicBlock-43            [-1, 256, 1, 1]               0
#            Conv2d-44            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-45            [-1, 256, 1, 1]             512
#              ReLU-46            [-1, 256, 1, 1]               0
#            Conv2d-47            [-1, 256, 1, 1]         589,824
#       BatchNorm2d-48            [-1, 256, 1, 1]             512
#              ReLU-49            [-1, 256, 1, 1]               0
#        BasicBlock-50            [-1, 256, 1, 1]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 5,130
# Non-trainable params: 11,176,512
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.17
# Params size (MB): 42.65
# Estimated Total Size (MB): 42.82
# ----------------------------------------------------------------

# %%
train_loss, train_accuracy, test_loss, test_accuracy = Train_model(train_dataloader, test_dataloader, model)
# Out:
# Epoch 1:
#
# loss: 2.877582  [   64/60000]
# loss: 1.188221  [ 6464/60000]
# loss: 0.864376  [12864/60000]
# loss: 0.987467  [19264/60000]
# loss: 1.006953  [25664/60000]
# loss: 0.981570  [32064/60000]
# loss: 0.852846  [38464/60000]
# loss: 0.827546  [44864/60000]
# loss: 1.107228  [51264/60000]
# loss: 0.929288  [57664/60000]
# Train Error:
#  Accuracy: 71.9%, Avg loss: 0.831429
#
# Test Error:
#  Accuracy: 70.6%, Avg loss: 0.861374
#
# Epoch 2:
#
# loss: 0.864762  [   64/60000]
# loss: 0.844972  [ 6464/60000]
# loss: 0.773689  [12864/60000]
# loss: 0.809148  [19264/60000]
# loss: 0.863156  [25664/60000]
# loss: 0.897840  [32064/60000]
# loss: 0.790178  [38464/60000]
# loss: 0.808006  [44864/60000]
# loss: 1.083287  [51264/60000]
# loss: 0.876846  [57664/60000]
# Train Error:
#  Accuracy: 73.2%, Avg loss: 0.789211
#
# Test Error:
#  Accuracy: 71.6%, Avg loss: 0.829666
#
# Epoch 3:
#
# loss: 0.852695  [   64/60000]
# loss: 0.791188  [ 6464/60000]
# loss: 0.761823  [12864/60000]
# loss: 0.782693  [19264/60000]
# loss: 0.811527  [25664/60000]
# loss: 0.868100  [32064/60000]
# loss: 0.763366  [38464/60000]
# loss: 0.798539  [44864/60000]
# loss: 1.076636  [51264/60000]
# loss: 0.852076  [57664/60000]
# Train Error:
#  Accuracy: 73.7%, Avg loss: 0.773204
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.819949
#
# Epoch 4:
#
# loss: 0.843069  [   64/60000]
# loss: 0.763354  [ 6464/60000]
# loss: 0.753813  [12864/60000]
# loss: 0.771617  [19264/60000]
# loss: 0.782028  [25664/60000]
# loss: 0.850451  [32064/60000]
# loss: 0.748258  [38464/60000]
# loss: 0.792751  [44864/60000]
# loss: 1.075718  [51264/60000]
# loss: 0.837609  [57664/60000]
# Train Error:
#  Accuracy: 73.9%, Avg loss: 0.765182
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.816249
#
# Epoch 5:
#
# loss: 0.835895  [   64/60000]
# loss: 0.746427  [ 6464/60000]
# loss: 0.747528  [12864/60000]
# loss: 0.765461  [19264/60000]
# loss: 0.762579  [25664/60000]
# loss: 0.838266  [32064/60000]
# loss: 0.738679  [38464/60000]
# loss: 0.789024  [44864/60000]
# loss: 1.076919  [51264/60000]
# loss: 0.828810  [57664/60000]
# Train Error:
#  Accuracy: 73.9%, Avg loss: 0.760589
#
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.814905
#
# Epoch 6:
#
# loss: 0.830639  [   64/60000]
# loss: 0.735243  [ 6464/60000]
# loss: 0.742535  [12864/60000]
# loss: 0.761597  [19264/60000]
# loss: 0.748809  [25664/60000]
# loss: 0.829326  [32064/60000]
# loss: 0.732174  [38464/60000]
# loss: 0.786431  [44864/60000]
# loss: 1.078820  [51264/60000]
# loss: 0.823248  [57664/60000]
# Train Error:
#  Accuracy: 74.1%, Avg loss: 0.757749
#
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.814664
#
# Epoch 7:
#
# loss: 0.826703  [   64/60000]
# loss: 0.727499  [ 6464/60000]
# loss: 0.738570  [12864/60000]
# loss: 0.758971  [19264/60000]
# loss: 0.738617  [25664/60000]
# loss: 0.822550  [32064/60000]
# loss: 0.727543  [38464/60000]
# loss: 0.784496  [44864/60000]
# loss: 1.080814  [51264/60000]
# loss: 0.819517  [57664/60000]
# Train Error:
#  Accuracy: 74.1%, Avg loss: 0.755899
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.814962
#
# Epoch 8:
#
# loss: 0.823555  [   64/60000]
# loss: 0.721992  [ 6464/60000]
# loss: 0.735412  [12864/60000]
# loss: 0.757073  [19264/60000]
# loss: 0.730843  [25664/60000]
# loss: 0.817297  [32064/60000]
# loss: 0.724118  [38464/60000]
# loss: 0.782970  [44864/60000]
# loss: 1.082660  [51264/60000]
# loss: 0.816842  [57664/60000]
# Train Error:
#  Accuracy: 74.1%, Avg loss: 0.754646
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.815514
#
# Epoch 9:
#
# loss: 0.820865  [   64/60000]
# loss: 0.718003  [ 6464/60000]
# loss: 0.732889  [12864/60000]
# loss: 0.755629  [19264/60000]
# loss: 0.724779  [25664/60000]
# loss: 0.813152  [32064/60000]
# loss: 0.721504  [38464/60000]
# loss: 0.781716  [44864/60000]
# loss: 1.084280  [51264/60000]
# loss: 0.814820  [57664/60000]
# Train Error:
#  Accuracy: 74.1%, Avg loss: 0.753775
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.816174
#
# Epoch 10:
#
# loss: 0.818482  [   64/60000]
# loss: 0.715071  [ 6464/60000]
# loss: 0.730867  [12864/60000]
# loss: 0.754479  [19264/60000]
# loss: 0.719965  [25664/60000]
# loss: 0.809828  [32064/60000]
# loss: 0.719456  [38464/60000]
# loss: 0.780650  [44864/60000]
# loss: 1.085671  [51264/60000]
# loss: 0.813232  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.753159
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.816866
#
# Epoch 11:
#
# loss: 0.816344  [   64/60000]
# loss: 0.712889  [ 6464/60000]
# loss: 0.729243  [12864/60000]
# loss: 0.753523  [19264/60000]
# loss: 0.716085  [25664/60000]
# loss: 0.807119  [32064/60000]
# loss: 0.717816  [38464/60000]
# loss: 0.779721  [44864/60000]
# loss: 1.086853  [51264/60000]
# loss: 0.811952  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.752719
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.817552
#
# Epoch 12:
#
# loss: 0.814419  [   64/60000]
# loss: 0.711247  [ 6464/60000]
# loss: 0.727937  [12864/60000]
# loss: 0.752700  [19264/60000]
# loss: 0.712916  [25664/60000]
# loss: 0.804881  [32064/60000]
# loss: 0.716477  [38464/60000]
# loss: 0.778896  [44864/60000]
# loss: 1.087854  [51264/60000]
# loss: 0.810899  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.752404
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.818211
#
# Epoch 13:
#
# loss: 0.812687  [   64/60000]
# loss: 0.710003  [ 6464/60000]
# loss: 0.726882  [12864/60000]
# loss: 0.751969  [19264/60000]
# loss: 0.710297  [25664/60000]
# loss: 0.803005  [32064/60000]
# loss: 0.715364  [38464/60000]
# loss: 0.778148  [44864/60000]
# loss: 1.088703  [51264/60000]
# loss: 0.810019  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.752178
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.818833
#
# Epoch 14:
#
# loss: 0.811131  [   64/60000]
# loss: 0.709054  [ 6464/60000]
# loss: 0.726029  [12864/60000]
# loss: 0.751306  [19264/60000]
# loss: 0.708108  [25664/60000]
# loss: 0.801417  [32064/60000]
# loss: 0.714422  [38464/60000]
# loss: 0.777462  [44864/60000]
# loss: 1.089425  [51264/60000]
# loss: 0.809274  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.752016
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.819413
#
# Epoch 15:
#
# loss: 0.809736  [   64/60000]
# loss: 0.708331  [ 6464/60000]
# loss: 0.725335  [12864/60000]
# loss: 0.750693  [19264/60000]
# loss: 0.706263  [25664/60000]
# loss: 0.800057  [32064/60000]
# loss: 0.713612  [38464/60000]
# loss: 0.776825  [44864/60000]
# loss: 1.090039  [51264/60000]
# loss: 0.808635  [57664/60000]
# Train Error:
#  Accuracy: 74.3%, Avg loss: 0.751902
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.819951
#
# Epoch 16:
#
# loss: 0.808487  [   64/60000]
# loss: 0.707780  [ 6464/60000]
# loss: 0.724770  [12864/60000]
# loss: 0.750122  [19264/60000]
# loss: 0.704692  [25664/60000]
# loss: 0.798883  [32064/60000]
# loss: 0.712906  [38464/60000]
# loss: 0.776227  [44864/60000]
# loss: 1.090564  [51264/60000]
# loss: 0.808081  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.751823
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.820449
#
# Epoch 17:
#
# loss: 0.807369  [   64/60000]
# loss: 0.707364  [ 6464/60000]
# loss: 0.724307  [12864/60000]
# loss: 0.749584  [19264/60000]
# loss: 0.703343  [25664/60000]
# loss: 0.797863  [32064/60000]
# loss: 0.712280  [38464/60000]
# loss: 0.775662  [44864/60000]
# loss: 1.091011  [51264/60000]
# loss: 0.807596  [57664/60000]
# Train Error:
#  Accuracy: 74.2%, Avg loss: 0.751771
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.820907
#
# Epoch 18:
#
# loss: 0.806366  [   64/60000]
# loss: 0.707053  [ 6464/60000]
# loss: 0.723925  [12864/60000]
# loss: 0.749076  [19264/60000]
# loss: 0.702176  [25664/60000]
# loss: 0.796972  [32064/60000]
# loss: 0.711719  [38464/60000]
# loss: 0.775124  [44864/60000]
# loss: 1.091393  [51264/60000]
# loss: 0.807168  [57664/60000]
# Train Error:
#  Accuracy: 74.3%, Avg loss: 0.751738
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.821329
#
# Epoch 19:
#
# loss: 0.805468  [   64/60000]
# loss: 0.706824  [ 6464/60000]
# loss: 0.723608  [12864/60000]
# loss: 0.748595  [19264/60000]
# loss: 0.701159  [25664/60000]
# loss: 0.796188  [32064/60000]
# loss: 0.711209  [38464/60000]
# loss: 0.774610  [44864/60000]
# loss: 1.091717  [51264/60000]
# loss: 0.806787  [57664/60000]
# Train Error:
#  Accuracy: 74.3%, Avg loss: 0.751720
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.821718
#
# Epoch 20:
#
# loss: 0.804662  [   64/60000]
# loss: 0.706663  [ 6464/60000]
# loss: 0.723344  [12864/60000]
# loss: 0.748138  [19264/60000]
# loss: 0.700266  [25664/60000]
# loss: 0.795497  [32064/60000]
# loss: 0.710743  [38464/60000]
# loss: 0.774117  [44864/60000]
# loss: 1.091992  [51264/60000]
# loss: 0.806445  [57664/60000]
# Train Error:
#  Accuracy: 74.3%, Avg loss: 0.751714
#
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.822076
#
# Done training!

# %%
plot_train_test(train_loss, train_accuracy, test_loss, test_accuracy)

# %% [markdown]
# ### <font color='red'>Your text here.</font>
# <font color='red'>Enter your text descriptions in the cell below:</font>

# %% [markdown]
# <span style="color:green"># Approach 1 : Random Weights
# The model starts with Random Weights and hence the weights assigned would be what is in the memory and would need to train and update all the weights. This makes it computationally expensive as the model has no prior knowledge about the train data. The only advantage is we are using a tested architecture. Here the best train accuracy is 97% and the test accuracy is 91%. Here we can see considerable overfitting. </span>
#
# <span style="color:green"># Approach 2: Default or IMAGENET1K_V1 weights
# Here we load the Resnet18 model with pre-trained weights. This means that the model has knowledge of some features that it has already learned using the IMAGENET1K_V1 weights. Hence it requires less data and consequently less time to converge. Here the best test accuracy is 92% and train accuracy corresponding to it is 97.9%. Here as well we can see considerable overfitting. </span>
#
# <span style="color:green"># Approach 3 : Freeze all but the last layer
# Typically used when we have less data to train on. Since we are only working with the last fully connected layer, hence the number of parameters we train would be limited. This is also the reason for the lower accuracy. Here the best training accuracy is 74.2% and test accuracy is 72.2%. Even though the accuracy is not as high as the previous results, we see a lower rate of overfitting with this model. This could be because of the number of parameters we use here for training is considerably less(5130).</span>
